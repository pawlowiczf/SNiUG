# %%
import numpy as np
import matplotlib.pyplot as plt
import time

np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1)
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities, _ = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]

    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)

    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(16, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch: np.ndarray, stochastic: bool = False) -> np.ndarray:
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(x: np.ndarray) -> np.ndarray:
    max_z = np.max(x, axis=1, keepdims=True)
    x = x - max_z
    exp_x = np.exp(x)

    sum_z = np.sum(exp_x, axis=1, keepdims=True)
    return exp_x / sum_z

# %%
def relu(batch: np.ndarray, stochastic: bool = False) -> np.ndarray:
    """
    Stochastic ReLU
    """
    if stochastic:
        noise = randn(*batch.shape) * np.sqrt(sigmoid(batch))
        return np.maximum(0, batch + noise)
    return np.maximum(0, batch)

def relu_derivative(batch: np.ndarray) -> np.ndarray:
    """
    ReLU derivative
    """
    return (batch > 0).astype(float)

# %% [markdown]
# # MNIST dataset

# %%
from mnists import MNIST

mnist = MNIST()

PREVIEW_N_ROWS = 12
PREVIEW_N_COLS = 24
TILE_DIM = 28  # [px]

def create_mnist_digits(n_rows: int, n_cols: int, tile_dim: int) -> np.ndarray:
    shape = (n_rows, n_cols, tile_dim, tile_dim)
    return np.reshape(mnist.train_images()[: 12 * 24], newshape=shape)

mnist_digits = create_mnist_digits(PREVIEW_N_ROWS, PREVIEW_N_COLS, TILE_DIM)

tiles(mnist_digits)

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 dropout_rate, learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
        
        self.dropout_rate = dropout_rate
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None
        
        self.M = zeros(self.visible_size+1, self.hidden_size)
        
    def deep_copy(self):
        copy = Layer(self.visible_size, self.hidden_size, self.activation_fun, self.d_activation_fun,
                     self.dropout_rate, self.learning_rate, self.momentum, self.weight_limit)
        copy.W = np.copy(self.W)
        copy.M = np.copy(self.M)
        return copy

# %%
def limit_weights(weights: np.ndarray, lambda_limit: float) -> np.ndarray:
    """
    Weight normalization
    """
    if lambda_limit == 0:
        return weights

    column_norms = np.linalg.norm(weights, ord=2, axis=0)
    scale = np.minimum(1.0, lambda_limit / column_norms)

    return weights * scale

# %% [markdown]
# ### Forward pass
#
# Calculate total input to the neurons. Then calculate activations (remember to add *ones* as the last column). Store result in `layer.activations`.
#
# ##### Computing derivatives of activation function
#
# If `compute_derivatives` is set to `True`, we also need to compute the derivatives of the activation function and store them in `layer.d_activations`. We **do not** need to add *ones column* to the derivatives matrix! *Ones* are only needed in the activations matrix, where they are used to add biases to the total input of neurons in the next hidden layer.
#
# ##### Dropout
#
# If `compute_derivatives` is set to `True` and the dropout rate in the input layer is greater than 0, we need to calculate the dropout mask for the MLP input and apply it to `batch`.
#
# When calculating hidden activations in an MLP layer, check whether dropout rate in the next layer is greater then 0. If yes, then we need to apply dropout to the calculated activations (and derivatives of activations). In this case:
# * construct dropout mask for the hidden layer,
# * apply this mask to where it is needed in the hidden layer.
#
# Do **not** apply dropout to the last column in activations or input batch, as they contains fixed *ones*.

# %%
def forward_pass(mlp, batch, compute_derivatives):
    if compute_derivatives and mlp[0].dropout_rate > 0:
        batch = np.copy(batch)
        mask = (rand(*batch.shape) > mlp[0].dropout_rate).astype(np.float32)
        batch *= mask
    #

    visible = batch

    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        layer.activations = layer.activation_fun(z)

        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)

            if mlp[layer_idx+1].dropout_rate > 0:
                mask = (rand(*layer.activations.shape) > mlp[layer_idx+1].dropout_rate).astype(np.float32)
                layer.activations *= mask
                layer.d_activations *= mask

        layer.activations = append_ones(layer.activations)
        visible = layer.activations
    #

    return visible[:, :-1], batch
#

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]

    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations

            error = layer.deltas @ layer.W[:-1, :].T
            prev_layer.deltas = error * prev_layer.d_activations
        else:
            visible = batch

        gradient = visible.T @ layer.deltas / observations_count
        layer.M = layer.momentum * layer.M + layer.learning_rate * gradient
        layer.W -= layer.M

        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)
#

# %% [markdown]
# ### Mean dropout network
#
# Implement the weight scalling for the network that approximates MLP outputs under dropout.

# %%
def mean_network(mlp):
    mlp = [layer.deep_copy() for layer in mlp]

    for layer in mlp:
        layer.W *= (1 - layer.dropout_rate)

    return mlp

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size

    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)

    for batch_idx, (batch, batch_labels) in enumerate(
        zip(batched_data, batched_labels)
    ):
        # Forward pass: compute activatations and derivatives of activations
        y, masked_batch = forward_pass(mlp, batch, True)

        # implement the deltas for the last layer (i.e. the loss function)
        mlp[-1].deltas = y - batch_labels

        error_backpropagate(mlp, masked_batch)

        if batch_idx % round(batches_limit / 50) == 0:
            print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")

        if epoch == 5:
            for layer in mlp:
                layer.momentum = 0.95
                layer.lr = 0.15
        elif epoch == 170:
            for layer in mlp:
                layer.momentum = 0.5
                layer.lr = 0.01

        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        test_mlp = mean_network(mlp)

        predictions = classify(test_mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# # MNIST digits classification

# %%
np.random.seed(1234)

DATASET_SIZE: int = 10000  # 60000 for whole dataset
DIGIT_SIZE: int = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 512

BATCH_SIZE = 128
EPOCHS_COUNT = 200

LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.5

# %%
from IPython.core.display import HTML

def evaluate(mlp, train_set, train_labels,
             validation_set, validation_labels,
             batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)

    display(HTML('<h3>Input layer filters in MLP</h3>'))
    draw_layer_filters(mlp[0])

    display(HTML('<h3>Largest norms of weight-vectors in MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Plain MLP (no dropout)

# %%
mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.0, LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, 0.0, LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, 0.0, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

evaluate(mlp,
         mnist_train_images, mnist_train_labels,
         mnist_test_images, mnist_test_labels,
         BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>MLP training</h3>
# Epoch 1:	########################################	elapsed: 3.50s, accuracy: 23.55
# Epoch 2:	########################################	elapsed: 3.04s, accuracy: 68.84
# Epoch 3:	########################################	elapsed: 4.57s, accuracy: 75.74
# Epoch 4:	########################################	elapsed: 5.78s, accuracy: 81.75
# Epoch 5:	########################################	elapsed: 4.13s, accuracy: 85.10
# Epoch 6:	########################################	elapsed: 2.88s, accuracy: 90.41
# Epoch 7:	########################################	elapsed: 3.01s, accuracy: 93.56
# Epoch 8:	########################################	elapsed: 2.90s, accuracy: 94.42
# Epoch 9:	########################################	elapsed: 2.87s, accuracy: 94.52
# Epoch 10:	########################################	elapsed: 3.20s, accuracy: 94.82
# Epoch 11:	########################################	elapsed: 3.07s, accuracy: 94.07
# Epoch 12:	########################################	elapsed: 3.13s, accuracy: 94.89
# Epoch 13:	########################################	elapsed: 2.77s, accuracy: 95.44
# Epoch 14:	########################################	elapsed: 2.85s, accuracy: 95.11
# Epoch 15:	########################################	elapsed: 2.97s, accuracy: 96.01
# Epoch 16:	########################################	elapsed: 2.88s, accuracy: 95.82
# Epoch 17:	########################################	elapsed: 2.98s, accuracy: 96.12
# Epoch 18:	########################################	elapsed: 3.19s, accuracy: 95.75
# Epoch 19:	########################################	elapsed: 2.06s, accuracy: 96.41
# Epoch 20:	########################################	elapsed: 2.04s, accuracy: 95.40
# Epoch 21:	########################################	elapsed: 1.92s, accuracy: 96.74
# Epoch 22:	########################################	elapsed: 1.85s, accuracy: 96.68
# Epoch 23:	########################################	elapsed: 1.85s, accuracy: 96.91
# Epoch 24:	########################################	elapsed: 2.01s, accuracy: 96.84
# Epoch 25:	########################################	elapsed: 1.79s, accuracy: 96.97
# Epoch 26:	########################################	elapsed: 1.67s, accuracy: 96.96
# Epoch 27:	########################################	elapsed: 1.48s, accuracy: 96.98
# Epoch 28:	########################################	elapsed: 1.50s, accuracy: 96.95
# Epoch 29:	########################################	elapsed: 1.94s, accuracy: 96.93
# Epoch 30:	########################################	elapsed: 1.70s, accuracy: 96.92
# Epoch 31:	########################################	elapsed: 1.60s, accuracy: 96.92
# Epoch 32:	########################################	elapsed: 1.50s, accuracy: 96.94
# Epoch 33:	########################################	elapsed: 1.50s, accuracy: 96.94
# Epoch 34:	########################################	elapsed: 3.05s, accuracy: 96.94
# Epoch 35:	########################################	elapsed: 1.48s, accuracy: 96.93
# Epoch 36:	########################################	elapsed: 1.48s, accuracy: 96.94
# Epoch 37:	########################################	elapsed: 1.42s, accuracy: 96.94
# Epoch 38:	########################################	elapsed: 1.53s, accuracy: 96.93
# Epoch 39:	########################################	elapsed: 1.66s, accuracy: 96.92
# Epoch 40:	########################################	elapsed: 1.49s, accuracy: 96.92
# Epoch 41:	########################################	elapsed: 1.46s, accuracy: 96.93
# Epoch 42:	########################################	elapsed: 1.50s, accuracy: 96.94
# Epoch 43:	########################################	elapsed: 1.56s, accuracy: 96.94
# Epoch 44:	########################################	elapsed: 1.51s, accuracy: 96.93
# Epoch 45:	########################################	elapsed: 1.50s, accuracy: 96.92
# Epoch 46:	########################################	elapsed: 1.48s, accuracy: 96.92
# Epoch 47:	########################################	elapsed: 1.48s, accuracy: 96.92
# Epoch 48:	########################################	elapsed: 1.51s, accuracy: 96.93
# Epoch 49:	########################################	elapsed: 1.74s, accuracy: 96.93
# Epoch 50:	########################################	elapsed: 1.54s, accuracy: 96.94
# Epoch 51:	########################################	elapsed: 1.40s, accuracy: 96.95
# Epoch 52:	########################################	elapsed: 1.64s, accuracy: 96.95
# Epoch 53:	########################################	elapsed: 2.16s, accuracy: 96.95
# Epoch 54:	########################################	elapsed: 3.45s, accuracy: 96.95
# Epoch 55:	########################################	elapsed: 2.59s, accuracy: 96.95
# Epoch 56:	########################################	elapsed: 2.03s, accuracy: 96.95
# Epoch 57:	########################################	elapsed: 1.80s, accuracy: 96.96
# Epoch 58:	########################################	elapsed: 1.59s, accuracy: 96.94
# Epoch 59:	########################################	elapsed: 1.74s, accuracy: 96.94
# Epoch 60:	########################################	elapsed: 1.66s, accuracy: 96.94
# Epoch 61:	########################################	elapsed: 1.70s, accuracy: 96.95
# Epoch 62:	########################################	elapsed: 1.79s, accuracy: 96.95
# Epoch 63:	########################################	elapsed: 2.00s, accuracy: 96.95
# Epoch 64:	########################################	elapsed: 2.48s, accuracy: 96.96
# Epoch 65:	########################################	elapsed: 2.28s, accuracy: 96.96
# Epoch 66:	########################################	elapsed: 2.08s, accuracy: 96.95
# Epoch 67:	########################################	elapsed: 2.16s, accuracy: 96.95
# Epoch 68:	########################################	elapsed: 1.81s, accuracy: 96.95
# Epoch 69:	########################################	elapsed: 1.81s, accuracy: 96.95
# Epoch 70:	########################################	elapsed: 1.82s, accuracy: 96.95
# Epoch 71:	########################################	elapsed: 1.61s, accuracy: 96.95
# Epoch 72:	########################################	elapsed: 1.68s, accuracy: 96.95
# Epoch 73:	########################################	elapsed: 1.68s, accuracy: 96.95
# Epoch 74:	########################################	elapsed: 1.60s, accuracy: 96.95
# Epoch 75:	########################################	elapsed: 1.77s, accuracy: 96.94
# Epoch 76:	########################################	elapsed: 1.63s, accuracy: 96.95
# Epoch 77:	########################################	elapsed: 1.69s, accuracy: 96.95
# Epoch 78:	########################################	elapsed: 1.62s, accuracy: 96.95
# Epoch 79:	########################################	elapsed: 1.59s, accuracy: 96.95
# Epoch 80:	########################################	elapsed: 1.75s, accuracy: 96.95
# Epoch 81:	########################################	elapsed: 1.62s, accuracy: 96.95
# Epoch 82:	########################################	elapsed: 1.64s, accuracy: 96.96
# Epoch 83:	########################################	elapsed: 1.56s, accuracy: 96.96
# Epoch 84:	########################################	elapsed: 1.68s, accuracy: 96.96
# Epoch 85:	########################################	elapsed: 1.57s, accuracy: 96.96
# Epoch 86:	########################################	elapsed: 1.57s, accuracy: 96.96
# Epoch 87:	########################################	elapsed: 1.56s, accuracy: 96.97
# Epoch 88:	########################################	elapsed: 1.68s, accuracy: 96.97
# Epoch 89:	########################################	elapsed: 1.55s, accuracy: 96.97
# Epoch 90:	########################################	elapsed: 1.59s, accuracy: 96.97
# Epoch 91:	########################################	elapsed: 1.66s, accuracy: 96.97
# Epoch 92:	########################################	elapsed: 1.85s, accuracy: 96.97
# Epoch 93:	########################################	elapsed: 1.89s, accuracy: 96.97
# Epoch 94:	########################################	elapsed: 2.15s, accuracy: 96.97
# Epoch 95:	########################################	elapsed: 2.36s, accuracy: 96.97
# Epoch 96:	########################################	elapsed: 1.90s, accuracy: 96.97
# Epoch 97:	########################################	elapsed: 1.98s, accuracy: 96.97
# Epoch 98:	########################################	elapsed: 1.71s, accuracy: 96.97
# Epoch 99:	########################################	elapsed: 1.68s, accuracy: 96.97
# Epoch 100:	########################################	elapsed: 1.64s, accuracy: 96.97
# Epoch 101:	########################################	elapsed: 1.73s, accuracy: 96.97
# Epoch 102:	########################################	elapsed: 1.52s, accuracy: 96.97
# Epoch 103:	########################################	elapsed: 1.55s, accuracy: 96.97
# Epoch 104:	########################################	elapsed: 1.49s, accuracy: 96.97
# Epoch 105:	########################################	elapsed: 1.57s, accuracy: 96.96
# Epoch 106:	########################################	elapsed: 1.57s, accuracy: 96.96
# Epoch 107:	########################################	elapsed: 1.57s, accuracy: 96.96
# Epoch 108:	########################################	elapsed: 1.70s, accuracy: 96.96
# Epoch 109:	########################################	elapsed: 1.90s, accuracy: 96.96
# Epoch 110:	########################################	elapsed: 1.66s, accuracy: 96.96
# Epoch 111:	########################################	elapsed: 1.67s, accuracy: 96.96
# Epoch 112:	########################################	elapsed: 1.84s, accuracy: 96.96
# Epoch 113:	########################################	elapsed: 1.81s, accuracy: 96.96
# Epoch 114:	########################################	elapsed: 1.82s, accuracy: 96.96
# Epoch 115:	########################################	elapsed: 1.76s, accuracy: 96.96
# Epoch 116:	########################################	elapsed: 1.58s, accuracy: 96.96
# Epoch 117:	########################################	elapsed: 1.82s, accuracy: 96.96
# Epoch 118:	########################################	elapsed: 1.78s, accuracy: 96.95
# Epoch 119:	########################################	elapsed: 1.66s, accuracy: 96.95
# Epoch 120:	########################################	elapsed: 1.55s, accuracy: 96.95
# Epoch 121:	########################################	elapsed: 1.59s, accuracy: 96.95
# Epoch 122:	########################################	elapsed: 1.68s, accuracy: 96.94
# Epoch 123:	########################################	elapsed: 1.75s, accuracy: 96.94
# Epoch 124:	########################################	elapsed: 1.64s, accuracy: 96.94
# Epoch 125:	########################################	elapsed: 1.65s, accuracy: 96.94
# Epoch 126:	########################################	elapsed: 1.62s, accuracy: 96.94
# Epoch 127:	########################################	elapsed: 1.64s, accuracy: 96.94
# Epoch 128:	########################################	elapsed: 1.66s, accuracy: 96.94
# Epoch 129:	########################################	elapsed: 1.74s, accuracy: 96.94
# Epoch 130:	########################################	elapsed: 1.70s, accuracy: 96.93
# Epoch 131:	########################################	elapsed: 1.79s, accuracy: 96.93
# Epoch 132:	########################################	elapsed: 1.67s, accuracy: 96.93
# Epoch 133:	########################################	elapsed: 1.75s, accuracy: 96.93
# Epoch 134:	########################################	elapsed: 1.92s, accuracy: 96.93
# Epoch 135:	########################################	elapsed: 1.47s, accuracy: 96.93
# Epoch 136:	########################################	elapsed: 1.59s, accuracy: 96.93
# Epoch 137:	########################################	elapsed: 1.65s, accuracy: 96.93
# Epoch 138:	########################################	elapsed: 1.57s, accuracy: 96.93
# Epoch 139:	########################################	elapsed: 2.20s, accuracy: 96.93
# Epoch 140:	########################################	elapsed: 1.66s, accuracy: 96.93
# Epoch 141:	########################################	elapsed: 1.55s, accuracy: 96.93
# Epoch 142:	########################################	elapsed: 1.53s, accuracy: 96.93
# Epoch 143:	########################################	elapsed: 1.85s, accuracy: 96.93
# Epoch 144:	########################################	elapsed: 1.75s, accuracy: 96.93
# Epoch 145:	########################################	elapsed: 1.74s, accuracy: 96.93
# Epoch 146:	########################################	elapsed: 1.76s, accuracy: 96.93
# Epoch 147:	########################################	elapsed: 1.67s, accuracy: 96.94
# Epoch 148:	########################################	elapsed: 1.62s, accuracy: 96.95
# Epoch 149:	########################################	elapsed: 1.66s, accuracy: 96.95
# Epoch 150:	########################################	elapsed: 1.65s, accuracy: 96.95
# Epoch 151:	########################################	elapsed: 1.68s, accuracy: 96.95
# Epoch 152:	########################################	elapsed: 1.71s, accuracy: 96.95
# Epoch 153:	########################################	elapsed: 1.70s, accuracy: 96.95
# Epoch 154:	########################################	elapsed: 1.79s, accuracy: 96.95
# Epoch 155:	########################################	elapsed: 1.74s, accuracy: 96.95
# Epoch 156:	########################################	elapsed: 1.43s, accuracy: 96.95
# Epoch 157:	########################################	elapsed: 1.60s, accuracy: 96.95
# Epoch 158:	########################################	elapsed: 1.68s, accuracy: 96.95
# Epoch 159:	########################################	elapsed: 1.78s, accuracy: 96.94
# Epoch 160:	########################################	elapsed: 1.77s, accuracy: 96.94
# Epoch 161:	########################################	elapsed: 1.89s, accuracy: 96.94
