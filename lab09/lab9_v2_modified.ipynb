# %% [markdown]
# # Dropout

# %%
# Check for all needed packages
import time

import IPython
import matplotlib
import mnists
import numpy

# In case of ImportError, install them to the running kernel with
# %pip install numpy matplotlib mnists
# or the the runtime container with:
# !pip install numpy matplotlib mnists
# (In case of the latter, remember to restart the kernel!)

# Tested in Python 3.14.3 with:
# numpy==2.4.3
# matplotlib==3.10.8
# mnists==0.4.1
# Out:
# /usr/sbin/python: No module named pip
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       3 import time
#       4
#       5 import IPython
#       6 import matplotlib
# ----> 7 import mnists
#       8 import numpy
#       9
#      10 # In case of ImportError, install them to the running kernel with
#
# ModuleNotFoundError: No module named 'mnists'

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

np.random.seed(1234)

try:
    import mkl

    mkl.set_num_threads(2)
except ImportError:
    print(
        "Intel Math Kernel Library (MKL) does not always work on every machine. "
        "Continuing without `mkl`."
    )

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix: np.ndarray,  axis: int=1) -> np.ndarray:
    """
    Appends a column of ones to the right side of a 2D matrix.
    """
    return np.concatenate(
        (matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis
    )


def zeros(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of zeros with the given shape.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. zeros(3, 4) creates a (3, 4) array.
    """
    return np.zeros(shape=tuple(dims), dtype=np.float32)


def ones(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of ones with the given shape.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. ones(3, 4) creates a (3, 4) array.
    """
    return np.ones(shape=tuple(dims), dtype=np.float32)


def rand(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of random values sampled from a uniform [0, 1) distribution.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. rand(3, 4) creates a (3, 4) array.
    """
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of random values sampled from a standard normal distribution.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. rand(3, 4) creates a (3, 4) array.
    """
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq: list, size: int) -> tuple[np.ndarray]:
    """
    Splits a sequence into consecutive chunks of a given size.

    The last chunk may be smaller than `size` if the sequence length
    is not evenly divisible.

    Args:
        seq:  The input sequence (e.g. list or other sliceable) to split.
        size: The maximum number of elements in each chunk.

    Returns:
        Successive sub-sequences of length `size` (or less for the final chunk).
    """
    return tuple([seq[pos : (pos + size)] for pos in range(0, len(seq), size)])


def as_matrix(vector: np.ndarray) -> np.ndarray:
    """Reshape 1D vector to column matrix."""
    return np.reshape(vector, (-1, 1))


def one_hot_encode(labels: np.ndarray) -> np.ndarray:
    """Convert integer labels to one-hot encoded matrix."""
    (n_samples,) = labels.shape
    n_classes = np.max(labels) + 1

    one_hot = np.zeros((n_samples, n_classes), dtype=np.float32)
    one_hot[np.arange(n_samples), labels] = 1
    return one_hot

def classify(mlp: "MLP", batch: np.ndarray, forwad_pass_func: callable) -> np.ndarray:
    """
    Classify a batch of inputs using the MLP model.
    
    Performs a forward pass to compute class probabilities, then returns
    the predicted class indices (argmax over probabilities).
    
    Args:
        mlp: Trained MLP model with forward_pass method.
        batch: Input data batch of shape (N, input_dim).
    
    Returns:
        Predicted class indices of shape (N,).
    """
    # Shape: (batch_size, num_classes)
    probabilities: np.ndarray = forwad_pass_func(mlp, batch, False)
    
    predictions = np.argmax(probabilities, axis=1)
    return predictions

def arrange_tiles_img(examples: np.ndarray) -> np.ndarray:
    """
    Arrange 2D matrices as tiles

    Takes 4D `examples` tensor with dims:
        rows x cols x tile_height x tile_width
    """
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]

    space_between_tiles = 2
    img_matrix = np.empty(
        shape=(
            rows_count * (tile_height + space_between_tiles) - space_between_tiles,
            cols_count * (tile_width + space_between_tiles) - space_between_tiles,
        )
    )
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            img_matrix[x_0 : x_0 + tile_height, y_0 : y_0 + tile_width] = examples[r, c]

    return img_matrix


def preview_tiles(examples: np.ndarray) -> None:
    """Previews the arrange tiles"""
    img = arrange_tiles_img(examples)
    plt.matshow(img, cmap="gray", interpolation="none")
    plt.axis("off")
    plt.show()

def draw_rbm_filters(rbm: "RestrictedBoltzmannMachine") -> None:
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], shape=(8, -1, 28, 28))
    preview_tiles(filters)

def draw_layer_filters(layer: "Layer") -> None:
    filters = np.reshape(layer.W[:-1].T, shape=(8, -1, 28, 28))
    preview_tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch: np.ndarray, stochastic: bool = False) -> np.ndarray:
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(batch: np.ndarray) -> np.ndarray:
    # TODO implement (copy from previous labs)
    raise Exception("Not implemented!")

# %%
def relu(batch: np.ndarray, stochastic: bool = False) -> np.ndarray:
    """
    Stochastic ReLU
    """
    # TODO implement (copy from previous labs)
    raise Exception("Not implemented!")

def relu_derivative(batch: np.ndarray) -> np.ndarray:
    """
    ReLU derivative
    """
    # TODO implement (copy from previous labs)
    raise Exception("Not implemented!")

# %% [markdown]
# # MNIST dataset

# %%
from mnists import MNIST

mnist = MNIST()

PREVIEW_N_ROWS = 12
PREVIEW_N_COLS = 24
TILE_DIM = 28  # [px]


def create_mnist_digits(n_rows: int, n_cols: int, tile_dim: int) -> np.ndarray:
    shape = (n_rows, n_cols, tile_dim, tile_dim)
    return np.reshape(mnist.train_images()[: 12 * 24], shape=shape)


mnist_digits = create_mnist_digits(PREVIEW_N_ROWS, PREVIEW_N_COLS, TILE_DIM)

preview_tiles(mnist_digits)

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(
        self, 
        visible_size: int,
        hidden_size: int,
        activation_fun: callable[np.ndarray],
        d_activation_fun: callable[np.ndarray],
        dropout_rate: float,
        learning_rate: float,
        momentum: float,
        weight_limit: float,
    ):

        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
        
        self.dropout_rate = dropout_rate
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self) -> None:
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)
        
    def deep_copy(self) -> "Layer":
        # Idea: rewerite it in terms of __dict__/__atributes__ and **kwargs.
        copy = Layer(self.visible_size, self.hidden_size, self.activation_fun, self.d_activation_fun,
                     self.dropout_rate, self.learning_rate, self.momentum, self.weight_limit)
        copy.W = np.copy(self.W)
        copy.M = np.copy(self.M)
        return copy

# %%
from typing import TypeAlias
MLP: TypeAlias = list[Layer]

# %%
def limit_weights(weights: np.ndarray, lambda_limit: float) -> np.ndarray:
    """
    Weight normalization
    """
    # TODO implement (copy from previous labs)
    raise Exception("Not implemented!")

# %% [markdown]
# ### Forward pass
#
# Calculate total input to the neurons. Then calculate activations (remember to add *ones* as the last column). Store result in `layer.activations`.
#
# ##### Computing derivatives of activation function
#
# If `compute_derivatives` is set to `True`, we also need to compute the derivatives of the activation function and store them in `layer.d_activations`. We **do not** need to add *ones column* to the derivatives matrix! *Ones* are only needed in the activations matrix, where they are used to add biases to the total input of neurons in the next hidden layer.
#
# ##### Dropout
#
# If `compute_derivatives` is set to `True` and the dropout rate in the input layer is greater than 0, we need to calculate the dropout mask for the MLP input and apply it to `batch`.
#
# When calculating hidden activations in an MLP layer, check whether dropout rate in the next layer is greater then 0. If yes, then we need to apply dropout to the calculated activations (and derivatives of activations). In this case:
# * construct dropout mask for the hidden layer,
# * apply this mask to where it is needed in the hidden layer.
#
# Do **not** apply dropout to the last column in activations or input batch, as they contains fixed *ones*.

# %%
def dropout_mask(rate: float, *dims) -> np.ndarray:
    """
    dims - a tuple or a list with layer dimensions
    """
    # TODO THIS FUNC IS A SUGGESTION - implement the dropout as you wish!
    raise Exception("Read TODO")

def forward_pass(mlp: MLP, batch: np.ndarray, compute_derivatives: bool) -> np.ndarray:
    if compute_derivatives and mlp[0].dropout_rate > 0:
        batch = np.copy(batch)
        
        # TODO implement
        raise Exception("Dropout in the forward pass is not implemented!")
        #
        # apply dropout to the MLP input
        #

    visible = batch
    for layer_idx, layer in enumerate(mlp):
        # TODO implement
        raise Exception('Compute layer activations here!')
        # z = ???
        # layer.activations = ???
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            # TODO implement
            raise Exception('Remember about the derivatives of the activation function!')
            # layer.d_activations = ???
            
            if mlp[layer_idx+1].dropout_rate > 0:
                # TODO implement
                raise Exception("Dropout in the forward pass is not implemented!")
                #
                # apply dropout where is it needed in the hidden layer
                #
            
        visible = layer.activations
    
    return visible[:, :-1], batch

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp: MLP, batch: np.ndarray) -> None:
    observations_count = batch.shape[0]

    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            
            # TODO implement (copy from prev labs)
            raise Exception("Calculate the deltas in 'prev_layer'")
            # prev_layer.deltas = ???
        else:
            visible = batch
        
        # TODO implement (copy from prev labs)
        raise Exception("Update the momentum matrix with gradient from error backpropagation")
        # prev_layer.deltas = ???
        
        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Mean dropout network
#
# Implement the weight scaling for the network that approximates MLP outputs under dropout.

# %%
def mean_network(mlp: MLP) -> MLP:
    mlp = [layer.deep_copy() for layer in mlp]
    
    for layer in mlp:
       # TODO implement
       raise Exception("Mean dropout network is not implemented!")
         
    return mlp

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(
    mlp: MLP, dataset: np.ndarray, labels: np.ndarray, batch_size: np.ndarray
) -> None:
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y, batch_with_dropout = forward_pass(mlp, batch, True)
        
        # TODO implement (copy from prev labs)
        raise Exception("Delta in the sofmax layer is unimplemented!")
        # mlp[-1].deltas = ??
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch_with_dropout)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_mlp_training(
    mlp: MLP,
    train_set: np.ndarray,
    train_labels: np.ndarray,
    validation_set: np.ndarray,
    validation_labels: np.ndarray,
    batch_size: int,
    epochs_count: int,
    forward_pass_func: callable,
    target_momentum: float = 0.95,
) -> None:
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp:
                layer.momentum = 0.95
                layer.learning_rate = 0.15
        elif epoch == 150:
            for layer in mlp:
                layer.momentum = 0.925
                layer.learning_rate = 0.1
        elif epoch == 175:
            for layer in mlp:
                layer.momentum = 0.9
                layer.learning_rate = 0.01
                
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time
        
        test_mlp = mean_network(mlp)
        
        predictions = classify(test_mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# # MNIST digits classification

# %%
np.random.seed(1234)

DATASET_SIZE: int = 10000  # 60000 for whole dataset
DIGIT_SIZE: int = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE: int = DIGIT_SIZE * DIGIT_SIZE
HIDDEN_LAYER_SIZE: int = 256

BATCH_SIZE: int = 128
EPOCHS_COUNT: int = 50

LEARNING_RATE: float = 0.03
SOFTMAX_LEARNING_RATE: float = 0.15
MOMENTUM: float = 0.5

# %%
from IPython.core.display import HTML

def evaluate(
    mlp: MLP,
    train_set: np.ndarray,
    train_labels: np.ndarray,
    validation_set: np.ndarray,
    validation_labels: np.ndarray,
    monitoring_set: np.ndarray,
    batch_size: int,
    epochs_count: int,
) -> None:
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Plain MLP (no dropout)

# %%
mlp = [
      Layer(
        visible_size=VISIBLE_LAYER_SIZE,
        hidden_size=HIDDEN_LAYER_SIZE,
        activation_fun=relu,
        d_activation_fun=relu_derivative,
        dropout_rate=0.0,
        learning_rate=MLP_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=2.0,
    ),
    Layer(
        visible_size=HIDDEN_LAYER_SIZE,
        hidden_size=HIDDEN_LAYER_SIZE,
        activation_fun=relu,
        d_activation_fun=relu_derivative,
        dropout_rate=0.0,
        learning_rate=MLP_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=1.0,
    ),
    Layer(
        visible_size=HIDDEN_LAYER_SIZE,
        hidden_size=10,
        activation_fun=softmax,
        d_activation_fun=None,
        dropout_rate=0.0,
        learning_rate=SOFTMAX_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=4.0,
    ),
]

evaluate(
      mlp=mlp, 
      train_set=mnist_train_images,
      train_labels=mnist_train_labels,
      validation_set=mnist_test_images,
      validation_labels=mnist_test_labels,
      batch_size=BATCH_SIZE,
      epochs_count=EPOCHS_COUNT,
)
# Out:
# <h3>MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.60s, accuracy: 18.95
# Epoch 2:	########################################	elapsed: 0.61s, accuracy: 46.62
# Epoch 3:	########################################	elapsed: 0.59s, accuracy: 69.79
# Epoch 4:	########################################	elapsed: 0.58s, accuracy: 75.62
# Epoch 5:	########################################	elapsed: 0.61s, accuracy: 80.23
# Epoch 6:	########################################	elapsed: 0.59s, accuracy: 88.20
# Epoch 7:	########################################	elapsed: 0.57s, accuracy: 91.04
# Epoch 8:	########################################	elapsed: 0.59s, accuracy: 91.46
# Epoch 9:	########################################	elapsed: 0.60s, accuracy: 91.41
# Epoch 10:	########################################	elapsed: 0.59s, accuracy: 89.67
# Epoch 11:	########################################	elapsed: 0.62s, accuracy: 90.15
# Epoch 12:	########################################	elapsed: 0.58s, accuracy: 93.21
# Epoch 13:	########################################	elapsed: 0.59s, accuracy: 93.12
# Epoch 14:	########################################	elapsed: 0.58s, accuracy: 93.75
# Epoch 15:	########################################	elapsed: 0.60s, accuracy: 93.64
# Epoch 16:	########################################	elapsed: 0.61s, accuracy: 93.74
# Epoch 17:	########################################	elapsed: 0.61s, accuracy: 94.20
# Epoch 18:	########################################	elapsed: 0.61s, accuracy: 94.46
# Epoch 19:	########################################	elapsed: 0.60s, accuracy: 94.23
# Epoch 20:	########################################	elapsed: 0.59s, accuracy: 94.59
# Epoch 21:	########################################	elapsed: 0.61s, accuracy: 95.14
# Epoch 22:	########################################	elapsed: 0.61s, accuracy: 93.84
# Epoch 23:	########################################	elapsed: 0.58s, accuracy: 95.05
# Epoch 24:	########################################	elapsed: 0.61s, accuracy: 93.86
# Epoch 25:	########################################	elapsed: 0.62s, accuracy: 94.11
# Epoch 26:	########################################	elapsed: 0.59s, accuracy: 94.57
# Epoch 27:	########################################	elapsed: 0.60s, accuracy: 94.15
# Epoch 28:	########################################	elapsed: 0.62s, accuracy: 94.65
# Epoch 29:	########################################	elapsed: 0.60s, accuracy: 94.38
# Epoch 30:	########################################	elapsed: 0.61s, accuracy: 93.06
# Epoch 31:	########################################	elapsed: 0.61s, accuracy: 94.20
# Epoch 32:	########################################	elapsed: 0.61s, accuracy: 93.84
# Epoch 33:	########################################	elapsed: 0.61s, accuracy: 94.09
# Epoch 34:	########################################	elapsed: 0.59s, accuracy: 94.85
# Epoch 35:	########################################	elapsed: 0.61s, accuracy: 94.51
# Epoch 36:	########################################	elapsed: 0.61s, accuracy: 95.08
# Epoch 37:	########################################	elapsed: 0.62s, accuracy: 94.81
# Epoch 38:	########################################	elapsed: 0.62s, accuracy: 95.43
# Epoch 39:	########################################	elapsed: 0.63s, accuracy: 95.66
# Epoch 40:	########################################	elapsed: 0.64s, accuracy: 95.89
# Epoch 41:	########################################	elapsed: 0.64s, accuracy: 95.58
# Epoch 42:	########################################	elapsed: 0.66s, accuracy: 95.71
# Epoch 43:	########################################	elapsed: 0.67s, accuracy: 95.79
# Epoch 44:	########################################	elapsed: 0.72s, accuracy: 95.81
# Epoch 45:	########################################	elapsed: 0.90s, accuracy: 95.84
# Epoch 46:	########################################	elapsed: 0.82s, accuracy: 95.88
# Epoch 47:	########################################	elapsed: 0.89s, accuracy: 95.90
# Epoch 48:	########################################	elapsed: 0.90s, accuracy: 95.90
# Epoch 49:	########################################	elapsed: 0.91s, accuracy: 95.88
# Epoch 50:	########################################	elapsed: 0.90s, accuracy: 95.89
# Epoch 51:	########################################	elapsed: 0.98s, accuracy: 95.89
# Epoch 52:	########################################	elapsed: 0.93s, accuracy: 95.91
# Epoch 53:	########################################	elapsed: 1.11s, accuracy: 95.90
# Epoch 54:	########################################	elapsed: 0.92s, accuracy: 95.89
# Epoch 55:	########################################	elapsed: 0.94s, accuracy: 95.89
# Epoch 56:	########################################	elapsed: 0.95s, accuracy: 95.91
# Epoch 57:	########################################	elapsed: 0.94s, accuracy: 95.94
# Epoch 58:	########################################	elapsed: 0.95s, accuracy: 95.95
# Epoch 59:	########################################	elapsed: 0.95s, accuracy: 95.95
# Epoch 60:	########################################	elapsed: 0.97s, accuracy: 95.94
# Epoch 61:	########################################	elapsed: 0.97s, accuracy: 95.93
# Epoch 62:	########################################	elapsed: 0.99s, accuracy: 95.94
# Epoch 63:	########################################	elapsed: 0.95s, accuracy: 95.93
# Epoch 64:	########################################	elapsed: 0.99s, accuracy: 95.92
# Epoch 65:	########################################	elapsed: 0.99s, accuracy: 95.92
# Epoch 66:	########################################	elapsed: 1.01s, accuracy: 95.91
# Epoch 67:	########################################	elapsed: 1.01s, accuracy: 95.91
# Epoch 68:	########################################	elapsed: 0.99s, accuracy: 95.91
# Epoch 69:	########################################	elapsed: 1.01s, accuracy: 95.91
# Epoch 70:	########################################	elapsed: 1.00s, accuracy: 95.91
# Epoch 71:	########################################	elapsed: 1.02s, accuracy: 95.91
# Epoch 72:	########################################	elapsed: 1.02s, accuracy: 95.91
# Epoch 73:	########################################	elapsed: 1.02s, accuracy: 95.89
# Epoch 74:	########################################	elapsed: 1.03s, accuracy: 95.89
# Epoch 75:	########################################	elapsed: 1.03s, accuracy: 95.88
# Epoch 76:	########################################	elapsed: 1.05s, accuracy: 95.88
# Epoch 77:	########################################	elapsed: 1.07s, accuracy: 95.88
# Epoch 78:	########################################	elapsed: 1.02s, accuracy: 95.88
# Epoch 79:	########################################	elapsed: 1.02s, accuracy: 95.88
# Epoch 80:	########################################	elapsed: 1.05s, accuracy: 95.88
# Epoch 81:	########################################	elapsed: 1.02s, accuracy: 95.87
# Epoch 82:	########################################	elapsed: 1.03s, accuracy: 95.87
# Epoch 83:	########################################	elapsed: 1.01s, accuracy: 95.87
# Epoch 84:	########################################	elapsed: 1.01s, accuracy: 95.87
# Epoch 85:	########################################	elapsed: 1.01s, accuracy: 95.87
# Epoch 86:	########################################	elapsed: 1.01s, accuracy: 95.87
# Epoch 87:	########################################	elapsed: 1.01s, accuracy: 95.86
# Epoch 88:	########################################	elapsed: 1.03s, accuracy: 95.86
# Epoch 89:	########################################	elapsed: 1.02s, accuracy: 95.86
# Epoch 90:	########################################	elapsed: 1.00s, accuracy: 95.86
# Epoch 91:	########################################	elapsed: 1.05s, accuracy: 95.86
# Epoch 92:	########################################	elapsed: 1.03s, accuracy: 95.87
# Epoch 93:	########################################	elapsed: 1.08s, accuracy: 95.87
# Epoch 94:	########################################	elapsed: 1.03s, accuracy: 95.87
# Epoch 95:	########################################	elapsed: 1.07s, accuracy: 95.88
# Epoch 96:	########################################	elapsed: 1.35s, accuracy: 95.88
# Epoch 97:	########################################	elapsed: 1.25s, accuracy: 95.88
# Epoch 98:	########################################	elapsed: 1.23s, accuracy: 95.89
# Epoch 99:	########################################	elapsed: 1.36s, accuracy: 95.89
# Epoch 100:	########################################	elapsed: 1.11s, accuracy: 95.89
# Epoch 101:	########################################	elapsed: 1.03s, accuracy: 95.89
# Epoch 102:	########################################	elapsed: 1.05s, accuracy: 95.89
# Epoch 103:	########################################	elapsed: 1.03s, accuracy: 95.89
# Epoch 104:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 105:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 106:	########################################	elapsed: 1.04s, accuracy: 95.91
# Epoch 107:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 108:	########################################	elapsed: 1.05s, accuracy: 95.90
# Epoch 109:	########################################	elapsed: 1.04s, accuracy: 95.89
# Epoch 110:	########################################	elapsed: 1.04s, accuracy: 95.89
# Epoch 111:	########################################	elapsed: 1.00s, accuracy: 95.89
# Epoch 112:	########################################	elapsed: 1.03s, accuracy: 95.89
# Epoch 113:	########################################	elapsed: 1.05s, accuracy: 95.89
# Epoch 114:	########################################	elapsed: 1.06s, accuracy: 95.90
# Epoch 115:	########################################	elapsed: 1.03s, accuracy: 95.90
# Epoch 116:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 117:	########################################	elapsed: 1.06s, accuracy: 95.90
# Epoch 118:	########################################	elapsed: 1.01s, accuracy: 95.90
# Epoch 119:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 120:	########################################	elapsed: 1.02s, accuracy: 95.90
# Epoch 121:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 122:	########################################	elapsed: 1.00s, accuracy: 95.90
# Epoch 123:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 124:	########################################	elapsed: 1.15s, accuracy: 95.90
# Epoch 125:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 126:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 127:	########################################	elapsed: 1.03s, accuracy: 95.90
# Epoch 128:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 129:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 130:	########################################	elapsed: 1.05s, accuracy: 95.89
# Epoch 131:	########################################	elapsed: 1.04s, accuracy: 95.89
# Epoch 132:	########################################	elapsed: 1.00s, accuracy: 95.90
# Epoch 133:	########################################	elapsed: 1.03s, accuracy: 95.90
# Epoch 134:	########################################	elapsed: 1.00s, accuracy: 95.90
# Epoch 135:	########################################	elapsed: 1.02s, accuracy: 95.91
# Epoch 136:	########################################	elapsed: 1.04s, accuracy: 95.91
# Epoch 137:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 138:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 139:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 140:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 141:	########################################	elapsed: 1.04s, accuracy: 95.91
# Epoch 142:	########################################	elapsed: 1.02s, accuracy: 95.91
# Epoch 143:	########################################	elapsed: 1.04s, accuracy: 95.91
# Epoch 144:	########################################	elapsed: 1.04s, accuracy: 95.91
# Epoch 145:	########################################	elapsed: 1.04s, accuracy: 95.91
# Epoch 146:	########################################	elapsed: 1.04s, accuracy: 95.91
# Epoch 147:	########################################	elapsed: 1.05s, accuracy: 95.91
# Epoch 148:	########################################	elapsed: 1.04s, accuracy: 95.91
# Epoch 149:	########################################	elapsed: 1.05s, accuracy: 95.90
# Epoch 150:	########################################	elapsed: 1.05s, accuracy: 95.90
# Epoch 151:	########################################	elapsed: 1.04s, accuracy: 95.91
# Epoch 152:	########################################	elapsed: 1.01s, accuracy: 95.91
# Epoch 153:	########################################	elapsed: 1.02s, accuracy: 95.91
# Epoch 154:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 155:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 156:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 157:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 158:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 159:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 160:	########################################	elapsed: 1.02s, accuracy: 95.90
# Epoch 161:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 162:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 163:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 164:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 165:	########################################	elapsed: 1.05s, accuracy: 95.90
# Epoch 166:	########################################	elapsed: 1.03s, accuracy: 95.90
# Epoch 167:	########################################	elapsed: 1.03s, accuracy: 95.90
# Epoch 168:	########################################	elapsed: 1.05s, accuracy: 95.90
# Epoch 169:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 170:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 171:	########################################	elapsed: 1.04s, accuracy: 95.90
# Epoch 172:	########################################	elapsed: 1.00s, accuracy: 95.90
# Epoch 173:	########################################	elapsed: 1.03s, accuracy: 95.90
# Epoch 174:	########################################	elapsed: 1.05s, accuracy: 95.91
# Epoch 175:	########################################	elapsed: 1.04s, accuracy: 95.91
# Epoch 176:	########################################	elapsed: 1.05s, accuracy: 95.91
# Epoch 177:	########################################	elapsed: 1.04s, accuracy: 95.91
# Epoch 178:	########################################	elapsed: 1.04s, accuracy: 95.91
# Epoch 179:	########################################	elapsed: 1.07s, accuracy: 95.91
# Epoch 180:	########################################	elapsed: 1.06s, accuracy: 95.91
# Epoch 181:	########################################	elapsed: 1.12s, accuracy: 95.91
# Epoch 182:	########################################	elapsed: 1.07s, accuracy: 95.91
# Epoch 183:	########################################	elapsed: 1.01s, accuracy: 95.91
# Epoch 184:	########################################	elapsed: 1.04s, accuracy: 95.91
# Epoch 185:	########################################	elapsed: 1.06s, accuracy: 95.91
# Epoch 186:	########################################	elapsed: 1.05s, accuracy: 95.91
# Epoch 187:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 188:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 189:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 190:	########################################	elapsed: 1.00s, accuracy: 95.91
# Epoch 191:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 192:	########################################	elapsed: 1.02s, accuracy: 95.91
# Epoch 193:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 194:	########################################	elapsed: 0.99s, accuracy: 95.91
# Epoch 195:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 196:	########################################	elapsed: 1.04s, accuracy: 95.91
# Epoch 197:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 198:	########################################	elapsed: 1.03s, accuracy: 95.91
# Epoch 199:	########################################	elapsed: 1.02s, accuracy: 95.91
# Epoch 200:	########################################	elapsed: 1.03s, accuracy: 95.91
# Training finished!
# <h3>Input layer filters in MLP</h3>
# <h3>Largest norms of weight-vectors in MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.72
# 	layer 3: 2.50

# %% [markdown]
# ### MLP with dropout

# %%
mlp_with_dropout = [
      Layer(
        visible_size=VISIBLE_LAYER_SIZE,
        hidden_size=HIDDEN_LAYER_SIZE,
        activation_fun=relu,
        d_activation_fun=relu_derivative,
        dropout_rate=0.2,
        learning_rate=MLP_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=2.0,
    ),
    Layer(
        visible_size=HIDDEN_LAYER_SIZE,
        hidden_size=HIDDEN_LAYER_SIZE,
        activation_fun=relu,
        d_activation_fun=relu_derivative,
        dropout_rate=0.2,
        learning_rate=MLP_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=1.0,
    ),
    Layer(
        visible_size=HIDDEN_LAYER_SIZE,
        hidden_size=10,
        activation_fun=softmax,
        d_activation_fun=None,
        dropout_rate=0.5,
        learning_rate=SOFTMAX_LEARNING_RATE,
        momentum=MOMENTUM,
        weight_limit=4.0,
    ),
]

evaluate(
      mlp=mlp_with_dropout, 
      train_set=mnist_train_images,
      train_labels=mnist_train_labels,
      validation_set=mnist_test_images,
      validation_labels=mnist_test_labels,
      batch_size=BATCH_SIZE,
      epochs_count=EPOCHS_COUNT,
)
# Out:
# <h3>MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.80s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 0.76s, accuracy: 11.35
# Epoch 3:	########################################	elapsed: 0.78s, accuracy: 11.35
# Epoch 4:	########################################	elapsed: 0.78s, accuracy: 11.35
# Epoch 5:	########################################	elapsed: 0.80s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 0.79s, accuracy: 49.44
# Epoch 7:	########################################	elapsed: 0.80s, accuracy: 83.93
# Epoch 8:	########################################	elapsed: 0.77s, accuracy: 88.24
# Epoch 9:	########################################	elapsed: 0.80s, accuracy: 89.08
# Epoch 10:	########################################	elapsed: 0.80s, accuracy: 91.85
# Epoch 11:	########################################	elapsed: 0.79s, accuracy: 93.11
# Epoch 12:	########################################	elapsed: 0.76s, accuracy: 93.61
# Epoch 13:	########################################	elapsed: 0.80s, accuracy: 93.28
# Epoch 14:	########################################	elapsed: 0.78s, accuracy: 94.71
# Epoch 15:	########################################	elapsed: 0.79s, accuracy: 94.42
# Epoch 16:	########################################	elapsed: 0.78s, accuracy: 94.02
# Epoch 17:	########################################	elapsed: 0.78s, accuracy: 94.85
# Epoch 18:	########################################	elapsed: 0.78s, accuracy: 94.47
# Epoch 19:	########################################	elapsed: 0.79s, accuracy: 95.05
# Epoch 20:	########################################	elapsed: 0.77s, accuracy: 94.83
# Epoch 21:	########################################	elapsed: 0.79s, accuracy: 95.26
# Epoch 22:	########################################	elapsed: 0.78s, accuracy: 95.30
# Epoch 23:	########################################	elapsed: 0.79s, accuracy: 94.72
# Epoch 24:	########################################	elapsed: 0.79s, accuracy: 95.69
# Epoch 25:	########################################	elapsed: 0.79s, accuracy: 95.65
# Epoch 26:	########################################	elapsed: 0.78s, accuracy: 96.05
# Epoch 27:	########################################	elapsed: 0.79s, accuracy: 95.30
# Epoch 28:	########################################	elapsed: 0.79s, accuracy: 95.87
# Epoch 29:	########################################	elapsed: 0.80s, accuracy: 95.52
# Epoch 30:	########################################	elapsed: 0.79s, accuracy: 95.84
# Epoch 31:	########################################	elapsed: 0.79s, accuracy: 95.88
# Epoch 32:	########################################	elapsed: 0.79s, accuracy: 96.05
# Epoch 33:	########################################	elapsed: 0.80s, accuracy: 96.02
# Epoch 34:	########################################	elapsed: 0.86s, accuracy: 95.84
# Epoch 35:	########################################	elapsed: 0.79s, accuracy: 95.69
# Epoch 36:	########################################	elapsed: 0.86s, accuracy: 95.73
# Epoch 37:	########################################	elapsed: 0.80s, accuracy: 96.04
# Epoch 38:	########################################	elapsed: 0.82s, accuracy: 95.81
# Epoch 39:	########################################	elapsed: 0.84s, accuracy: 96.16
# Epoch 40:	########################################	elapsed: 0.79s, accuracy: 95.81
# Epoch 41:	########################################	elapsed: 1.10s, accuracy: 96.13
# Epoch 42:	########################################	elapsed: 0.82s, accuracy: 95.81
# Epoch 43:	########################################	elapsed: 0.81s, accuracy: 95.87
# Epoch 44:	########################################	elapsed: 0.84s, accuracy: 96.17
# Epoch 45:	########################################	elapsed: 0.85s, accuracy: 96.31
# Epoch 46:	########################################	elapsed: 0.86s, accuracy: 96.25
# Epoch 47:	########################################	elapsed: 0.90s, accuracy: 96.24
# Epoch 48:	########################################	elapsed: 0.91s, accuracy: 96.24
# Epoch 49:	########################################	elapsed: 1.02s, accuracy: 96.43
# Epoch 50:	########################################	elapsed: 0.91s, accuracy: 96.44
# Epoch 51:	########################################	elapsed: 0.91s, accuracy: 96.22
# Epoch 52:	########################################	elapsed: 0.93s, accuracy: 96.13
# Epoch 53:	########################################	elapsed: 0.92s, accuracy: 95.96
# Epoch 54:	########################################	elapsed: 0.91s, accuracy: 96.12
# Epoch 55:	########################################	elapsed: 0.92s, accuracy: 96.22
# Epoch 56:	########################################	elapsed: 0.93s, accuracy: 96.15
# Epoch 57:	########################################	elapsed: 0.93s, accuracy: 96.26
# Epoch 58:	########################################	elapsed: 0.92s, accuracy: 96.49
# Epoch 59:	########################################	elapsed: 0.92s, accuracy: 96.25
# Epoch 60:	########################################	elapsed: 0.87s, accuracy: 95.87
# Epoch 61:	########################################	elapsed: 0.99s, accuracy: 96.10
# Epoch 62:	########################################	elapsed: 0.89s, accuracy: 96.00
# Epoch 63:	########################################	elapsed: 0.90s, accuracy: 96.35
# Epoch 64:	########################################	elapsed: 0.87s, accuracy: 95.91
# Epoch 65:	########################################	elapsed: 0.91s, accuracy: 95.98
# Epoch 66:	########################################	elapsed: 0.89s, accuracy: 96.12
# Epoch 67:	########################################	elapsed: 0.91s, accuracy: 96.17
# Epoch 68:	########################################	elapsed: 0.88s, accuracy: 96.10
# Epoch 69:	########################################	elapsed: 0.90s, accuracy: 96.36
# Epoch 70:	########################################	elapsed: 0.91s, accuracy: 95.70
# Epoch 71:	########################################	elapsed: 0.90s, accuracy: 96.22
# Epoch 72:	########################################	elapsed: 0.88s, accuracy: 96.66
# Epoch 73:	########################################	elapsed: 0.93s, accuracy: 96.54
# Epoch 74:	########################################	elapsed: 0.93s, accuracy: 96.18
# Epoch 75:	########################################	elapsed: 1.11s, accuracy: 96.28
# Epoch 76:	########################################	elapsed: 0.93s, accuracy: 96.36
# Epoch 77:	########################################	elapsed: 0.90s, accuracy: 96.31
# Epoch 78:	########################################	elapsed: 1.09s, accuracy: 96.37
# Epoch 79:	########################################	elapsed: 1.12s, accuracy: 96.21
# Epoch 80:	########################################	elapsed: 0.93s, accuracy: 96.11
# Epoch 81:	########################################	elapsed: 0.91s, accuracy: 95.77
# Epoch 82:	########################################	elapsed: 0.91s, accuracy: 96.28
# Epoch 83:	########################################	elapsed: 0.91s, accuracy: 96.30
# Epoch 84:	########################################	elapsed: 0.88s, accuracy: 96.34
# Epoch 85:	########################################	elapsed: 0.92s, accuracy: 96.24
# Epoch 86:	########################################	elapsed: 0.92s, accuracy: 95.53
# Epoch 87:	########################################	elapsed: 0.91s, accuracy: 96.28
# Epoch 88:	########################################	elapsed: 0.87s, accuracy: 96.34
# Epoch 89:	########################################	elapsed: 0.91s, accuracy: 96.46
# Epoch 90:	########################################	elapsed: 0.90s, accuracy: 96.20
# Epoch 91:	########################################	elapsed: 0.92s, accuracy: 96.36
# Epoch 92:	########################################	elapsed: 0.88s, accuracy: 96.47
# Epoch 93:	########################################	elapsed: 0.93s, accuracy: 96.37
# Epoch 94:	########################################	elapsed: 0.91s, accuracy: 96.35
# Epoch 95:	########################################	elapsed: 0.92s, accuracy: 96.36
# Epoch 96:	########################################	elapsed: 0.89s, accuracy: 96.40
# Epoch 97:	########################################	elapsed: 0.92s, accuracy: 96.34
# Epoch 98:	########################################	elapsed: 0.91s, accuracy: 96.35
# Epoch 99:	########################################	elapsed: 0.91s, accuracy: 96.28
# Epoch 100:	########################################	elapsed: 0.88s, accuracy: 96.29
# Epoch 101:	########################################	elapsed: 0.92s, accuracy: 96.53
# Epoch 102:	########################################	elapsed: 0.92s, accuracy: 96.36
# Epoch 103:	########################################	elapsed: 0.91s, accuracy: 96.29
# Epoch 104:	########################################	elapsed: 0.87s, accuracy: 96.15
# Epoch 105:	########################################	elapsed: 0.91s, accuracy: 96.46
# Epoch 106:	########################################	elapsed: 0.91s, accuracy: 96.49
# Epoch 107:	########################################	elapsed: 0.91s, accuracy: 96.44
# Epoch 108:	########################################	elapsed: 0.87s, accuracy: 96.60
# Epoch 109:	########################################	elapsed: 0.90s, accuracy: 96.35
# Epoch 110:	########################################	elapsed: 0.92s, accuracy: 96.59
# Epoch 111:	########################################	elapsed: 0.92s, accuracy: 96.35
# Epoch 112:	########################################	elapsed: 0.89s, accuracy: 96.43
# Epoch 113:	########################################	elapsed: 0.91s, accuracy: 96.19
# Epoch 114:	########################################	elapsed: 0.91s, accuracy: 96.43
# Epoch 115:	########################################	elapsed: 0.91s, accuracy: 96.47
# Epoch 116:	########################################	elapsed: 0.88s, accuracy: 96.26
# Epoch 117:	########################################	elapsed: 0.91s, accuracy: 96.39
# Epoch 118:	########################################	elapsed: 0.92s, accuracy: 96.47
# Epoch 119:	########################################	elapsed: 0.93s, accuracy: 96.67
# Epoch 120:	########################################	elapsed: 0.87s, accuracy: 96.68
# Epoch 121:	########################################	elapsed: 0.91s, accuracy: 96.60
# Epoch 122:	########################################	elapsed: 0.91s, accuracy: 96.35
# Epoch 123:	########################################	elapsed: 0.94s, accuracy: 96.47
# Epoch 124:	########################################	elapsed: 0.87s, accuracy: 96.49
# Epoch 125:	########################################	elapsed: 0.91s, accuracy: 96.46
# Epoch 126:	########################################	elapsed: 0.90s, accuracy: 96.32
# Epoch 127:	########################################	elapsed: 0.92s, accuracy: 96.50
# Epoch 128:	########################################	elapsed: 0.88s, accuracy: 96.00
# Epoch 129:	########################################	elapsed: 0.91s, accuracy: 96.70
# Epoch 130:	########################################	elapsed: 0.91s, accuracy: 96.48
# Epoch 131:	########################################	elapsed: 0.91s, accuracy: 96.44
# Epoch 132:	########################################	elapsed: 0.87s, accuracy: 96.60
# Epoch 133:	########################################	elapsed: 0.93s, accuracy: 96.44
# Epoch 134:	########################################	elapsed: 0.90s, accuracy: 96.58
# Epoch 135:	########################################	elapsed: 0.91s, accuracy: 96.40
# Epoch 136:	########################################	elapsed: 0.89s, accuracy: 96.60
# Epoch 137:	########################################	elapsed: 0.92s, accuracy: 96.54
# Epoch 138:	########################################	elapsed: 0.91s, accuracy: 96.44
# Epoch 139:	########################################	elapsed: 0.90s, accuracy: 96.69
# Epoch 140:	########################################	elapsed: 0.87s, accuracy: 96.41
# Epoch 141:	########################################	elapsed: 0.91s, accuracy: 96.34
# Epoch 142:	########################################	elapsed: 0.95s, accuracy: 96.68
# Epoch 143:	########################################	elapsed: 0.93s, accuracy: 96.68
# Epoch 144:	########################################	elapsed: 0.89s, accuracy: 96.62
# Epoch 145:	########################################	elapsed: 0.93s, accuracy: 96.64
# Epoch 146:	########################################	elapsed: 0.91s, accuracy: 96.55
# Epoch 147:	########################################	elapsed: 0.91s, accuracy: 96.61
# Epoch 148:	########################################	elapsed: 0.87s, accuracy: 96.49
# Epoch 149:	########################################	elapsed: 0.91s, accuracy: 96.48
# Epoch 150:	########################################	elapsed: 0.92s, accuracy: 96.21
# Epoch 151:	########################################	elapsed: 0.91s, accuracy: 96.69
# Epoch 152:	########################################	elapsed: 0.89s, accuracy: 96.59
# Epoch 153:	########################################	elapsed: 0.93s, accuracy: 96.55
# Epoch 154:	########################################	elapsed: 0.91s, accuracy: 96.35
# Epoch 155:	########################################	elapsed: 0.91s, accuracy: 96.71
# Epoch 156:	########################################	elapsed: 0.87s, accuracy: 96.77
# Epoch 157:	########################################	elapsed: 1.14s, accuracy: 96.77
# Epoch 158:	########################################	elapsed: 1.20s, accuracy: 96.85
# Epoch 159:	########################################	elapsed: 1.25s, accuracy: 96.74
# Epoch 160:	########################################	elapsed: 0.88s, accuracy: 96.69
# Epoch 161:	########################################	elapsed: 0.93s, accuracy: 96.67
# Epoch 162:	########################################	elapsed: 0.93s, accuracy: 96.73
# Epoch 163:	########################################	elapsed: 0.92s, accuracy: 96.52
# Epoch 164:	########################################	elapsed: 0.88s, accuracy: 96.65
# Epoch 165:	########################################	elapsed: 0.91s, accuracy: 96.71
# Epoch 166:	########################################	elapsed: 0.91s, accuracy: 96.61
# Epoch 167:	########################################	elapsed: 0.92s, accuracy: 96.84
# Epoch 168:	########################################	elapsed: 0.93s, accuracy: 96.75
# Epoch 169:	########################################	elapsed: 0.95s, accuracy: 96.88
# Epoch 170:	########################################	elapsed: 0.93s, accuracy: 96.78
# Epoch 171:	########################################	elapsed: 0.93s, accuracy: 96.66
# Epoch 172:	########################################	elapsed: 0.89s, accuracy: 96.79
# Epoch 173:	########################################	elapsed: 0.93s, accuracy: 96.88
# Epoch 174:	########################################	elapsed: 0.92s, accuracy: 96.85
# Epoch 175:	########################################	elapsed: 0.92s, accuracy: 96.89
# Epoch 176:	########################################	elapsed: 0.90s, accuracy: 96.82
# Epoch 177:	########################################	elapsed: 0.92s, accuracy: 96.87
# Epoch 178:	########################################	elapsed: 0.93s, accuracy: 96.87
# Epoch 179:	########################################	elapsed: 0.92s, accuracy: 96.87
# Epoch 180:	########################################	elapsed: 0.98s, accuracy: 96.88
# Epoch 181:	########################################	elapsed: 0.92s, accuracy: 96.86
# Epoch 182:	########################################	elapsed: 1.03s, accuracy: 96.86
# Epoch 183:	########################################	elapsed: 0.93s, accuracy: 96.84
# Epoch 184:	########################################	elapsed: 0.89s, accuracy: 96.87
# Epoch 185:	########################################	elapsed: 0.92s, accuracy: 96.84
# Epoch 186:	########################################	elapsed: 0.93s, accuracy: 96.86
# Epoch 187:	########################################	elapsed: 0.94s, accuracy: 96.87
# Epoch 188:	########################################	elapsed: 0.90s, accuracy: 96.87
# Epoch 189:	########################################	elapsed: 0.94s, accuracy: 96.89
# Epoch 190:	########################################	elapsed: 0.93s, accuracy: 96.84
# Epoch 191:	########################################	elapsed: 0.94s, accuracy: 96.83
# Epoch 192:	########################################	elapsed: 0.90s, accuracy: 96.84
# Epoch 193:	########################################	elapsed: 0.95s, accuracy: 96.82
# Epoch 194:	########################################	elapsed: 0.93s, accuracy: 96.84
# Epoch 195:	########################################	elapsed: 0.94s, accuracy: 96.82
# Epoch 196:	########################################	elapsed: 0.90s, accuracy: 96.86
# Epoch 197:	########################################	elapsed: 0.93s, accuracy: 96.82
# Epoch 198:	########################################	elapsed: 0.94s, accuracy: 96.83
# Epoch 199:	########################################	elapsed: 0.96s, accuracy: 96.86
# Epoch 200:	########################################	elapsed: 0.91s, accuracy: 96.87
# Training finished!
# <h3>Input layer filters in MLP</h3>
# <h3>Largest norms of weight-vectors in MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 2.00
# 	layer 3: 2.50
