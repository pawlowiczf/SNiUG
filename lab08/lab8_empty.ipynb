# %%
import numpy as np
import matplotlib.pyplot as plt
import time

np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(x: np.ndarray) -> np.ndarray:
    max_z = np.max(x, axis=1, keepdims=True)
    x = x - max_z
    exp_x = np.exp(x)

    sum_z = np.sum(exp_x, axis=1, keepdims=True)
    return exp_x / sum_z

# %% [markdown]
# # MNIST dataset

# %%
from mnists import MNIST

mnist = MNIST()

PREVIEW_N_ROWS = 12
PREVIEW_N_COLS = 24
TILE_DIM = 28  # [px]

def create_mnist_digits(n_rows: int, n_cols: int, tile_dim: int) -> np.ndarray:
    shape = (n_rows, n_cols, tile_dim, tile_dim)
    return np.reshape(mnist.train_images()[: 12 * 24], newshape=shape)

mnist_digits = create_mnist_digits(PREVIEW_N_ROWS, PREVIEW_N_COLS, TILE_DIM)

tiles(mnist_digits)

# %% [markdown]
# # ReLU and Max-Norm regularization

# %%
def relu(batch, stochastic=False):
    if stochastic:
        noise = np.random.randn(*batch.shape).astype(np.float32) * np.sqrt(sigmoid(batch))
        return np.maximum(0, batch + noise)
    return np.maximum(0, batch)

def relu_derivative(batch):
    return (batch > 0).astype(float)

# %%
def limit_weights(weights, limit: float):
    if limit == 0:
        return weights

    norm = np.linalg.norm(weights, ord=2, axis=0)
    scale = np.where(norm > limit, limit / norm, 1.0)
    return weights * scale

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    rbm.W += rbm.M

    if rbm.weight_limit > 0.0:
        rbm.W[:-1, :-1] = limit_weights(rbm.W[:-1, :-1], rbm.weight_limit)

def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] =  rbm.hidden_act_func(minibatch @ rbm.W[:, :-1], stochastic=True)
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))

    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count

    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(dbn[i].hidden_act_func(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(dbn[i].visible_act_func(hidden @ dbn[i].W[:-1, :].T))
    return hidden

def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    return reconstuction_error(dbn[layer_idx], propagated)

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)

    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

def run_dbn_training(dbn, dataset, monitoring_set, batch_size, epochs_count, target_momentum=0.9):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx+1))

        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = target_momentum

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun,
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size

        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun

        self.learning_rate = learning_rate
        self.momentum = momentum

        self.weight_limit = weight_limit

        self.reset()

    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0

        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp, batch: np.ndarray, compute_derivatives: bool) -> np.ndarray:
    visible = batch

    for layer_idx, layer in enumerate(mlp):
        z = visible @ layer.W
        layer.activations = layer.activation_fun(z)

        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)

        visible = layer.activations
        visible = append_ones(visible)

    return visible[:, :-1]
#

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch: np.ndarray) -> None:
    observations_count = batch.shape[0]

    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = append_ones(prev_layer.activations)

            error = layer.deltas @ layer.W[:-1, :].T
            prev_layer.deltas = error * prev_layer.d_activations
        else:
            visible = batch

        gradient = visible.T @ layer.deltas / observations_count
        layer.M = layer.momentum * layer.M + layer.learning_rate * gradient
        layer.W -= layer.M
#

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(
    mlp, dataset: np.ndarray, labels: np.ndarray, batch_size: np.ndarray
) -> None:
    batches_limit = dataset.shape[0] / batch_size

    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)

    for batch_idx, (batch, batch_labels) in enumerate(
        zip(batched_data, batched_labels)
    ):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)

        # implement the deltas for the last layer (i.e. the loss function)
        mlp[-1].deltas = y - batch_labels

        error_backpropagate(mlp, batch)

        if batch_idx % round(batches_limit / 50) == 0:
            print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count, target_momentum=0.95):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")

        if epoch == 5:
            for layer in mlp: layer.momentum = target_momentum

        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# #  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
# Protip for better encpaulsation: create a helper class for MLP, with a custom constructor (@classmethod), `from_dbn(dbn: DBN)`
# However, there is no need for overengineering for this laboratories.

def initialize_mlp_from_dbn(mlp, dbn) -> None:
    for layer_idx in range(len(dbn)):
        mlp[layer_idx].W = np.copy(dbn[layer_idx].W[:, :-1])

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

MLP_LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
RBM_LEARNING_RATE = 0.003
MOMENTUM = 0.5

# %% [markdown]
# ### Plain vs pretrained comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)

    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])

    display(HTML('<h3>Largest norms of weight-vectors in the plain MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

    display(HTML('<h3>DBN training</h3>'))
    run_dbn_training(dbn, train_set, monitoring_set, batch_size, epochs_count)

    for layer in mlp:
        layer.reset()

    initialize_mlp_from_dbn(mlp, dbn)

    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)

    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])

    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

    display(HTML('<h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Shallow ReLU network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

shallow_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.51s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 0.53s, accuracy: 31.54
# Epoch 3:	########################################	elapsed: 0.53s, accuracy: 65.26
# Epoch 4:	########################################	elapsed: 0.50s, accuracy: 74.15
# Epoch 5:	########################################	elapsed: 0.52s, accuracy: 80.37
# Epoch 6:	########################################	elapsed: 0.51s, accuracy: 89.79
# Epoch 7:	########################################	elapsed: 0.48s, accuracy: 92.37
# Epoch 8:	########################################	elapsed: 0.50s, accuracy: 93.13
# Epoch 9:	########################################	elapsed: 0.51s, accuracy: 93.87
# Epoch 10:	########################################	elapsed: 0.69s, accuracy: 94.58
# Epoch 11:	########################################	elapsed: 0.50s, accuracy: 94.09
# Epoch 12:	########################################	elapsed: 0.49s, accuracy: 94.94
# Epoch 13:	########################################	elapsed: 0.49s, accuracy: 95.10
# Epoch 14:	########################################	elapsed: 0.49s, accuracy: 95.63
# Epoch 15:	########################################	elapsed: 0.47s, accuracy: 95.26
# Epoch 16:	########################################	elapsed: 0.50s, accuracy: 94.96
# Epoch 17:	########################################	elapsed: 0.49s, accuracy: 95.34
# Epoch 18:	########################################	elapsed: 0.50s, accuracy: 95.08
# Epoch 19:	########################################	elapsed: 0.49s, accuracy: 95.73
# Epoch 20:	########################################	elapsed: 0.48s, accuracy: 95.05
# Epoch 21:	########################################	elapsed: 0.51s, accuracy: 95.58
# Epoch 22:	########################################	elapsed: 0.49s, accuracy: 95.46
# Epoch 23:	########################################	elapsed: 0.49s, accuracy: 95.92
# Epoch 24:	########################################	elapsed: 0.48s, accuracy: 95.97
# Epoch 25:	########################################	elapsed: 0.51s, accuracy: 96.23
# Epoch 26:	########################################	elapsed: 0.49s, accuracy: 96.55
# Epoch 27:	########################################	elapsed: 0.49s, accuracy: 96.43
# Epoch 28:	########################################	elapsed: 0.48s, accuracy: 96.51
# Epoch 29:	########################################	elapsed: 0.49s, accuracy: 96.49
# Epoch 30:	########################################	elapsed: 0.48s, accuracy: 96.45
# Epoch 31:	########################################	elapsed: 0.48s, accuracy: 96.46
# Epoch 32:	########################################	elapsed: 0.49s, accuracy: 96.47
# Epoch 33:	########################################	elapsed: 0.49s, accuracy: 96.47
# Epoch 34:	########################################	elapsed: 0.49s, accuracy: 96.47
# Epoch 35:	########################################	elapsed: 0.49s, accuracy: 96.48
# Epoch 36:	########################################	elapsed: 0.48s, accuracy: 96.48
# Epoch 37:	########################################	elapsed: 0.48s, accuracy: 96.45
# Epoch 38:	########################################	elapsed: 0.49s, accuracy: 96.46
# Epoch 39:	########################################	elapsed: 0.53s, accuracy: 96.46
# Epoch 40:	########################################	elapsed: 0.52s, accuracy: 96.46
# Epoch 41:	########################################	elapsed: 0.49s, accuracy: 96.47
# Epoch 42:	########################################	elapsed: 0.53s, accuracy: 96.48
# Epoch 43:	########################################	elapsed: 0.48s, accuracy: 96.49
# Epoch 44:	########################################	elapsed: 0.56s, accuracy: 96.49
# Epoch 45:	########################################	elapsed: 0.53s, accuracy: 96.49
# Epoch 46:	########################################	elapsed: 0.62s, accuracy: 96.49
# Epoch 47:	########################################	elapsed: 0.53s, accuracy: 96.51
# Epoch 48:	########################################	elapsed: 0.59s, accuracy: 96.52
# Epoch 49:	########################################	elapsed: 0.50s, accuracy: 96.50
# Epoch 50:	########################################	elapsed: 0.50s, accuracy: 96.51
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 1.85
# 	layer 2: 1.20
# 	layer 3: 5.46
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.44s, reconstruction error: 75.37
# Epoch 2:	########################################	elapsed: 0.46s, reconstruction error: 54.89
# Epoch 3:	########################################	elapsed: 0.43s, reconstruction error: 42.84
# Epoch 4:	########################################	elapsed: 0.41s, reconstruction error: 36.50
# Epoch 5:	########################################	elapsed: 0.38s, reconstruction error: 32.70
# Epoch 6:	########################################	elapsed: 0.41s, reconstruction error: 24.95
# Epoch 7:	########################################	elapsed: 0.37s, reconstruction error: 20.96
# Epoch 8:	########################################	elapsed: 0.37s, reconstruction error: 18.61
# Epoch 9:	########################################	elapsed: 0.37s, reconstruction error: 16.90
# Epoch 10:	########################################	elapsed: 0.36s, reconstruction error: 15.65
# Epoch 11:	########################################	elapsed: 0.35s, reconstruction error: 14.76
# Epoch 12:	########################################	elapsed: 0.38s, reconstruction error: 13.84
# Epoch 13:	########################################	elapsed: 0.38s, reconstruction error: 13.17
# Epoch 14:	########################################	elapsed: 0.37s, reconstruction error: 12.52
# Epoch 15:	########################################	elapsed: 0.37s, reconstruction error: 11.90
# Epoch 16:	########################################	elapsed: 0.37s, reconstruction error: 11.46
# Epoch 17:	########################################	elapsed: 0.38s, reconstruction error: 11.20
# Epoch 18:	########################################	elapsed: 0.38s, reconstruction error: 10.66
# Epoch 19:	########################################	elapsed: 0.39s, reconstruction error: 10.41
# Epoch 20:	########################################	elapsed: 0.39s, reconstruction error: 10.23
# Epoch 21:	########################################	elapsed: 0.40s, reconstruction error: 9.85
# Epoch 22:	########################################	elapsed: 0.40s, reconstruction error: 9.59
# Epoch 23:	########################################	elapsed: 0.39s, reconstruction error: 9.49
# Epoch 24:	########################################	elapsed: 0.40s, reconstruction error: 9.35
# Epoch 25:	########################################	elapsed: 0.38s, reconstruction error: 9.29
# Epoch 26:	########################################	elapsed: 0.40s, reconstruction error: 9.10
# Epoch 27:	########################################	elapsed: 0.40s, reconstruction error: 8.92
# Epoch 28:	########################################	elapsed: 0.40s, reconstruction error: 8.84
# Epoch 29:	########################################	elapsed: 0.38s, reconstruction error: 8.81
# Epoch 30:	########################################	elapsed: 0.37s, reconstruction error: 8.68
# Epoch 31:	########################################	elapsed: 0.37s, reconstruction error: 8.53
# Epoch 32:	########################################	elapsed: 0.40s, reconstruction error: 8.57
# Epoch 33:	########################################	elapsed: 0.39s, reconstruction error: 8.51
# Epoch 34:	########################################	elapsed: 0.37s, reconstruction error: 8.50
# Epoch 35:	########################################	elapsed: 0.41s, reconstruction error: 8.46
# Epoch 36:	########################################	elapsed: 0.38s, reconstruction error: 8.54
# Epoch 37:	########################################	elapsed: 0.41s, reconstruction error: 8.36
# Epoch 38:	########################################	elapsed: 0.39s, reconstruction error: 8.30
# Epoch 39:	########################################	elapsed: 0.56s, reconstruction error: 8.25
# Epoch 40:	########################################	elapsed: 0.47s, reconstruction error: 8.18
# Epoch 41:	########################################	elapsed: 0.39s, reconstruction error: 8.20
# Epoch 42:	########################################	elapsed: 0.39s, reconstruction error: 8.20
# Epoch 43:	########################################	elapsed: 0.61s, reconstruction error: 8.20
# Epoch 44:	########################################	elapsed: 0.38s, reconstruction error: 8.13
# Epoch 45:	########################################	elapsed: 0.39s, reconstruction error: 8.13
# Epoch 46:	########################################	elapsed: 0.38s, reconstruction error: 8.11
# Epoch 47:	########################################	elapsed: 0.38s, reconstruction error: 8.02
# Epoch 48:	########################################	elapsed: 0.38s, reconstruction error: 7.99
# Epoch 49:	########################################	elapsed: 0.39s, reconstruction error: 8.00
# Epoch 50:	########################################	elapsed: 0.38s, reconstruction error: 7.87
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.28s, reconstruction error: 118.32
# Epoch 2:	########################################	elapsed: 0.29s, reconstruction error: 76.57
# Epoch 3:	########################################	elapsed: 0.29s, reconstruction error: 62.66
# Epoch 4:	########################################	elapsed: 0.28s, reconstruction error: 53.02
# Epoch 5:	########################################	elapsed: 0.29s, reconstruction error: 49.13
# Epoch 6:	########################################	elapsed: 0.28s, reconstruction error: 48.96
# Epoch 7:	########################################	elapsed: 0.29s, reconstruction error: 46.36
# Epoch 8:	########################################	elapsed: 0.28s, reconstruction error: 43.81
# Epoch 9:	########################################	elapsed: 0.28s, reconstruction error: 43.65
# Epoch 10:	########################################	elapsed: 0.30s, reconstruction error: 40.88
# Epoch 11:	########################################	elapsed: 0.32s, reconstruction error: 39.06
# Epoch 12:	########################################	elapsed: 0.28s, reconstruction error: 38.75
# Epoch 13:	########################################	elapsed: 0.28s, reconstruction error: 40.23
# Epoch 14:	########################################	elapsed: 0.29s, reconstruction error: 37.55
# Epoch 15:	########################################	elapsed: 0.28s, reconstruction error: 36.62
# Epoch 16:	########################################	elapsed: 0.29s, reconstruction error: 36.54
# Epoch 17:	########################################	elapsed: 0.28s, reconstruction error: 34.24
# Epoch 18:	########################################	elapsed: 0.29s, reconstruction error: 36.32
# Epoch 19:	########################################	elapsed: 0.29s, reconstruction error: 35.90
# Epoch 20:	########################################	elapsed: 0.31s, reconstruction error: 34.25
# Epoch 21:	########################################	elapsed: 0.39s, reconstruction error: 34.65
# Epoch 22:	########################################	elapsed: 0.28s, reconstruction error: 34.75
# Epoch 23:	########################################	elapsed: 0.29s, reconstruction error: 34.21
# Epoch 24:	########################################	elapsed: 0.27s, reconstruction error: 35.79
# Epoch 25:	########################################	elapsed: 0.29s, reconstruction error: 34.40
# Epoch 26:	########################################	elapsed: 0.29s, reconstruction error: 34.89
# Epoch 27:	########################################	elapsed: 0.27s, reconstruction error: 32.91
# Epoch 28:	########################################	elapsed: 0.39s, reconstruction error: 33.25
# Epoch 29:	########################################	elapsed: 0.28s, reconstruction error: 33.36
# Epoch 30:	########################################	elapsed: 0.28s, reconstruction error: 33.17
# Epoch 31:	########################################	elapsed: 0.29s, reconstruction error: 33.52
# Epoch 32:	########################################	elapsed: 0.28s, reconstruction error: 32.75
# Epoch 33:	########################################	elapsed: 0.29s, reconstruction error: 33.21
# Epoch 34:	########################################	elapsed: 0.29s, reconstruction error: 34.10
# Epoch 35:	########################################	elapsed: 0.28s, reconstruction error: 33.76
# Epoch 36:	########################################	elapsed: 0.29s, reconstruction error: 32.18
# Epoch 37:	########################################	elapsed: 0.28s, reconstruction error: 32.51
# Epoch 38:	########################################	elapsed: 0.28s, reconstruction error: 33.21
# Epoch 39:	########################################	elapsed: 0.28s, reconstruction error: 32.84
# Epoch 40:	########################################	elapsed: 0.29s, reconstruction error: 32.87
# Epoch 41:	########################################	elapsed: 0.34s, reconstruction error: 32.56
# Epoch 42:	########################################	elapsed: 0.28s, reconstruction error: 33.57
# Epoch 43:	########################################	elapsed: 0.29s, reconstruction error: 32.42
# Epoch 44:	########################################	elapsed: 0.29s, reconstruction error: 32.17
# Epoch 45:	########################################	elapsed: 0.29s, reconstruction error: 33.01
# Epoch 46:	########################################	elapsed: 0.29s, reconstruction error: 34.98
# Epoch 47:	########################################	elapsed: 0.30s, reconstruction error: 32.96
# Epoch 48:	########################################	elapsed: 0.30s, reconstruction error: 32.96
# Epoch 49:	########################################	elapsed: 0.29s, reconstruction error: 32.10
# Epoch 50:	########################################	elapsed: 0.30s, reconstruction error: 32.55
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.49s, accuracy: 93.18
# Epoch 2:	########################################	elapsed: 0.47s, accuracy: 95.15
# Epoch 3:	########################################	elapsed: 0.49s, accuracy: 96.37
# Epoch 4:	########################################	elapsed: 0.48s, accuracy: 96.26
# Epoch 5:	########################################	elapsed: 0.48s, accuracy: 96.75
# Epoch 6:	########################################	elapsed: 0.47s, accuracy: 96.83
# Epoch 7:	########################################	elapsed: 0.52s, accuracy: 96.81
# Epoch 8:	########################################	elapsed: 0.48s, accuracy: 97.04
# Epoch 9:	########################################	elapsed: 0.49s, accuracy: 97.21
# Epoch 10:	########################################	elapsed: 0.47s, accuracy: 97.30
# Epoch 11:	########################################	elapsed: 0.52s, accuracy: 97.35
# Epoch 12:	########################################	elapsed: 0.48s, accuracy: 97.45
# Epoch 13:	########################################	elapsed: 0.48s, accuracy: 97.47
# Epoch 14:	########################################	elapsed: 0.49s, accuracy: 97.43
# Epoch 15:	########################################	elapsed: 0.48s, accuracy: 97.41
# Epoch 16:	########################################	elapsed: 0.48s, accuracy: 97.43
# Epoch 17:	########################################	elapsed: 0.47s, accuracy: 97.42
# Epoch 18:	########################################	elapsed: 0.49s, accuracy: 97.40
# Epoch 19:	########################################	elapsed: 0.47s, accuracy: 97.41
# Epoch 20:	########################################	elapsed: 0.51s, accuracy: 97.42
# Epoch 21:	########################################	elapsed: 0.61s, accuracy: 97.41
# Epoch 22:	########################################	elapsed: 0.68s, accuracy: 97.40
# Epoch 23:	########################################	elapsed: 0.47s, accuracy: 97.42
# Epoch 24:	########################################	elapsed: 0.50s, accuracy: 97.41
# Epoch 25:	########################################	elapsed: 0.50s, accuracy: 97.39
# Epoch 26:	########################################	elapsed: 0.48s, accuracy: 97.40
# Epoch 27:	########################################	elapsed: 0.48s, accuracy: 97.40
# Epoch 28:	########################################	elapsed: 0.49s, accuracy: 97.39
# Epoch 29:	########################################	elapsed: 0.48s, accuracy: 97.39
# Epoch 30:	########################################	elapsed: 0.48s, accuracy: 97.39
# Epoch 31:	########################################	elapsed: 0.49s, accuracy: 97.40
# Epoch 32:	########################################	elapsed: 0.55s, accuracy: 97.39
# Epoch 33:	########################################	elapsed: 0.48s, accuracy: 97.39
# Epoch 34:	########################################	elapsed: 0.49s, accuracy: 97.39
# Epoch 35:	########################################	elapsed: 0.49s, accuracy: 97.39
# Epoch 36:	########################################	elapsed: 0.48s, accuracy: 97.39
# Epoch 37:	########################################	elapsed: 0.49s, accuracy: 97.39
# Epoch 38:	########################################	elapsed: 0.50s, accuracy: 97.39
# Epoch 39:	########################################	elapsed: 0.46s, accuracy: 97.39
# Epoch 40:	########################################	elapsed: 0.48s, accuracy: 97.39
# Epoch 41:	########################################	elapsed: 0.52s, accuracy: 97.39
# Epoch 42:	########################################	elapsed: 0.50s, accuracy: 97.39
# Epoch 43:	########################################	elapsed: 0.50s, accuracy: 97.40
# Epoch 44:	########################################	elapsed: 0.48s, accuracy: 97.40
# Epoch 45:	########################################	elapsed: 0.48s, accuracy: 97.40
# Epoch 46:	########################################	elapsed: 0.48s, accuracy: 97.40
# Epoch 47:	########################################	elapsed: 0.49s, accuracy: 97.40
# Epoch 48:	########################################	elapsed: 0.49s, accuracy: 97.39
# Epoch 49:	########################################	elapsed: 0.49s, accuracy: 97.39
# Epoch 50:	########################################	elapsed: 0.49s, accuracy: 97.39
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
# <h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>
# 	layer 1: 2.42
# 	layer 2: 1.84
# 	layer 3: 6.59

# %% [markdown]
# ### Deep ReLU network

# %%
deep_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 2 * HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(2 * HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

deep_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0),
    Rbm(HIDDEN_LAYER_SIZE, 2 * HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(deep_mlp, deep_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.85s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 0.81s, accuracy: 11.35
# Epoch 3:	########################################	elapsed: 0.82s, accuracy: 11.35
# Epoch 4:	########################################	elapsed: 0.78s, accuracy: 11.35
# Epoch 5:	########################################	elapsed: 0.84s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 0.80s, accuracy: 38.88
# Epoch 7:	########################################	elapsed: 0.82s, accuracy: 78.63
# Epoch 8:	########################################	elapsed: 0.80s, accuracy: 87.72
# Epoch 9:	########################################	elapsed: 0.81s, accuracy: 91.97
# Epoch 10:	########################################	elapsed: 0.80s, accuracy: 92.67
# Epoch 11:	########################################	elapsed: 0.83s, accuracy: 93.93
# Epoch 12:	########################################	elapsed: 0.80s, accuracy: 91.59
# Epoch 13:	########################################	elapsed: 0.80s, accuracy: 92.05
# Epoch 14:	########################################	elapsed: 0.78s, accuracy: 94.29
# Epoch 15:	########################################	elapsed: 0.81s, accuracy: 94.21
# Epoch 16:	########################################	elapsed: 0.80s, accuracy: 95.20
# Epoch 17:	########################################	elapsed: 0.81s, accuracy: 95.72
# Epoch 18:	########################################	elapsed: 0.89s, accuracy: 95.43
# Epoch 19:	########################################	elapsed: 0.90s, accuracy: 95.26
# Epoch 20:	########################################	elapsed: 0.92s, accuracy: 95.30
# Epoch 21:	########################################	elapsed: 0.85s, accuracy: 95.23
# Epoch 22:	########################################	elapsed: 1.00s, accuracy: 95.27
# Epoch 23:	########################################	elapsed: 0.85s, accuracy: 95.68
# Epoch 24:	########################################	elapsed: 0.83s, accuracy: 95.82
# Epoch 25:	########################################	elapsed: 0.83s, accuracy: 95.47
# Epoch 26:	########################################	elapsed: 0.81s, accuracy: 96.12
# Epoch 27:	########################################	elapsed: 0.83s, accuracy: 96.62
# Epoch 28:	########################################	elapsed: 0.79s, accuracy: 96.42
# Epoch 29:	########################################	elapsed: 0.82s, accuracy: 96.71
# Epoch 30:	########################################	elapsed: 0.80s, accuracy: 96.77
# Epoch 31:	########################################	elapsed: 0.82s, accuracy: 96.77
# Epoch 32:	########################################	elapsed: 0.80s, accuracy: 96.76
# Epoch 33:	########################################	elapsed: 0.86s, accuracy: 96.75
# Epoch 34:	########################################	elapsed: 0.83s, accuracy: 96.75
# Epoch 35:	########################################	elapsed: 0.81s, accuracy: 96.75
# Epoch 36:	########################################	elapsed: 0.80s, accuracy: 96.75
# Epoch 37:	########################################	elapsed: 0.84s, accuracy: 96.75
# Epoch 38:	########################################	elapsed: 0.80s, accuracy: 96.74
# Epoch 39:	########################################	elapsed: 0.89s, accuracy: 96.74
# Epoch 40:	########################################	elapsed: 0.82s, accuracy: 96.74
# Epoch 41:	########################################	elapsed: 0.82s, accuracy: 96.74
# Epoch 42:	########################################	elapsed: 0.83s, accuracy: 96.75
# Epoch 43:	########################################	elapsed: 0.84s, accuracy: 96.75
# Epoch 44:	########################################	elapsed: 0.82s, accuracy: 96.75
# Epoch 45:	########################################	elapsed: 0.81s, accuracy: 96.75
# Epoch 46:	########################################	elapsed: 0.84s, accuracy: 96.75
# Epoch 47:	########################################	elapsed: 0.82s, accuracy: 96.75
# Epoch 48:	########################################	elapsed: 0.83s, accuracy: 96.74
# Epoch 49:	########################################	elapsed: 0.83s, accuracy: 96.74
# Epoch 50:	########################################	elapsed: 0.83s, accuracy: 96.73
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 2.58
# 	layer 2: 1.35
# 	layer 3: 0.78
# 	layer 4: 5.53
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.43s, reconstruction error: 74.95
# Epoch 2:	########################################	elapsed: 0.37s, reconstruction error: 54.83
# Epoch 3:	########################################	elapsed: 0.37s, reconstruction error: 42.51
# Epoch 4:	########################################	elapsed: 0.38s, reconstruction error: 36.23
# Epoch 5:	########################################	elapsed: 0.36s, reconstruction error: 32.49
# Epoch 6:	########################################	elapsed: 0.36s, reconstruction error: 24.70
# Epoch 7:	########################################	elapsed: 0.37s, reconstruction error: 20.91
# Epoch 8:	########################################	elapsed: 0.36s, reconstruction error: 18.61
# Epoch 9:	########################################	elapsed: 0.37s, reconstruction error: 16.92
# Epoch 10:	########################################	elapsed: 0.37s, reconstruction error: 15.68
# Epoch 11:	########################################	elapsed: 0.37s, reconstruction error: 14.94
# Epoch 12:	########################################	elapsed: 0.37s, reconstruction error: 13.87
# Epoch 13:	########################################	elapsed: 0.42s, reconstruction error: 13.30
# Epoch 14:	########################################	elapsed: 0.36s, reconstruction error: 12.56
# Epoch 15:	########################################	elapsed: 0.36s, reconstruction error: 11.96
# Epoch 16:	########################################	elapsed: 0.38s, reconstruction error: 11.52
# Epoch 17:	########################################	elapsed: 0.38s, reconstruction error: 11.12
# Epoch 18:	########################################	elapsed: 0.38s, reconstruction error: 10.76
# Epoch 19:	########################################	elapsed: 0.38s, reconstruction error: 10.40
# Epoch 20:	########################################	elapsed: 0.38s, reconstruction error: 10.15
# Epoch 21:	########################################	elapsed: 0.38s, reconstruction error: 9.93
# Epoch 22:	########################################	elapsed: 0.39s, reconstruction error: 9.85
# Epoch 23:	########################################	elapsed: 0.38s, reconstruction error: 9.66
# Epoch 24:	########################################	elapsed: 0.39s, reconstruction error: 9.47
# Epoch 25:	########################################	elapsed: 0.39s, reconstruction error: 9.39
# Epoch 26:	########################################	elapsed: 0.38s, reconstruction error: 9.20
# Epoch 27:	########################################	elapsed: 0.39s, reconstruction error: 9.17
# Epoch 28:	########################################	elapsed: 0.38s, reconstruction error: 9.00
# Epoch 29:	########################################	elapsed: 0.39s, reconstruction error: 8.99
# Epoch 30:	########################################	elapsed: 0.38s, reconstruction error: 8.86
# Epoch 31:	########################################	elapsed: 0.39s, reconstruction error: 8.78
# Epoch 32:	########################################	elapsed: 0.38s, reconstruction error: 8.69
# Epoch 33:	########################################	elapsed: 0.38s, reconstruction error: 8.58
# Epoch 34:	########################################	elapsed: 0.40s, reconstruction error: 8.53
# Epoch 35:	########################################	elapsed: 0.38s, reconstruction error: 8.52
# Epoch 36:	########################################	elapsed: 0.45s, reconstruction error: 8.46
# Epoch 37:	########################################	elapsed: 0.38s, reconstruction error: 8.41
# Epoch 38:	########################################	elapsed: 0.38s, reconstruction error: 8.37
# Epoch 39:	########################################	elapsed: 0.38s, reconstruction error: 8.24
# Epoch 40:	########################################	elapsed: 0.38s, reconstruction error: 8.17
# Epoch 41:	########################################	elapsed: 0.39s, reconstruction error: 8.24
# Epoch 42:	########################################	elapsed: 0.38s, reconstruction error: 8.22
# Epoch 43:	########################################	elapsed: 0.38s, reconstruction error: 8.21
# Epoch 44:	########################################	elapsed: 0.38s, reconstruction error: 8.21
# Epoch 45:	########################################	elapsed: 0.39s, reconstruction error: 8.18
# Epoch 46:	########################################	elapsed: 0.39s, reconstruction error: 8.11
# Epoch 47:	########################################	elapsed: 0.38s, reconstruction error: 7.98
# Epoch 48:	########################################	elapsed: 0.38s, reconstruction error: 8.02
# Epoch 49:	########################################	elapsed: 0.38s, reconstruction error: 8.02
# Epoch 50:	########################################	elapsed: 0.38s, reconstruction error: 8.05
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.29s, reconstruction error: 225.89
# Epoch 2:	########################################	elapsed: 0.30s, reconstruction error: 143.85
# Epoch 3:	########################################	elapsed: 0.29s, reconstruction error: 121.80
# Epoch 4:	########################################	elapsed: 0.29s, reconstruction error: 105.60
# Epoch 5:	########################################	elapsed: 0.28s, reconstruction error: 97.60
# Epoch 6:	########################################	elapsed: 0.29s, reconstruction error: 85.03
# Epoch 7:	########################################	elapsed: 0.29s, reconstruction error: 73.30
# Epoch 8:	########################################	elapsed: 0.29s, reconstruction error: 69.99
# Epoch 9:	########################################	elapsed: 0.29s, reconstruction error: 70.13
# Epoch 10:	########################################	elapsed: 0.29s, reconstruction error: 62.96
# Epoch 11:	########################################	elapsed: 0.29s, reconstruction error: 60.71
# Epoch 12:	########################################	elapsed: 0.28s, reconstruction error: 60.63
# Epoch 13:	########################################	elapsed: 0.28s, reconstruction error: 56.44
# Epoch 14:	########################################	elapsed: 0.30s, reconstruction error: 59.07
# Epoch 15:	########################################	elapsed: 0.29s, reconstruction error: 56.23
# Epoch 16:	########################################	elapsed: 0.29s, reconstruction error: 56.18
# Epoch 17:	########################################	elapsed: 0.29s, reconstruction error: 57.75
# Epoch 18:	########################################	elapsed: 0.29s, reconstruction error: 54.49
# Epoch 19:	########################################	elapsed: 0.28s, reconstruction error: 53.54
# Epoch 20:	########################################	elapsed: 0.29s, reconstruction error: 53.92
# Epoch 21:	########################################	elapsed: 0.29s, reconstruction error: 53.80
# Epoch 22:	########################################	elapsed: 0.28s, reconstruction error: 53.12
# Epoch 23:	########################################	elapsed: 0.29s, reconstruction error: 51.03
# Epoch 24:	########################################	elapsed: 0.28s, reconstruction error: 51.30
# Epoch 25:	########################################	elapsed: 0.29s, reconstruction error: 54.31
# Epoch 26:	########################################	elapsed: 0.29s, reconstruction error: 52.47
# Epoch 27:	########################################	elapsed: 0.29s, reconstruction error: 50.26
# Epoch 28:	########################################	elapsed: 0.42s, reconstruction error: 50.09
# Epoch 29:	########################################	elapsed: 0.28s, reconstruction error: 49.46
# Epoch 30:	########################################	elapsed: 0.30s, reconstruction error: 50.66
# Epoch 31:	########################################	elapsed: 0.29s, reconstruction error: 47.20
# Epoch 32:	########################################	elapsed: 0.29s, reconstruction error: 49.57
# Epoch 33:	########################################	elapsed: 0.29s, reconstruction error: 49.58
# Epoch 34:	########################################	elapsed: 0.29s, reconstruction error: 51.28
# Epoch 35:	########################################	elapsed: 0.29s, reconstruction error: 49.89
# Epoch 36:	########################################	elapsed: 0.28s, reconstruction error: 50.34
# Epoch 37:	########################################	elapsed: 0.29s, reconstruction error: 49.58
# Epoch 38:	########################################	elapsed: 0.28s, reconstruction error: 49.90
# Epoch 39:	########################################	elapsed: 0.29s, reconstruction error: 47.28
# Epoch 40:	########################################	elapsed: 0.29s, reconstruction error: 49.15
# Epoch 41:	########################################	elapsed: 0.29s, reconstruction error: 48.65
# Epoch 42:	########################################	elapsed: 0.30s, reconstruction error: 48.46
# Epoch 43:	########################################	elapsed: 0.30s, reconstruction error: 48.21
# Epoch 44:	########################################	elapsed: 0.29s, reconstruction error: 48.89
# Epoch 45:	########################################	elapsed: 0.29s, reconstruction error: 45.77
# Epoch 46:	########################################	elapsed: 0.29s, reconstruction error: 47.86
# Epoch 47:	########################################	elapsed: 0.29s, reconstruction error: 48.94
# Epoch 48:	########################################	elapsed: 0.29s, reconstruction error: 47.98
# Epoch 49:	########################################	elapsed: 0.30s, reconstruction error: 46.43
# Epoch 50:	########################################	elapsed: 0.29s, reconstruction error: 47.91
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 0.41s, reconstruction error: 45.52
# Epoch 2:	########################################	elapsed: 0.41s, reconstruction error: 27.39
# Epoch 3:	########################################	elapsed: 0.41s, reconstruction error: 22.14
# Epoch 4:	########################################	elapsed: 0.41s, reconstruction error: 20.10
# Epoch 5:	########################################	elapsed: 0.41s, reconstruction error: 19.19
# Epoch 6:	########################################	elapsed: 0.41s, reconstruction error: 20.32
# Epoch 7:	########################################	elapsed: 0.41s, reconstruction error: 19.85
# Epoch 8:	########################################	elapsed: 0.41s, reconstruction error: 19.19
# Epoch 9:	########################################	elapsed: 0.41s, reconstruction error: 18.84
# Epoch 10:	########################################	elapsed: 0.41s, reconstruction error: 16.91
# Epoch 11:	########################################	elapsed: 0.41s, reconstruction error: 19.43
# Epoch 12:	########################################	elapsed: 0.42s, reconstruction error: 17.53
# Epoch 13:	########################################	elapsed: 0.41s, reconstruction error: 16.43
# Epoch 14:	########################################	elapsed: 0.40s, reconstruction error: 16.82
# Epoch 15:	########################################	elapsed: 0.40s, reconstruction error: 17.07
# Epoch 16:	########################################	elapsed: 0.40s, reconstruction error: 17.65
# Epoch 17:	########################################	elapsed: 0.41s, reconstruction error: 15.54
# Epoch 18:	########################################	elapsed: 0.41s, reconstruction error: 17.20
# Epoch 19:	########################################	elapsed: 0.46s, reconstruction error: 18.00
# Epoch 20:	########################################	elapsed: 0.41s, reconstruction error: 17.69
# Epoch 21:	########################################	elapsed: 0.42s, reconstruction error: 16.69
# Epoch 22:	########################################	elapsed: 0.41s, reconstruction error: 18.48
# Epoch 23:	########################################	elapsed: 0.41s, reconstruction error: 15.24
# Epoch 24:	########################################	elapsed: 0.40s, reconstruction error: 15.76
# Epoch 25:	########################################	elapsed: 0.41s, reconstruction error: 16.90
# Epoch 26:	########################################	elapsed: 0.42s, reconstruction error: 16.12
# Epoch 27:	########################################	elapsed: 0.42s, reconstruction error: 15.98
# Epoch 28:	########################################	elapsed: 0.42s, reconstruction error: 15.43
# Epoch 29:	########################################	elapsed: 0.43s, reconstruction error: 16.67
# Epoch 30:	########################################	elapsed: 0.43s, reconstruction error: 15.88
# Epoch 31:	########################################	elapsed: 0.43s, reconstruction error: 16.22
# Epoch 32:	########################################	elapsed: 0.44s, reconstruction error: 15.37
# Epoch 33:	########################################	elapsed: 0.43s, reconstruction error: 15.22
# Epoch 34:	########################################	elapsed: 0.43s, reconstruction error: 16.28
# Epoch 35:	########################################	elapsed: 0.48s, reconstruction error: 15.32
# Epoch 36:	########################################	elapsed: 0.43s, reconstruction error: 15.06
# Epoch 37:	########################################	elapsed: 0.43s, reconstruction error: 16.13
# Epoch 38:	########################################	elapsed: 0.42s, reconstruction error: 15.04
# Epoch 39:	########################################	elapsed: 0.42s, reconstruction error: 14.76
# Epoch 40:	########################################	elapsed: 0.42s, reconstruction error: 15.38
# Epoch 41:	########################################	elapsed: 0.43s, reconstruction error: 14.69
# Epoch 42:	########################################	elapsed: 0.42s, reconstruction error: 14.80
# Epoch 43:	########################################	elapsed: 0.43s, reconstruction error: 14.84
# Epoch 44:	########################################	elapsed: 0.42s, reconstruction error: 14.75
# Epoch 45:	########################################	elapsed: 0.45s, reconstruction error: 14.86
# Epoch 46:	########################################	elapsed: 0.43s, reconstruction error: 15.50
# Epoch 47:	########################################	elapsed: 0.42s, reconstruction error: 14.29
# Epoch 48:	########################################	elapsed: 0.42s, reconstruction error: 15.07
# Epoch 49:	########################################	elapsed: 0.43s, reconstruction error: 15.03
# Epoch 50:	########################################	elapsed: 0.42s, reconstruction error: 14.78
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.85s, accuracy: 93.15
# Epoch 2:	########################################	elapsed: 0.81s, accuracy: 95.06
# Epoch 3:	########################################	elapsed: 0.82s, accuracy: 95.60
# Epoch 4:	########################################	elapsed: 0.83s, accuracy: 95.39
# Epoch 5:	########################################	elapsed: 0.80s, accuracy: 96.35
# Epoch 6:	########################################	elapsed: 0.87s, accuracy: 96.20
# Epoch 7:	########################################	elapsed: 0.81s, accuracy: 96.66
# Epoch 8:	########################################	elapsed: 0.86s, accuracy: 95.85
# Epoch 9:	########################################	elapsed: 0.81s, accuracy: 96.71
# Epoch 10:	########################################	elapsed: 0.84s, accuracy: 96.81
# Epoch 11:	########################################	elapsed: 0.82s, accuracy: 97.09
# Epoch 12:	########################################	elapsed: 0.80s, accuracy: 97.14
# Epoch 13:	########################################	elapsed: 0.81s, accuracy: 97.29
# Epoch 14:	########################################	elapsed: 0.85s, accuracy: 97.32
# Epoch 15:	########################################	elapsed: 0.81s, accuracy: 97.38
# Epoch 16:	########################################	elapsed: 0.82s, accuracy: 97.39
# Epoch 17:	########################################	elapsed: 0.85s, accuracy: 97.41
# Epoch 18:	########################################	elapsed: 0.84s, accuracy: 97.41
# Epoch 19:	########################################	elapsed: 0.80s, accuracy: 97.41
# Epoch 20:	########################################	elapsed: 0.80s, accuracy: 97.41
# Epoch 21:	########################################	elapsed: 0.81s, accuracy: 97.40
# Epoch 22:	########################################	elapsed: 0.80s, accuracy: 97.40
# Epoch 23:	########################################	elapsed: 0.82s, accuracy: 97.40
# Epoch 24:	########################################	elapsed: 0.81s, accuracy: 97.40
# Epoch 25:	########################################	elapsed: 0.79s, accuracy: 97.40
# Epoch 26:	########################################	elapsed: 0.80s, accuracy: 97.40
# Epoch 27:	########################################	elapsed: 0.84s, accuracy: 97.41
# Epoch 28:	########################################	elapsed: 0.80s, accuracy: 97.42
# Epoch 29:	########################################	elapsed: 0.80s, accuracy: 97.42
# Epoch 30:	########################################	elapsed: 0.85s, accuracy: 97.42
# Epoch 31:	########################################	elapsed: 0.82s, accuracy: 97.43
# Epoch 32:	########################################	elapsed: 0.83s, accuracy: 97.43
# Epoch 33:	########################################	elapsed: 0.82s, accuracy: 97.43
# Epoch 34:	########################################	elapsed: 0.85s, accuracy: 97.43
# Epoch 35:	########################################	elapsed: 1.19s, accuracy: 97.43
# Epoch 36:	########################################	elapsed: 0.87s, accuracy: 97.43
# Epoch 37:	########################################	elapsed: 1.05s, accuracy: 97.43
# Epoch 38:	########################################	elapsed: 0.81s, accuracy: 97.43
# Epoch 39:	########################################	elapsed: 0.96s, accuracy: 97.44
# Epoch 40:	########################################	elapsed: 0.92s, accuracy: 97.43
# Epoch 41:	########################################	elapsed: 1.04s, accuracy: 97.43
# Epoch 42:	########################################	elapsed: 0.83s, accuracy: 97.42
# Epoch 43:	########################################	elapsed: 1.04s, accuracy: 97.43
# Epoch 44:	########################################	elapsed: 0.85s, accuracy: 97.43
# Epoch 45:	########################################	elapsed: 0.82s, accuracy: 97.43
# Epoch 46:	########################################	elapsed: 0.85s, accuracy: 97.43
# Epoch 47:	########################################	elapsed: 0.85s, accuracy: 97.43
# Epoch 48:	########################################	elapsed: 0.88s, accuracy: 97.43
# Epoch 49:	########################################	elapsed: 0.89s, accuracy: 97.42
# Epoch 50:	########################################	elapsed: 0.85s, accuracy: 97.42
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
# <h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>
# 	layer 1: 2.30
# 	layer 2: 1.88
# 	layer 3: 1.19
# 	layer 4: 6.36
