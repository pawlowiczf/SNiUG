# %% [markdown]
# # Nesterov’s method and data visualization using autoassociative neural networks

# %%
# Check for all needed packages
import time

import IPython
import matplotlib
import mnists
import numpy

# In case of ImportError, install them to the running kernel with
# %pip install numpy matplotlib mnists
# or the the runtime container with:
# !pip install numpy matplotlib mnists
# (In case of the latter, remember to restart the kernel!)

# Tested in Python 3.14.3 with:
# numpy==2.4.3
# matplotlib==3.10.8
# mnists==0.4.1

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix: np.ndarray, axis: int = 1) -> np.ndarray:
    """
    Appends a column of ones to the right side of a 2D matrix.
    """
    return np.concatenate(
        (matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis
    )


def zeros(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of zeros with the given shape.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. zeros(3, 4) creates a (3, 4) array.
    """
    return np.zeros(shape=tuple(dims), dtype=np.float32)


def ones(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of ones with the given shape.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. ones(3, 4) creates a (3, 4) array.
    """
    return np.ones(shape=tuple(dims), dtype=np.float32)


def rand(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of random values sampled from a uniform [0, 1) distribution.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. rand(3, 4) creates a (3, 4) array.
    """
    return np.random.rand(*dims).astype(np.float32)


def randn(*dims: int) -> np.ndarray:
    """
    Creates a NumPy array of random values sampled from a standard normal distribution.

    Args:
        *dims:  Variable number of integers defining the shape of the array.
                E.g. rand(3, 4) creates a (3, 4) array.
    """
    return np.random.randn(*dims).astype(np.float32)


def chunks(seq: list, size: int) -> tuple[np.ndarray]:
    """
    Splits a sequence into consecutive chunks of a given size.

    The last chunk may be smaller than `size` if the sequence length
    is not evenly divisible.

    Args:
        seq:  The input sequence (e.g. list or other sliceable) to split.
        size: The maximum number of elements in each chunk.

    Returns:
        Successive sub-sequences of length `size` (or less for the final chunk).
    """
    return tuple([seq[pos : (pos + size)] for pos in range(0, len(seq), size)])


def as_matrix(vector: np.ndarray) -> np.ndarray:
    """Reshape 1D vector to column matrix."""
    return np.reshape(vector, (-1, 1))


def arrange_tiles_img(examples: np.ndarray) -> np.ndarray:
    """
    Arrange 2D matrices as tiles

    Takes 4D `examples` tensor with dims:
        rows x cols x tile_height x tile_width
    """
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]

    space_between_tiles = 2
    img_matrix = np.empty(
        shape=(
            rows_count * (tile_height + space_between_tiles) - space_between_tiles,
            cols_count * (tile_width + space_between_tiles) - space_between_tiles,
        )
    )
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            img_matrix[x_0 : x_0 + tile_height, y_0 : y_0 + tile_width] = examples[r, c]

    return img_matrix


def tiles(examples: np.ndarray) -> None:
    """Previews the arrange tiles"""
    img = arrange_tiles_img(examples)
    plt.matshow(img, cmap="gray", interpolation="none")
    plt.axis("off")
    plt.show()


def draw_rbm_filters(rbm: "RestrictedBoltzmannMachine") -> None:
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)


def draw_layer_filters(layer: "Layer") -> None:
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations


def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)


# Tip: its a plain linear function with optional stochastic noise
def gaussian(batch: np.ndarray, stochastic: bool = False) -> np.ndarray:
    if stochastic:
        noise = randn(*batch.shape)
        return batch + noise
    return batch


def gaussian_derivative(batch: np.ndarray) -> np.ndarray:
    return ones(*batch.shape)

# %% [markdown]
# # MNIST dataset

# %%
from mnists import MNIST

mnist = MNIST()

PREVIEW_N_ROWS = 12
PREVIEW_N_COLS = 24
TILE_DIM = 28  # [px]


def create_mnist_digits(n_rows: int, n_cols: int, tile_dim: int) -> np.ndarray:
    shape = (n_rows, n_cols, tile_dim, tile_dim)
    return np.reshape(mnist.train_images()[: 12 * 24], newshape=shape)


mnist_digits = create_mnist_digits(PREVIEW_N_ROWS, PREVIEW_N_COLS, TILE_DIM)

tiles(mnist_digits)

# %% [markdown]
# # RBM & DBN training

# %%
class RestrictedBoltzmannMachine:
    """
    A Restricted Boltzmann Machine (RBM) with a single visible and hidden layer.

    The weight matrix W has shape (visible_size + 1, hidden_size + 1), where
    the extra row and column are reserved for bias units.

    Attributes:
        visible_size:       Number of visible (input) units, excluding the bias.
        hidden_size:        Number of hidden units, excluding the bias.
        visible_act_func:   The activation function used within visible layer.
        hidden_act_func:    The activation function used within hidden layer.
        learning_rate:      Step size used during contrastive divergence updates.
        W:                  Weight matrix of shape (visible_size+1, hidden_size+1).
        momentum:           Momentum coefficient.
        l2_penalty:         Coefficent for the L2 regularization.
    """

    def __init__(
        self,
        visible_size: int,
        hidden_size: int,
        visible_act_func: callable,
        hidden_act_func: callable,
        learning_rate: float,
        momentum: float,
        l2_penalty: float,
    ):
        self.visible_size = visible_size
        self.hidden_size = hidden_size

        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func

        self.learning_rate = learning_rate
        self.momentum = momentum

        self.l2_penalty = l2_penalty

        self.reset()

    def reset(self) -> None:
        self.W = np.random.normal(
            scale=0.01, size=(self.visible_size + 1, self.hidden_size + 1)
        ).astype(np.float32)
        self.W[:, -1] = 0.0  # zero hidden-bias weights
        self.W[-1, :] = 0.0  # zero visible-bias weights
        self.M = zeros(self.visible_size + 1, self.hidden_size + 1)

# %%
from typing import TypeAlias

DBN: TypeAlias = list[RestrictedBoltzmannMachine]

# %%
def cdk(rbm: RestrictedBoltzmannMachine, minibatch: np.ndarray, k: int = 1) -> None:
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(
            negative_hidden @ rbm.W[:-1, :].T, stochastic=True
        )
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (
        (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    )
    rbm.M -= (
        (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden
    )

    if rbm.l2_penalty is not None:
        rbm.M[:-1, :-1] = (
            rbm.M[:-1, :-1] - rbm.learning_rate * rbm.l2_penalty * rbm.W[:-1, :-1]
        )

    rbm.W += rbm.M


def reconstruction_error(
    rbm: RestrictedBoltzmannMachine, minibatch: np.ndarray
) -> float:
    """
    Computes the mean per-sample reconstruction error on a minibatch.
    """
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] = rbm.hidden_act_func(minibatch @ rbm.W[:, :-1])
    hidden[:, :-1] = hidden[:, :-1] > rand(observations_count, rbm.hidden_size)

    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))

    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count

    return error

# %%
def propagate_up(
    dbn: DBN,
    layers_count: int,
    visible: np.ndarray,
) -> np.ndarray:
    """
    Forward pass through DBN layers: propagates visible units upward to the target layer.
    Appends bias term (ones) and applies sigmoid activation after matrix multiplication.
    """
    for i in range(layers_count):
        visible = append_ones(dbn[i].visible_act_func(visible @ dbn[i].W[:, :-1]))
    return visible


def propagate_down(
    dbn: DBN,
    layers_count: int,
    hidden: np.ndarray,
) -> np.ndarray:
    """
    Reconstruct data by propagating downward through the DBN.
    Appends bias term (ones) and applies sigmoid activation after matrix multiplication.
    """
    for i in reversed(range(layers_count)):
        hidden = append_ones(
            dbn[i].hidden_act_func(hidden @ np.transpose(dbn[i].W[:-1, :]))
        )
    return hidden


def dbn_reconstuction_error(
    dbn: DBN,
    layer_idx: int,
    minibatch: np.ndarray,
) -> float:
    """
    Compute the reconstruction error for a selected DBN layer.

    The minibatch is first propagated upward to the chosen layer,
    then the reconstruction error is evaluated for that RBM.

    Args:
        dbn: List of pretrained RBM layers.
        layer_idx: Index of the RBM layer to evaluate.
        minibatch: Input minibatch.

    Returns:
        Reconstruction error as a scalar value.
    """
    propagated = propagate_up(dbn, layer_idx, minibatch)
    return reconstruction_error(dbn[layer_idx], propagated)


def train_dbn_layer(
    dbn: DBN,
    layer_idx: int,
    dataset: np.ndarray,
    batch_size: int,
) -> None:
    """
    Train one DBN layer using greedy layer-wise pretraining.

    The dataset is first propagated through all previously trained layers.
    Then the selected RBM layer is trained on minibatches.

    Args:
        dbn: List of RBM layers.
        layer_idx: Index of the RBM layer to train.
        dataset: Full training dataset.
        batch_size: Minibatch size.
    """

    dataset = propagate_up(dbn, layer_idx, dataset)

    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0:
            print("#", end="")


def run_dbn_training(
    dbn: DBN,
    dataset: np.ndarray,
    monitoring_set: np.ndarray,
    batch_size: int,
    epochs_count: int,
    target_momentum: float = 0.9,
) -> None:
    for layer_idx in range(len(dbn)):
        print(f"\nLearning layer {layer_idx}")

        for epoch in range(epochs_count):
            print(f"Epoch {epoch}:", end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = target_momentum

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print(f"\telapsed: {elapsed:>2.2f}s, reconstruction error: {error:>2.2f}")

# %% [markdown]
# # Part 1. Autoencoder training with Nesterov accelerated gradient descend

# %%
class Layer:
    def __init__(
        self,
        visible_size: int,
        hidden_size: int,
        activation_fun,
        d_activation_fun,
        learning_rate: float,
        momentum: float,
        l2_penalty: float,
    ):
        self.visible_size = visible_size
        self.hidden_size = hidden_size

        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun

        self.learning_rate = learning_rate
        self.momentum = momentum

        self.l2_penalty = l2_penalty

        self.reset()

    def reset(self) -> None:
        self.W = np.random.normal(
            scale=0.01, size=(self.visible_size + 1, self.hidden_size)
        ).astype(np.float32)
        self.W[-1, :] = 0.0

        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size + 1, self.hidden_size)

# %%
from typing import TypeAlias

MLP: TypeAlias = list[Layer]

# %% [markdown]
# ## Error backpropagation with Nesterov accelerated gradient descend
#
# __Forward pass.__ When ```compute_derivatives == false```, we are not training the network but use it to make predictions. In this case we cannot use weights in ```layer.W``` directly: in Nesterov method weights in this matrix are shifted along the direction of momentum (that is, they are at the point in the weight space where the gradient is calculated). We need to account for this when calculating the total input to the next layer.

# %%
def forward_pass(ae: MLP, batch: np.ndarray, compute_derivatives: bool) -> np.ndarray:
    visible = batch

    for layer_idx, layer in enumerate(ae):
        if not compute_derivatives:
            # We are using the network to make predictions. Fix evaluation of the total
            # input to the next layer (z) so that it uses the correct weights, and not
            # the weights where the gradient is calculated.

            z = visible @ (layer.W - layer.momentum * layer.M)
        else:
            z = visible @ layer.W

        layer.activations = append_ones(layer.activation_fun(z))

        if compute_derivatives and (layer_idx < len(ae) - 1):
            layer.d_activations = layer.d_activation_fun(z)

        visible = layer.activations

    return visible[:, :-1]

# %% [markdown]
# __Backward pass.__ Implement Nesterov updates in the backward pass of error backpropagation.
#
# Remember that the weights in ```layer.W``` are shifted along the direction of momentum. Before we change the momentum matrix (but after we have everything needed to calculate the gradient), we must fix (i.e. _un-shift_) these weights.
#
# At the end of the backward pass, we must update the weight matrix accoring to the momentum interpretation of the Nesterov method.

# %%
def error_backpropagate(ae: MLP, batch: np.ndarray) -> None:
    observations_count = batch.shape[0]

    for layer_idx, layer in reversed(list(enumerate(ae))):
        if layer_idx > 0:
            prev_layer = ae[layer_idx - 1]
            visible = prev_layer.activations

            prev_layer.deltas = (
                layer.deltas @ layer.W[:-1, :].T
            ) * prev_layer.d_activations
        else:
            visible = batch

        # Fix weights in layer.W before changing the momentum matrix
        layer.W = layer.W - layer.momentum * layer.M

        layer.M *= layer.momentum
        layer.M -= (layer.learning_rate / observations_count) * (
            visible.T @ layer.deltas
        )

        if layer.l2_penalty > 0:
            layer.M[:-1, :] = (
                layer.M[:-1, :]
                - layer.learning_rate * layer.l2_penalty * layer.W[:-1, :]
            )

        # Update the weight matrix according to the momentum interpretation of the Nesterov method.
        layer.W = layer.W + (1 + layer.momentum) * layer.M

# %% [markdown]
# ### Cross entropy cost

# %%
def xentropy(batch, reconstructions):
    observations_count = batch.shape[0]

    xe = batch * np.log(reconstructions) + (ones(*batch.shape) - batch) * np.log(
        ones(*reconstructions.shape) - reconstructions
    )
    xe = -np.sum(xe, axis=1)
    return np.sum(xe, axis=0) / observations_count

# %% [markdown]
# ### Training procedure

# %%
def train_ae(ae: MLP, dataset: np.ndarray, batch_size: np.ndarray) -> None:
    batches_limit = dataset.shape[0] / batch_size
    batched_data = chunks(dataset, batch_size)

    for batch_idx, batch in enumerate(batched_data):
        reconstructions = forward_pass(ae, batch, True)

        ae[-1].deltas = reconstructions - batch[:, :-1]

        error_backpropagate(ae, batch)

        if batch_idx % round(batches_limit / 40) == 0:
            print("#", end="")

# %%
def run_ae_training(
    ae: MLP,
    train_set: np.ndarray,
    validation_set: np.ndarray,
    batch_size: int,
    epochs_count: int,
) -> None:
    for epoch in range(epochs_count):
        print(f"Epoch {epoch + 1}:", end="\t")

        if epoch == 10:
            for layer in ae:
                layer.momentum = 0.95
        elif epoch == 15:
            for layer in ae:
                layer.momentum = 0.97
        elif epoch == 20:
            for layer in ae:
                layer.momentum = 0.98
        elif epoch == 25:
            for layer in ae:
                layer.momentum = 0.99

        start_time = time.time()
        train_ae(ae, train_set, batch_size)
        elapsed = time.time() - start_time

        xe = xentropy(validation_set[:, :-1], forward_pass(ae, validation_set, False))
        print(f"\telapsed: {elapsed:>2.2f}s, cross-entropy: {xe:>2.2f}")

    print("Training finished!")

# %% [markdown]
# ###  Initializing AE with DBN weights

# %%
def initialize_ae(ae: MLP, dbn: DBN) -> None:
    assert len(ae) == 2 * len(dbn)

    n = len(dbn)
    for layer_idx in range(n):
        ae[layer_idx].W = np.copy(dbn[layer_idx].W[:, :-1])
        ae[n + layer_idx].W = np.copy(dbn[n - layer_idx - 1].W[:-1, :].T)

# %% [markdown]
# ## Autoencoder for MNIST digits

# %%
np.random.seed(1234)

DATASET_SIZE: int = 10000  # 60000 for whole dataset
DIGIT_SIZE: int = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_images = np.random.permutation(mnist_train_images)

mnist_train_images = np.reshape(
    mnist_train_images[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE * DIGIT_SIZE)
)
mnist_train_images = append_ones(mnist_train_images)

monitoring_set_indeces = np.random.choice(
    mnist_train_images.shape[0], 512, replace=False
)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(
    mnist_test_images, newshape=(-1, DIGIT_SIZE * DIGIT_SIZE)
)
mnist_test_images = append_ones(mnist_test_images)

# %%
VISIBLE_LAYER_SIZE: int = DIGIT_SIZE * DIGIT_SIZE

BATCH_SIZE: int = 128
EPOCHS_COUNT: int = 50

RBM_LEARNING_RATE: float = 0.1
AE_LEARNING_RATE: float = 0.01
AE_MOMENTUM: float = 0.9
L2_PENALTY: float = 0.0002

# %%
from IPython.core.display import HTML


def compare_results(
    ae: MLP,
    dbn: DBN,
    train_set: np.ndarray,
    validation_set: np.ndarray,
    monitoring_set: np.ndarray,
    batch_size: int,
    epochs_count: int,
) -> None:
    for layer in ae:
        layer.reset()

    display(HTML("<h3>DBN training</h3>"))
    run_dbn_training(dbn, train_set, monitoring_set, batch_size, epochs_count)

    initialize_ae(ae, dbn)
    dbn_reconstructions = np.reshape(
        forward_pass(ae, validation_set[: 8 * 24, :], False), newshape=(8, 24, 28, 28)
    )
    dbn_rec_cost = xentropy(
        validation_set[:, :-1], forward_pass(ae, validation_set, False)
    )

    display(HTML("<h3>Finetuning pretrained AE</h3>"))

    print("Reconstruction cost before finetuning: {0:>2.2f}\n".format(dbn_rec_cost))
    run_ae_training(ae, train_set, validation_set, batch_size, epochs_count)

    display(HTML("<h3>Input minibatch</h3>"))
    tiles(np.reshape(validation_set[: 8 * 24, :-1], newshape=(8, 24, 28, 28)))

    display(HTML("<h3>Pretrained AE reconstructions</h3>"))
    tiles(dbn_reconstructions)

    display(HTML("<h3>Finetuned AE reconstructions</h3>"))
    ae_reconstructions = np.reshape(
        forward_pass(ae, validation_set[: 8 * 24], False), newshape=(8, 24, 28, 28)
    )
    tiles(ae_reconstructions)

# %% [markdown]
# ###  Autoencoder network
#
# Define the autoencoder network for MNIST digits. The network structure should be suitable for pretraining with the provided DBN.

# %%
dbn = [
    RestrictedBoltzmannMachine(
        VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY
    ),
    RestrictedBoltzmannMachine(
        256, 128, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY
    ),
    RestrictedBoltzmannMachine(
        128, 64, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY
    ),
    RestrictedBoltzmannMachine(
        64, 10, sigmoid, gaussian, RBM_LEARNING_RATE / 10.0, 0.5, L2_PENALTY
    ),
]

ae: MLP = [
    # encoder
    Layer(
        VISIBLE_LAYER_SIZE,
        256,
        sigmoid,
        sigmoid_derivative,
        AE_LEARNING_RATE,
        AE_MOMENTUM,
        L2_PENALTY,
    ),
    Layer(
        256, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY
    ),
    Layer(
        128, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY
    ),
    Layer(
        64,
        10,
        gaussian,
        gaussian_derivative,
        AE_LEARNING_RATE / 10.0,
        AE_MOMENTUM,
        L2_PENALTY,
    ),
    # decoder (mirrored)
    Layer(
        10,
        64,
        sigmoid,
        sigmoid_derivative,
        AE_LEARNING_RATE / 10.0,
        AE_MOMENTUM,
        L2_PENALTY,
    ),
    Layer(
        64, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY
    ),
    Layer(
        128, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY
    ),
    Layer(
        256,
        VISIBLE_LAYER_SIZE,
        sigmoid,
        sigmoid_derivative,
        AE_LEARNING_RATE,
        AE_MOMENTUM,
        L2_PENALTY,
    ),
]

compare_results(
    ae,
    dbn,
    mnist_train_images,
    mnist_test_images,
    monitoring_set,
    BATCH_SIZE,
    EPOCHS_COUNT,
)
# Out:
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 0:	########################################	elapsed: 1.52s, reconstruction error: 31.66
# Epoch 1:	########################################	elapsed: 1.29s, reconstruction error: 24.76
# Epoch 2:	########################################	elapsed: 1.05s, reconstruction error: 21.29
# Epoch 3:	########################################	elapsed: 1.34s, reconstruction error: 19.00
# Epoch 4:	########################################	elapsed: 1.45s, reconstruction error: 17.64
# Epoch 5:	########################################	elapsed: 1.42s, reconstruction error: 15.24
# Epoch 6:	########################################	elapsed: 1.09s, reconstruction error: 13.77
# Epoch 7:	########################################	elapsed: 1.14s, reconstruction error: 12.63
# Epoch 8:	########################################	elapsed: 1.47s, reconstruction error: 12.05
# Epoch 9:	########################################	elapsed: 1.15s, reconstruction error: 11.58
# Epoch 10:	########################################	elapsed: 1.22s, reconstruction error: 11.05
# Epoch 11:	########################################	elapsed: 1.08s, reconstruction error: 10.83
# Epoch 12:	########################################	elapsed: 1.16s, reconstruction error: 10.68
# Epoch 13:	########################################	elapsed: 1.20s, reconstruction error: 10.54
# Epoch 14:	########################################	elapsed: 1.39s, reconstruction error: 10.42
# Epoch 15:	########################################	elapsed: 1.39s, reconstruction error: 10.15
# Epoch 16:	########################################	elapsed: 1.26s, reconstruction error: 10.08
# Epoch 17:	########################################	elapsed: 3.47s, reconstruction error: 10.04
# Epoch 18:	########################################	elapsed: 2.96s, reconstruction error: 9.80
# Epoch 19:	########################################	elapsed: 1.15s, reconstruction error: 9.89
# Epoch 20:	########################################	elapsed: 0.98s, reconstruction error: 9.71
# Epoch 21:	########################################	elapsed: 1.07s, reconstruction error: 9.61
# Epoch 22:	########################################	elapsed: 0.91s, reconstruction error: 9.62
# Epoch 23:	########################################	elapsed: 1.14s, reconstruction error: 9.55
# Epoch 24:	########################################	elapsed: 1.19s, reconstruction error: 9.38
# Epoch 25:	########################################	elapsed: 1.45s, reconstruction error: 9.33
# Epoch 26:	########################################	elapsed: 1.77s, reconstruction error: 9.24
# Epoch 27:	########################################	elapsed: 1.40s, reconstruction error: 9.36
# Epoch 28:	########################################	elapsed: 1.19s, reconstruction error: 9.15
# Epoch 29:	########################################	elapsed: 1.03s, reconstruction error: 9.28
# Epoch 30:	########################################	elapsed: 1.04s, reconstruction error: 9.20
# Epoch 31:	########################################	elapsed: 1.05s, reconstruction error: 8.96
# Epoch 32:	########################################	elapsed: 0.73s, reconstruction error: 9.04
# Epoch 33:	########################################	elapsed: 1.02s, reconstruction error: 9.09
# Epoch 34:	########################################	elapsed: 1.24s, reconstruction error: 9.03
# Epoch 35:	########################################	elapsed: 0.96s, reconstruction error: 8.87
# Epoch 36:	########################################	elapsed: 0.84s, reconstruction error: 8.95
# Epoch 37:	########################################	elapsed: 1.17s, reconstruction error: 8.87
# Epoch 38:	########################################	elapsed: 0.92s, reconstruction error: 8.84
# Epoch 39:	########################################	elapsed: 0.85s, reconstruction error: 8.88
# Epoch 40:	########################################	elapsed: 1.24s, reconstruction error: 8.82
# Epoch 41:	########################################	elapsed: 1.80s, reconstruction error: 8.77
# Epoch 42:	########################################	elapsed: 1.30s, reconstruction error: 8.68
# Epoch 43:	########################################	elapsed: 1.73s, reconstruction error: 8.87
# Epoch 44:	########################################	elapsed: 1.23s, reconstruction error: 8.79
# Epoch 45:	########################################	elapsed: 1.32s, reconstruction error: 8.70
# Epoch 46:	########################################	elapsed: 1.26s, reconstruction error: 8.79
# Epoch 47:	########################################	elapsed: 1.27s, reconstruction error: 8.76
# Epoch 48:	########################################	elapsed: 1.23s, reconstruction error: 8.64
# Epoch 49:	########################################	elapsed: 1.22s, reconstruction error: 8.66
#
# Learning layer 1
# Epoch 0:	########################################	elapsed: 0.50s, reconstruction error: 20.89
# Epoch 1:	########################################	elapsed: 0.62s, reconstruction error: 15.82
# Epoch 2:	########################################	elapsed: 0.65s, reconstruction error: 13.74
# Epoch 3:	########################################	elapsed: 0.42s, reconstruction error: 12.38
# Epoch 4:	########################################	elapsed: 0.93s, reconstruction error: 11.45
# Epoch 5:	########################################	elapsed: 0.45s, reconstruction error: 9.42
# Epoch 6:	########################################	elapsed: 0.74s, reconstruction error: 8.22
# Epoch 7:	########################################	elapsed: 0.68s, reconstruction error: 7.54
# Epoch 8:	########################################	elapsed: 0.81s, reconstruction error: 7.13
# Epoch 9:	########################################	elapsed: 0.47s, reconstruction error: 6.91
# Epoch 10:	########################################	elapsed: 0.61s, reconstruction error: 6.64
# Epoch 11:	########################################	elapsed: 0.70s, reconstruction error: 6.39
# Epoch 12:	########################################	elapsed: 0.46s, reconstruction error: 6.33
# Epoch 13:	########################################	elapsed: 0.70s, reconstruction error: 6.23
# Epoch 14:	########################################	elapsed: 0.56s, reconstruction error: 6.02
# Epoch 15:	########################################	elapsed: 0.52s, reconstruction error: 5.92
# Epoch 16:	########################################	elapsed: 0.45s, reconstruction error: 6.00
# Epoch 17:	########################################	elapsed: 0.45s, reconstruction error: 5.97
# Epoch 18:	########################################	elapsed: 0.44s, reconstruction error: 5.77
# Epoch 19:	########################################	elapsed: 0.44s, reconstruction error: 5.76
# Epoch 20:	########################################	elapsed: 0.57s, reconstruction error: 5.66
# Epoch 21:	########################################	elapsed: 0.64s, reconstruction error: 5.66
# Epoch 22:	########################################	elapsed: 0.47s, reconstruction error: 5.57
# Epoch 23:	########################################	elapsed: 0.50s, reconstruction error: 5.58
# Epoch 24:	########################################	elapsed: 0.56s, reconstruction error: 5.52
# Epoch 25:	########################################	elapsed: 0.64s, reconstruction error: 5.64
# Epoch 26:	########################################	elapsed: 0.35s, reconstruction error: 5.49
# Epoch 27:	########################################	elapsed: 0.55s, reconstruction error: 5.36
# Epoch 28:	########################################	elapsed: 0.65s, reconstruction error: 5.44
# Epoch 29:	########################################	elapsed: 0.57s, reconstruction error: 5.39
# Epoch 30:	########################################	elapsed: 0.46s, reconstruction error: 5.47
# Epoch 31:	########################################	elapsed: 0.63s, reconstruction error: 5.44
# Epoch 32:	########################################	elapsed: 0.38s, reconstruction error: 5.39
# Epoch 33:	########################################	elapsed: 0.51s, reconstruction error: 5.21
# Epoch 34:	########################################	elapsed: 0.71s, reconstruction error: 5.26
# Epoch 35:	########################################	elapsed: 0.40s, reconstruction error: 5.28
# Epoch 36:	########################################	elapsed: 0.80s, reconstruction error: 5.20
# Epoch 37:	########################################	elapsed: 0.49s, reconstruction error: 5.17
# Epoch 38:	########################################	elapsed: 0.57s, reconstruction error: 5.23
# Epoch 39:	########################################	elapsed: 0.57s, reconstruction error: 5.17
# Epoch 40:	########################################	elapsed: 0.56s, reconstruction error: 5.19
# Epoch 41:	########################################	elapsed: 0.95s, reconstruction error: 5.22
# Epoch 42:	########################################	elapsed: 0.45s, reconstruction error: 5.14
# Epoch 43:	########################################	elapsed: 0.79s, reconstruction error: 5.09
# Epoch 44:	########################################	elapsed: 0.88s, reconstruction error: 5.05
# Epoch 45:	########################################	elapsed: 0.52s, reconstruction error: 5.03
# Epoch 46:	########################################	elapsed: 0.52s, reconstruction error: 5.08
# Epoch 47:	########################################	elapsed: 0.92s, reconstruction error: 5.05
# Epoch 48:	########################################	elapsed: 0.53s, reconstruction error: 5.10
# Epoch 49:	########################################	elapsed: 0.94s, reconstruction error: 5.07
#
# Learning layer 2
# Epoch 0:	########################################	elapsed: 0.39s, reconstruction error: 14.37
# Epoch 1:	########################################	elapsed: 0.38s, reconstruction error: 10.59
# Epoch 2:	########################################	elapsed: 0.52s, reconstruction error: 9.30
# Epoch 3:	########################################	elapsed: 0.46s, reconstruction error: 8.28
# Epoch 4:	########################################	elapsed: 0.69s, reconstruction error: 7.67
# Epoch 5:	########################################	elapsed: 0.45s, reconstruction error: 6.36
# Epoch 6:	########################################	elapsed: 0.42s, reconstruction error: 5.57
# Epoch 7:	########################################	elapsed: 0.58s, reconstruction error: 5.24
# Epoch 8:	########################################	elapsed: 0.55s, reconstruction error: 4.95
# Epoch 9:	########################################	elapsed: 0.55s, reconstruction error: 4.81
# Epoch 10:	########################################	elapsed: 0.44s, reconstruction error: 4.55
# Epoch 11:	########################################	elapsed: 0.56s, reconstruction error: 4.59
# Epoch 12:	########################################	elapsed: 0.31s, reconstruction error: 4.42
# Epoch 13:	########################################	elapsed: 0.73s, reconstruction error: 4.42
# Epoch 14:	########################################	elapsed: 0.36s, reconstruction error: 4.34
# Epoch 15:	########################################	elapsed: 0.39s, reconstruction error: 4.35
# Epoch 16:	########################################	elapsed: 0.28s, reconstruction error: 4.28
# Epoch 17:	########################################	elapsed: 0.55s, reconstruction error: 4.25
# Epoch 18:	########################################	elapsed: 0.49s, reconstruction error: 4.22
# Epoch 19:	########################################	elapsed: 0.43s, reconstruction error: 4.17
# Epoch 20:	########################################	elapsed: 0.35s, reconstruction error: 4.15
# Epoch 21:	########################################	elapsed: 0.46s, reconstruction error: 4.15
# Epoch 22:	########################################	elapsed: 0.49s, reconstruction error: 4.09
# Epoch 23:	########################################	elapsed: 0.59s, reconstruction error: 4.12
# Epoch 24:	########################################	elapsed: 0.38s, reconstruction error: 4.14
# Epoch 25:	########################################	elapsed: 0.28s, reconstruction error: 4.06
# Epoch 26:	########################################	elapsed: 0.50s, reconstruction error: 4.07
# Epoch 27:	########################################	elapsed: 0.49s, reconstruction error: 4.03
# Epoch 28:	########################################	elapsed: 0.28s, reconstruction error: 4.08
# Epoch 29:	########################################	elapsed: 0.49s, reconstruction error: 4.00
# Epoch 30:	########################################	elapsed: 0.34s, reconstruction error: 4.07
# Epoch 31:	########################################	elapsed: 0.46s, reconstruction error: 3.96
# Epoch 32:	########################################	elapsed: 0.39s, reconstruction error: 3.97
# Epoch 33:	########################################	elapsed: 0.26s, reconstruction error: 4.02
# Epoch 34:	########################################	elapsed: 0.50s, reconstruction error: 4.00
# Epoch 35:	########################################	elapsed: 0.45s, reconstruction error: 4.01
# Epoch 36:	########################################	elapsed: 0.29s, reconstruction error: 4.01
# Epoch 37:	########################################	elapsed: 0.59s, reconstruction error: 3.95
# Epoch 38:	########################################	elapsed: 0.55s, reconstruction error: 3.88
# Epoch 39:	########################################	elapsed: 0.42s, reconstruction error: 3.96
# Epoch 40:	########################################	elapsed: 0.57s, reconstruction error: 3.99
# Epoch 41:	########################################	elapsed: 0.41s, reconstruction error: 3.97
# Epoch 42:	########################################	elapsed: 0.35s, reconstruction error: 3.96
# Epoch 43:	########################################	elapsed: 0.26s, reconstruction error: 3.92
# Epoch 44:	########################################	elapsed: 0.47s, reconstruction error: 3.93
# Epoch 45:	########################################	elapsed: 0.29s, reconstruction error: 3.85
# Epoch 46:	########################################	elapsed: 0.39s, reconstruction error: 3.92
# Epoch 47:	########################################	elapsed: 0.28s, reconstruction error: 3.90
# Epoch 48:	########################################	elapsed: 0.50s, reconstruction error: 3.86
# Epoch 49:	########################################	elapsed: 0.28s, reconstruction error: 3.94
#
# Learning layer 3
# Epoch 0:	########################################	elapsed: 0.21s, reconstruction error: 11.61
# Epoch 1:	########################################	elapsed: 0.19s, reconstruction error: 10.52
# Epoch 2:	########################################	elapsed: 0.13s, reconstruction error: 9.69
# Epoch 3:	########################################	elapsed: 0.13s, reconstruction error: 9.23
# Epoch 4:	########################################	elapsed: 0.16s, reconstruction error: 9.00
# Epoch 5:	########################################	elapsed: 0.20s, reconstruction error: 8.81
# Epoch 6:	########################################	elapsed: 0.13s, reconstruction error: 9.03
# Epoch 7:	########################################	elapsed: 0.20s, reconstruction error: 9.12
# Epoch 8:	########################################	elapsed: 0.12s, reconstruction error: 9.28
# Epoch 9:	########################################	elapsed: 0.12s, reconstruction error: 9.33
# Epoch 10:	########################################	elapsed: 0.12s, reconstruction error: 9.42
# Epoch 11:	########################################	elapsed: 0.10s, reconstruction error: 9.48
# Epoch 12:	########################################	elapsed: 0.14s, reconstruction error: 9.52
# Epoch 13:	########################################	elapsed: 0.17s, reconstruction error: 9.56
# Epoch 14:	########################################	elapsed: 0.15s, reconstruction error: 9.58
# Epoch 15:	########################################	elapsed: 0.13s, reconstruction error: 9.63
# Epoch 16:	########################################	elapsed: 0.11s, reconstruction error: 9.64
# Epoch 17:	########################################	elapsed: 0.22s, reconstruction error: 9.63
# Epoch 18:	########################################	elapsed: 0.13s, reconstruction error: 9.67
# Epoch 19:	########################################	elapsed: 0.13s, reconstruction error: 9.68
# Epoch 20:	########################################	elapsed: 0.11s, reconstruction error: 9.67
# Epoch 21:	########################################	elapsed: 0.12s, reconstruction error: 9.70
# Epoch 22:	########################################	elapsed: 0.47s, reconstruction error: 9.67
# Epoch 23:	########################################	elapsed: 0.29s, reconstruction error: 9.75
# Epoch 24:	########################################	elapsed: 0.26s, reconstruction error: 9.74
# Epoch 25:	########################################	elapsed: 0.16s, reconstruction error: 9.75
# Epoch 26:	########################################	elapsed: 0.13s, reconstruction error: 9.75
# Epoch 27:	########################################	elapsed: 0.12s, reconstruction error: 9.81
# Epoch 28:	########################################	elapsed: 0.22s, reconstruction error: 9.84
# Epoch 29:	########################################	elapsed: 0.17s, reconstruction error: 9.86
# Epoch 30:	########################################	elapsed: 0.15s, reconstruction error: 9.87
# Epoch 31:	########################################	elapsed: 0.15s, reconstruction error: 9.89
# Epoch 32:	########################################	elapsed: 0.24s, reconstruction error: 9.91
# Epoch 33:	########################################	elapsed: 0.13s, reconstruction error: 9.93
# Epoch 34:	########################################	elapsed: 0.23s, reconstruction error: 9.95
# Epoch 35:	########################################	elapsed: 0.13s, reconstruction error: 10.00
# Epoch 36:	########################################	elapsed: 0.13s, reconstruction error: 9.99
# Epoch 37:	########################################	elapsed: 0.12s, reconstruction error: 10.02
# Epoch 38:	########################################	elapsed: 0.17s, reconstruction error: 10.03
# Epoch 39:	########################################	elapsed: 0.15s, reconstruction error: 10.06
# Epoch 40:	########################################	elapsed: 0.14s, reconstruction error: 10.07
# Epoch 41:	########################################	elapsed: 0.11s, reconstruction error: 10.07
# Epoch 42:	########################################	elapsed: 0.11s, reconstruction error: 10.08
# Epoch 43:	########################################	elapsed: 0.18s, reconstruction error: 10.09
# Epoch 44:	########################################	elapsed: 0.12s, reconstruction error: 10.09
# Epoch 45:	########################################	elapsed: 0.11s, reconstruction error: 10.12
# Epoch 46:	########################################	elapsed: 0.12s, reconstruction error: 10.13
# Epoch 47:	########################################	elapsed: 0.21s, reconstruction error: 10.13
# Epoch 48:	########################################	elapsed: 0.23s, reconstruction error: 10.14
# Epoch 49:	########################################	elapsed: 0.15s, reconstruction error: 10.14
# <h3>Finetuning pretrained AE</h3>
# Reconstruction cost before finetuning: 142.19
#
# Epoch 1:	########################################	elapsed: 1.57s, cross-entropy: 109.32
# Epoch 2:	########################################	elapsed: 1.46s, cross-entropy: 105.26
# Epoch 3:	########################################	elapsed: 1.83s, cross-entropy: 102.88
# Epoch 4:	########################################	elapsed: 2.19s, cross-entropy: 101.16
# Epoch 5:	########################################	elapsed: 1.74s, cross-entropy: 99.85
# Epoch 6:	########################################	elapsed: 1.60s, cross-entropy: 98.79
# Epoch 7:	########################################	elapsed: 2.17s, cross-entropy: 97.91
# Epoch 8:	########################################	elapsed: 1.48s, cross-entropy: 97.16
# Epoch 9:	########################################	elapsed: 1.64s, cross-entropy: 96.50
# Epoch 10:	########################################	elapsed: 1.85s, cross-entropy: 95.91
# Epoch 11:	########################################	elapsed: 1.89s, cross-entropy: 95.21
# Epoch 12:	########################################	elapsed: 1.79s, cross-entropy: 94.36
# Epoch 13:	########################################	elapsed: 1.64s, cross-entropy: 93.63
# Epoch 14:	########################################	elapsed: 1.68s, cross-entropy: 92.99
# Epoch 15:	########################################	elapsed: 1.57s, cross-entropy: 92.42
# Epoch 16:	########################################	elapsed: 2.11s, cross-entropy: 91.93
# Epoch 17:	########################################	elapsed: 2.17s, cross-entropy: 91.25
# Epoch 18:	########################################	elapsed: 1.96s, cross-entropy: 90.66
# Epoch 19:	########################################	elapsed: 1.60s, cross-entropy: 90.15
# Epoch 20:	########################################	elapsed: 0.93s, cross-entropy: 89.70
# Epoch 21:	########################################	elapsed: 0.87s, cross-entropy: 89.40
# Epoch 22:	########################################	elapsed: 0.67s, cross-entropy: 88.95
# Epoch 23:	########################################	elapsed: 0.89s, cross-entropy: 88.58
# Epoch 24:	########################################	elapsed: 0.76s, cross-entropy: 88.17
# Epoch 25:	########################################	elapsed: 0.80s, cross-entropy: 87.90
# Epoch 26:	########################################	elapsed: 0.64s, cross-entropy: 87.88
# Epoch 27:	########################################	elapsed: 0.82s, cross-entropy: 87.85
# Epoch 28:	########################################	elapsed: 0.58s, cross-entropy: 87.90
# Epoch 29:	########################################	elapsed: 0.55s, cross-entropy: 88.30
# Epoch 30:	########################################	elapsed: 0.64s, cross-entropy: 88.75
# Epoch 31:	########################################	elapsed: 0.86s, cross-entropy: 89.41
# Epoch 32:	########################################	elapsed: 0.89s, cross-entropy: 89.08
# Epoch 33:	########################################	elapsed: 0.85s, cross-entropy: 88.74
# Epoch 34:	########################################	elapsed: 0.56s, cross-entropy: 88.05
# Epoch 35:	########################################	elapsed: 0.73s, cross-entropy: 87.49
# Epoch 36:	########################################	elapsed: 0.67s, cross-entropy: 87.24
# Epoch 37:	########################################	elapsed: 0.75s, cross-entropy: 87.14
# Epoch 38:	########################################	elapsed: 0.90s, cross-entropy: 86.92
# Epoch 39:	########################################	elapsed: 0.75s, cross-entropy: 86.96
# Epoch 40:	########################################	elapsed: 0.58s, cross-entropy: 86.62
# Epoch 41:	########################################	elapsed: 0.66s, cross-entropy: 86.82
# Epoch 42:	########################################	elapsed: 0.81s, cross-entropy: 86.64
# Epoch 43:	########################################	elapsed: 0.76s, cross-entropy: 86.58
# Epoch 44:	########################################	elapsed: 0.76s, cross-entropy: 86.54
# Epoch 45:	########################################	elapsed: 0.57s, cross-entropy: 86.60
# Epoch 46:	########################################	elapsed: 0.72s, cross-entropy: 86.24
# Epoch 47:	########################################	elapsed: 0.84s, cross-entropy: 86.34
# Epoch 48:	########################################	elapsed: 0.66s, cross-entropy: 86.54
# Epoch 49:	########################################	elapsed: 0.73s, cross-entropy: 86.45
# Epoch 50:	########################################	elapsed: 0.52s, cross-entropy: 86.75
# Training finished!
# <h3>Input minibatch</h3>
# <h3>Pretrained AE reconstructions</h3>
# <h3>Finetuned AE reconstructions</h3>

# %% [markdown]
# # Part 2. Visualization of MNIST digits with an autoencoder

# %%
def run_2d_ae_training(ae: MLP, train_set: np.ndarray, validation_set: np.ndarray, batch_size: int, epochs_count: int) -> None:
    for epoch in range(epochs_count):
        print(f"Epoch {epoch + 1}:", end="\t")

        if epoch == 10:
            for layer in ae:
                layer.momentum = 0.8
        elif epoch == 30:
            for layer in ae:
                layer.momentum = 0.9

        start_time = time.time()
        train_ae(ae, train_set, batch_size)
        elapsed = time.time() - start_time

        xe = xentropy(validation_set[:, :-1], forward_pass(ae, validation_set, False))
        print(f"\telapsed: {elapsed:>2.2f}s, cross-entropy: {xe:>2.2f}")

    print("Training finished!")

# %%
def plot_2d_mnist_scatter(X: np.ndarray, y:np.ndarray) -> None:
    fig, plot = plt.subplots()
    fig.set_size_inches(16, 16)
    plt.prism()

    for i in range(10):
        digit_indeces = y == i
        dim1 = X[digit_indeces, 0]
        dim2 = X[digit_indeces, 1]
        plot.scatter(dim1, dim2, label=str(i))

    plot.set_xticks(())
    plot.set_yticks(())

    plt.tight_layout()
    plt.legend()
    plt.show()

# %%
from IPython.core.display import HTML

def compare_2d_visualizations(
    ae: MLP,
    dbn: DBN,
    train_set: np.ndarray,
    validation_set: np.ndarray,
    validation_labels: np.ndarray,
    monitoring_set: np.ndarray,
    batch_size: int,
    epochs_count: int,
) -> None:
    for layer in ae:
        layer.reset()

    display(HTML("<h3>DBN training</h3>"))
    run_dbn_training(dbn, train_set, monitoring_set, batch_size, epochs_count)

    initialize_ae(ae, dbn)
    dbn_rec_cost = xentropy(
        validation_set[:, :-1], forward_pass(ae, validation_set, False)
    )

    _ = forward_pass(ae, validation_set, False)
    dbn_codes = ae[3].activations[:, :-1]

    display(HTML("<h3>Finetuning pretrained AE</h3>"))

    print("Reconstruction cost before finetuning: {0:>2.2f}\n".format(dbn_rec_cost))
    run_2d_ae_training(ae, train_set, validation_set, batch_size, epochs_count)

    _ = forward_pass(ae, validation_set, False)
    ae_codes = ae[3].activations[:, :-1]

    display(HTML("<h3>2D codes from the pretrained AE</h3>"))
    plot_2d_mnist_scatter(dbn_codes, validation_labels)

    display(HTML("<h3>2D codes from the finetuned AE</h3>"))
    plot_2d_mnist_scatter(ae_codes, validation_labels)

# %%
np.random.seed(1234)

DATASET_SIZE: int = 20000  # 60000 for whole dataset
DIGIT_SIZE: int = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_images = np.random.permutation(mnist_train_images)

mnist_train_images = np.reshape(
    mnist_train_images[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE * DIGIT_SIZE)
)
mnist_train_images = append_ones(mnist_train_images)

monitoring_set_indeces = np.random.choice(
    mnist_train_images.shape[0], 512, replace=False
)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(
    mnist_test_images, newshape=(-1, DIGIT_SIZE * DIGIT_SIZE)
)
mnist_test_images = append_ones(mnist_test_images)
mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE: int = DIGIT_SIZE * DIGIT_SIZE

BATCH_SIZE: int = 128
EPOCHS_COUNT: int = 50

RBM_LEARNING_RATE: float = 0.1
AE_LEARNING_RATE: float = 0.01
AE_MOMENTUM: float = 0.5
L2_PENALTY: float = 0.0002

# %% [markdown]
# ###  Autoencoder network for 2D visualization
#
# Define the autoencoder network for MNIST digits. Use the network structure from the previous part, but change the size of the coding layer to 2 neurons.

# %%
dbn = [
    RestrictedBoltzmannMachine(
        VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY
    ),
    RestrictedBoltzmannMachine(
        256, 128, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY
    ),
    RestrictedBoltzmannMachine(
        128, 64, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY
    ),
    RestrictedBoltzmannMachine(
        64, 2, sigmoid, gaussian, RBM_LEARNING_RATE / 10.0, 0.5, L2_PENALTY
    ),
]

ae: MLP = [
    # encoder
    Layer(
        VISIBLE_LAYER_SIZE,
        256,
        sigmoid,
        sigmoid_derivative,
        AE_LEARNING_RATE,
        AE_MOMENTUM,
        L2_PENALTY,
    ),
    Layer(
        256, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY
    ),
    Layer(
        128, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY
    ),
    Layer(
        64,
        2,
        gaussian,
        gaussian_derivative,
        AE_LEARNING_RATE / 10.0,
        AE_MOMENTUM,
        L2_PENALTY,
    ),
    # decoder (mirrored)
    Layer(
        2,
        64,
        sigmoid,
        sigmoid_derivative,
        AE_LEARNING_RATE / 10.0,
        AE_MOMENTUM,
        L2_PENALTY,
    ),
    Layer(
        64, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY
    ),
    Layer(
        128, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY
    ),
    Layer(
        256,
        VISIBLE_LAYER_SIZE,
        sigmoid,
        sigmoid_derivative,
        AE_LEARNING_RATE,
        AE_MOMENTUM,
        L2_PENALTY,
    ),
]

compare_2d_visualizations(
    ae,
    dbn,
    mnist_train_images,
    mnist_test_images,
    mnist_test_labels,
    monitoring_set,
    BATCH_SIZE,
    EPOCHS_COUNT,
)
# Out:
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 0:	#####################################################	elapsed: 1.06s, reconstruction error: 23.42
# Epoch 1:	#####################################################	elapsed: 0.78s, reconstruction error: 17.97
# Epoch 2:	#####################################################	elapsed: 0.75s, reconstruction error: 15.74
# Epoch 3:	#####################################################	elapsed: 0.91s, reconstruction error: 14.34
# Epoch 4:	#####################################################	elapsed: 0.98s, reconstruction error: 13.26
# Epoch 5:	#####################################################	elapsed: 0.89s, reconstruction error: 11.99
# Epoch 6:	#####################################################	elapsed: 0.82s, reconstruction error: 11.12
# Epoch 7:	#####################################################	elapsed: 0.82s, reconstruction error: 10.52
# Epoch 8:	#####################################################	elapsed: 0.98s, reconstruction error: 10.15
# Epoch 9:	#####################################################	elapsed: 0.82s, reconstruction error: 10.06
# Epoch 10:	#####################################################	elapsed: 0.84s, reconstruction error: 9.65
# Epoch 11:	#####################################################	elapsed: 0.79s, reconstruction error: 9.54
# Epoch 12:	#####################################################	elapsed: 1.17s, reconstruction error: 9.25
# Epoch 13:	#####################################################	elapsed: 1.10s, reconstruction error: 9.27
# Epoch 14:	#####################################################	elapsed: 0.79s, reconstruction error: 9.27
# Epoch 15:	#####################################################	elapsed: 1.09s, reconstruction error: 9.11
# Epoch 16:	#####################################################	elapsed: 1.06s, reconstruction error: 9.17
# Epoch 17:	#####################################################	elapsed: 0.87s, reconstruction error: 9.02
# Epoch 18:	#####################################################	elapsed: 0.83s, reconstruction error: 9.03
# Epoch 19:	#####################################################	elapsed: 0.95s, reconstruction error: 9.05
# Epoch 20:	#####################################################	elapsed: 0.84s, reconstruction error: 8.92
# Epoch 21:	#####################################################	elapsed: 0.85s, reconstruction error: 8.70
# Epoch 22:	#####################################################	elapsed: 0.85s, reconstruction error: 8.89
# Epoch 23:	#####################################################	elapsed: 0.96s, reconstruction error: 8.90
# Epoch 24:	#####################################################	elapsed: 0.94s, reconstruction error: 8.75
# Epoch 25:	#####################################################	elapsed: 0.86s, reconstruction error: 8.72
# Epoch 26:	#####################################################	elapsed: 0.86s, reconstruction error: 8.74
# Epoch 27:	#####################################################	elapsed: 0.97s, reconstruction error: 8.74
# Epoch 28:	#####################################################	elapsed: 0.85s, reconstruction error: 8.72
# Epoch 29:	#####################################################	elapsed: 0.83s, reconstruction error: 8.57
# Epoch 30:	#####################################################	elapsed: 0.87s, reconstruction error: 8.53
# Epoch 31:	#####################################################	elapsed: 0.75s, reconstruction error: 8.54
# Epoch 32:	#####################################################	elapsed: 0.84s, reconstruction error: 8.56
# Epoch 33:	#####################################################	elapsed: 1.02s, reconstruction error: 8.57
# Epoch 34:	#####################################################	elapsed: 0.75s, reconstruction error: 8.57
# Epoch 35:	#####################################################	elapsed: 0.98s, reconstruction error: 8.42
# Epoch 36:	#####################################################	elapsed: 0.91s, reconstruction error: 8.41
# Epoch 37:	#####################################################	elapsed: 0.94s, reconstruction error: 8.49
# Epoch 38:	#####################################################	elapsed: 0.78s, reconstruction error: 8.51
# Epoch 39:	#####################################################	elapsed: 1.02s, reconstruction error: 8.56
# Epoch 40:	#####################################################	elapsed: 0.99s, reconstruction error: 8.43
# Epoch 41:	#####################################################	elapsed: 0.80s, reconstruction error: 8.36
# Epoch 42:	#####################################################	elapsed: 0.96s, reconstruction error: 8.58
# Epoch 43:	#####################################################	elapsed: 0.88s, reconstruction error: 8.30
# Epoch 44:	#####################################################	elapsed: 0.79s, reconstruction error: 8.37
# Epoch 45:	#####################################################	elapsed: 0.81s, reconstruction error: 8.37
# Epoch 46:	#####################################################	elapsed: 0.85s, reconstruction error: 8.37
# Epoch 47:	#####################################################	elapsed: 0.83s, reconstruction error: 8.39
# Epoch 48:	#####################################################	elapsed: 0.76s, reconstruction error: 8.40
# Epoch 49:	#####################################################	elapsed: 0.78s, reconstruction error: 8.42
#
# Learning layer 1
# Epoch 0:	#####################################################	elapsed: 0.40s, reconstruction error: 15.12
# Epoch 1:	#####################################################	elapsed: 0.52s, reconstruction error: 11.68
# Epoch 2:	#####################################################	elapsed: 0.46s, reconstruction error: 9.97
# Epoch 3:	#####################################################	elapsed: 0.38s, reconstruction error: 8.97
# Epoch 4:	#####################################################	elapsed: 0.41s, reconstruction error: 8.28
# Epoch 5:	#####################################################	elapsed: 0.42s, reconstruction error: 7.25
# Epoch 6:	#####################################################	elapsed: 0.65s, reconstruction error: 6.52
# Epoch 7:	#####################################################	elapsed: 0.50s, reconstruction error: 6.23
# Epoch 8:	#####################################################	elapsed: 0.36s, reconstruction error: 5.97
# Epoch 9:	#####################################################	elapsed: 0.40s, reconstruction error: 5.87
# Epoch 10:	#####################################################	elapsed: 0.43s, reconstruction error: 5.58
# Epoch 11:	#####################################################	elapsed: 0.49s, reconstruction error: 5.50
# Epoch 12:	#####################################################	elapsed: 0.49s, reconstruction error: 5.48
# Epoch 13:	#####################################################	elapsed: 0.44s, reconstruction error: 5.34
# Epoch 14:	#####################################################	elapsed: 0.55s, reconstruction error: 5.22
# Epoch 15:	#####################################################	elapsed: 0.50s, reconstruction error: 5.15
# Epoch 16:	#####################################################	elapsed: 0.45s, reconstruction error: 5.08
# Epoch 17:	#####################################################	elapsed: 0.44s, reconstruction error: 5.18
# Epoch 18:	#####################################################	elapsed: 0.38s, reconstruction error: 5.07
# Epoch 19:	#####################################################	elapsed: 0.41s, reconstruction error: 4.97
# Epoch 20:	#####################################################	elapsed: 0.47s, reconstruction error: 4.97
# Epoch 21:	#####################################################	elapsed: 0.55s, reconstruction error: 4.96
# Epoch 22:	#####################################################	elapsed: 0.39s, reconstruction error: 4.99
# Epoch 23:	#####################################################	elapsed: 0.43s, reconstruction error: 4.96
# Epoch 24:	#####################################################	elapsed: 0.41s, reconstruction error: 4.88
# Epoch 25:	#####################################################	elapsed: 0.50s, reconstruction error: 4.96
# Epoch 26:	#####################################################	elapsed: 0.43s, reconstruction error: 4.87
# Epoch 27:	#####################################################	elapsed: 0.41s, reconstruction error: 4.83
# Epoch 28:	#####################################################	elapsed: 0.41s, reconstruction error: 4.86
# Epoch 29:	#####################################################	elapsed: 0.52s, reconstruction error: 4.87
# Epoch 30:	#####################################################	elapsed: 0.51s, reconstruction error: 4.77
# Epoch 31:	#####################################################	elapsed: 0.47s, reconstruction error: 4.85
# Epoch 32:	#####################################################	elapsed: 0.42s, reconstruction error: 4.70
# Epoch 33:	#####################################################	elapsed: 0.38s, reconstruction error: 4.78
# Epoch 34:	#####################################################	elapsed: 0.46s, reconstruction error: 4.78
# Epoch 35:	#####################################################	elapsed: 0.48s, reconstruction error: 4.68
# Epoch 36:	#####################################################	elapsed: 0.54s, reconstruction error: 4.75
# Epoch 37:	#####################################################	elapsed: 0.39s, reconstruction error: 4.78
# Epoch 38:	#####################################################	elapsed: 0.40s, reconstruction error: 4.74
# Epoch 39:	#####################################################	elapsed: 0.48s, reconstruction error: 4.69
# Epoch 40:	#####################################################	elapsed: 0.37s, reconstruction error: 4.63
# Epoch 41:	#####################################################	elapsed: 0.46s, reconstruction error: 4.62
# Epoch 42:	#####################################################	elapsed: 0.38s, reconstruction error: 4.71
# Epoch 43:	#####################################################	elapsed: 0.60s, reconstruction error: 4.76
# Epoch 44:	#####################################################	elapsed: 0.50s, reconstruction error: 4.67
# Epoch 45:	#####################################################	elapsed: 0.47s, reconstruction error: 4.66
# Epoch 46:	#####################################################	elapsed: 0.46s, reconstruction error: 4.68
# Epoch 47:	#####################################################	elapsed: 0.37s, reconstruction error: 4.64
# Epoch 48:	#####################################################	elapsed: 0.48s, reconstruction error: 4.72
# Epoch 49:	#####################################################	elapsed: 0.77s, reconstruction error: 4.61
#
# Learning layer 2
# Epoch 0:	#####################################################	elapsed: 0.29s, reconstruction error: 10.29
# Epoch 1:	#####################################################	elapsed: 0.35s, reconstruction error: 8.17
# Epoch 2:	#####################################################	elapsed: 0.27s, reconstruction error: 6.91
# Epoch 3:	#####################################################	elapsed: 0.30s, reconstruction error: 6.27
# Epoch 4:	#####################################################	elapsed: 0.37s, reconstruction error: 5.87
# Epoch 5:	#####################################################	elapsed: 0.29s, reconstruction error: 5.10
# Epoch 6:	#####################################################	elapsed: 0.41s, reconstruction error: 4.59
# Epoch 7:	#####################################################	elapsed: 0.26s, reconstruction error: 4.49
# Epoch 8:	#####################################################	elapsed: 0.32s, reconstruction error: 4.33
# Epoch 9:	#####################################################	elapsed: 0.27s, reconstruction error: 4.25
# Epoch 10:	#####################################################	elapsed: 0.26s, reconstruction error: 4.19
# Epoch 11:	#####################################################	elapsed: 0.26s, reconstruction error: 4.09
# Epoch 12:	#####################################################	elapsed: 0.27s, reconstruction error: 4.09
# Epoch 13:	#####################################################	elapsed: 0.66s, reconstruction error: 4.07
# Epoch 14:	#####################################################	elapsed: 0.35s, reconstruction error: 3.97
# Epoch 15:	#####################################################	elapsed: 0.27s, reconstruction error: 4.02
# Epoch 16:	#####################################################	elapsed: 0.43s, reconstruction error: 4.01
# Epoch 17:	#####################################################	elapsed: 0.38s, reconstruction error: 4.05
# Epoch 18:	#####################################################	elapsed: 0.33s, reconstruction error: 3.98
# Epoch 19:	#####################################################	elapsed: 0.34s, reconstruction error: 3.96
# Epoch 20:	#####################################################	elapsed: 0.33s, reconstruction error: 3.92
# Epoch 21:	#####################################################	elapsed: 0.39s, reconstruction error: 3.94
# Epoch 22:	#####################################################	elapsed: 0.53s, reconstruction error: 3.92
# Epoch 23:	#####################################################	elapsed: 0.32s, reconstruction error: 3.88
# Epoch 24:	#####################################################	elapsed: 0.28s, reconstruction error: 3.92
# Epoch 25:	#####################################################	elapsed: 0.27s, reconstruction error: 3.90
# Epoch 26:	#####################################################	elapsed: 0.35s, reconstruction error: 3.91
# Epoch 27:	#####################################################	elapsed: 0.35s, reconstruction error: 3.90
# Epoch 28:	#####################################################	elapsed: 0.27s, reconstruction error: 3.86
# Epoch 29:	#####################################################	elapsed: 0.26s, reconstruction error: 3.88
# Epoch 30:	#####################################################	elapsed: 0.30s, reconstruction error: 3.89
# Epoch 31:	#####################################################	elapsed: 0.30s, reconstruction error: 3.85
# Epoch 32:	#####################################################	elapsed: 0.41s, reconstruction error: 3.89
# Epoch 33:	#####################################################	elapsed: 0.37s, reconstruction error: 3.86
# Epoch 34:	#####################################################	elapsed: 0.45s, reconstruction error: 3.87
# Epoch 35:	#####################################################	elapsed: 0.39s, reconstruction error: 3.88
# Epoch 36:	#####################################################	elapsed: 0.29s, reconstruction error: 3.85
# Epoch 37:	#####################################################	elapsed: 0.38s, reconstruction error: 3.93
# Epoch 38:	#####################################################	elapsed: 0.40s, reconstruction error: 3.89
# Epoch 39:	#####################################################	elapsed: 0.27s, reconstruction error: 3.88
# Epoch 40:	#####################################################	elapsed: 0.26s, reconstruction error: 3.83
# Epoch 41:	#####################################################	elapsed: 0.27s, reconstruction error: 3.80
# Epoch 42:	#####################################################	elapsed: 0.26s, reconstruction error: 3.78
# Epoch 43:	#####################################################	elapsed: 0.27s, reconstruction error: 3.85
# Epoch 44:	#####################################################	elapsed: 0.43s, reconstruction error: 3.79
# Epoch 45:	#####################################################	elapsed: 0.51s, reconstruction error: 3.78
# Epoch 46:	#####################################################	elapsed: 0.28s, reconstruction error: 3.84
# Epoch 47:	#####################################################	elapsed: 0.40s, reconstruction error: 3.83
# Epoch 48:	#####################################################	elapsed: 0.31s, reconstruction error: 3.71
# Epoch 49:	#####################################################	elapsed: 0.28s, reconstruction error: 3.79
#
# Learning layer 3
# Epoch 0:	#####################################################	elapsed: 0.16s, reconstruction error: 10.46
# Epoch 1:	#####################################################	elapsed: 0.18s, reconstruction error: 9.56
# Epoch 2:	#####################################################	elapsed: 0.18s, reconstruction error: 9.38
# Epoch 3:	#####################################################	elapsed: 0.19s, reconstruction error: 9.35
# Epoch 4:	#####################################################	elapsed: 0.15s, reconstruction error: 9.37
# Epoch 5:	#####################################################	elapsed: 0.18s, reconstruction error: 9.50
# Epoch 6:	#####################################################	elapsed: 0.20s, reconstruction error: 9.57
# Epoch 7:	#####################################################	elapsed: 0.22s, reconstruction error: 9.59
# Epoch 8:	#####################################################	elapsed: 0.16s, reconstruction error: 9.59
# Epoch 9:	#####################################################	elapsed: 0.17s, reconstruction error: 9.59
# Epoch 10:	#####################################################	elapsed: 0.16s, reconstruction error: 9.60
# Epoch 11:	#####################################################	elapsed: 0.17s, reconstruction error: 9.59
# Epoch 12:	#####################################################	elapsed: 0.17s, reconstruction error: 9.60
# Epoch 13:	#####################################################	elapsed: 0.21s, reconstruction error: 9.60
# Epoch 14:	#####################################################	elapsed: 0.20s, reconstruction error: 9.61
# Epoch 15:	#####################################################	elapsed: 0.26s, reconstruction error: 9.60
# Epoch 16:	#####################################################	elapsed: 0.29s, reconstruction error: 9.61
# Epoch 17:	#####################################################	elapsed: 0.15s, reconstruction error: 9.62
# Epoch 18:	#####################################################	elapsed: 0.15s, reconstruction error: 9.61
# Epoch 19:	#####################################################	elapsed: 0.15s, reconstruction error: 9.63
# Epoch 20:	#####################################################	elapsed: 0.15s, reconstruction error: 9.62
# Epoch 21:	#####################################################	elapsed: 0.14s, reconstruction error: 9.61
# Epoch 22:	#####################################################	elapsed: 0.15s, reconstruction error: 9.61
# Epoch 23:	#####################################################	elapsed: 0.16s, reconstruction error: 9.59
# Epoch 24:	#####################################################	elapsed: 0.22s, reconstruction error: 9.62
# Epoch 25:	#####################################################	elapsed: 0.16s, reconstruction error: 9.61
# Epoch 26:	#####################################################	elapsed: 0.18s, reconstruction error: 9.62
# Epoch 27:	#####################################################	elapsed: 0.15s, reconstruction error: 9.62
# Epoch 28:	#####################################################	elapsed: 0.15s, reconstruction error: 9.62
# Epoch 29:	#####################################################	elapsed: 0.15s, reconstruction error: 9.63
# Epoch 30:	#####################################################	elapsed: 0.16s, reconstruction error: 9.61
# Epoch 31:	#####################################################	elapsed: 0.15s, reconstruction error: 9.62
# Epoch 32:	#####################################################	elapsed: 0.16s, reconstruction error: 9.61
# Epoch 33:	#####################################################	elapsed: 0.15s, reconstruction error: 9.62
# Epoch 34:	#####################################################	elapsed: 0.22s, reconstruction error: 9.60
# Epoch 35:	#####################################################	elapsed: 0.15s, reconstruction error: 9.60
# Epoch 36:	#####################################################	elapsed: 0.16s, reconstruction error: 9.63
# Epoch 37:	#####################################################	elapsed: 0.15s, reconstruction error: 9.62
# Epoch 38:	#####################################################	elapsed: 0.15s, reconstruction error: 9.62
# Epoch 39:	#####################################################	elapsed: 0.15s, reconstruction error: 9.61
# Epoch 40:	#####################################################	elapsed: 0.15s, reconstruction error: 9.61
# Epoch 41:	#####################################################	elapsed: 0.14s, reconstruction error: 9.61
# Epoch 42:	#####################################################	elapsed: 0.21s, reconstruction error: 9.62
# Epoch 43:	#####################################################	elapsed: 0.14s, reconstruction error: 9.62
# Epoch 44:	#####################################################	elapsed: 0.15s, reconstruction error: 9.62
# Epoch 45:	#####################################################	elapsed: 0.14s, reconstruction error: 9.61
# Epoch 46:	#####################################################	elapsed: 0.15s, reconstruction error: 9.62
# Epoch 47:	#####################################################	elapsed: 0.14s, reconstruction error: 9.62
# Epoch 48:	#####################################################	elapsed: 0.19s, reconstruction error: 9.62
# Epoch 49:	#####################################################	elapsed: 0.15s, reconstruction error: 9.63
# <h3>Finetuning pretrained AE</h3>
# Reconstruction cost before finetuning: 238.19
#
# Epoch 1:	########################################	elapsed: 1.31s, cross-entropy: 169.55
# Epoch 2:	########################################	elapsed: 1.25s, cross-entropy: 166.46
# Epoch 3:	########################################	elapsed: 1.30s, cross-entropy: 164.41
# Epoch 4:	########################################	elapsed: 1.28s, cross-entropy: 162.76
# Epoch 5:	########################################	elapsed: 1.27s, cross-entropy: 161.31
# Epoch 6:	########################################	elapsed: 1.28s, cross-entropy: 160.02
# Epoch 7:	########################################	elapsed: 1.34s, cross-entropy: 158.86
# Epoch 8:	########################################	elapsed: 1.24s, cross-entropy: 157.79
# Epoch 9:	########################################	elapsed: 1.24s, cross-entropy: 156.80
# Epoch 10:	########################################	elapsed: 1.31s, cross-entropy: 155.89
# Epoch 11:	########################################	elapsed: 1.26s, cross-entropy: 154.20
# Epoch 12:	########################################	elapsed: 1.25s, cross-entropy: 152.61
# Epoch 13:	########################################	elapsed: 1.28s, cross-entropy: 151.27
# Epoch 14:	########################################	elapsed: 1.24s, cross-entropy: 150.15
# Epoch 15:	########################################	elapsed: 1.32s, cross-entropy: 149.21
# Epoch 16:	########################################	elapsed: 1.28s, cross-entropy: 148.40
# Epoch 17:	########################################	elapsed: 1.38s, cross-entropy: 147.70
# Epoch 18:	########################################	elapsed: 1.40s, cross-entropy: 147.09
# Epoch 19:	########################################	elapsed: 1.66s, cross-entropy: 146.53
# Epoch 20:	########################################	elapsed: 1.37s, cross-entropy: 146.01
# Epoch 21:	########################################	elapsed: 1.29s, cross-entropy: 145.53
# Epoch 22:	########################################	elapsed: 1.71s, cross-entropy: 145.08
# Epoch 23:	########################################	elapsed: 1.16s, cross-entropy: 144.66
# Epoch 24:	########################################	elapsed: 1.43s, cross-entropy: 144.27
# Epoch 25:	########################################	elapsed: 1.42s, cross-entropy: 143.91
# Epoch 26:	########################################	elapsed: 1.24s, cross-entropy: 143.58
# Epoch 27:	########################################	elapsed: 1.33s, cross-entropy: 143.26
# Epoch 28:	########################################	elapsed: 1.34s, cross-entropy: 142.96
# Epoch 29:	########################################	elapsed: 1.53s, cross-entropy: 142.67
# Epoch 30:	########################################	elapsed: 1.45s, cross-entropy: 142.39
# Epoch 31:	########################################	elapsed: 1.24s, cross-entropy: 142.15
# Epoch 32:	########################################	elapsed: 1.49s, cross-entropy: 141.71
# Epoch 33:	########################################	elapsed: 1.31s, cross-entropy: 141.29
# Epoch 34:	########################################	elapsed: 1.41s, cross-entropy: 140.88
# Epoch 35:	########################################	elapsed: 1.37s, cross-entropy: 140.54
# Epoch 36:	########################################	elapsed: 1.38s, cross-entropy: 140.17
# Epoch 37:	########################################	elapsed: 1.43s, cross-entropy: 139.85
# Epoch 38:	########################################	elapsed: 1.31s, cross-entropy: 139.58
# Epoch 39:	########################################	elapsed: 1.24s, cross-entropy: 139.29
# Epoch 40:	########################################	elapsed: 1.49s, cross-entropy: 138.99
# Epoch 41:	########################################	elapsed: 1.34s, cross-entropy: 138.76
# Epoch 42:	########################################	elapsed: 1.40s, cross-entropy: 138.58
# Epoch 43:	########################################	elapsed: 1.21s, cross-entropy: 138.38
# Epoch 44:	########################################	elapsed: 1.34s, cross-entropy: 138.10
# Epoch 45:	########################################	elapsed: 1.32s, cross-entropy: 137.95
# Epoch 46:	########################################	elapsed: 1.44s, cross-entropy: 137.73
# Epoch 47:	########################################	elapsed: 1.30s, cross-entropy: 137.58
# Epoch 48:	########################################	elapsed: 1.40s, cross-entropy: 137.40
# Epoch 49:	########################################	elapsed: 1.29s, cross-entropy: 137.29
# Epoch 50:	########################################	elapsed: 1.31s, cross-entropy: 137.18
# Training finished!
# <h3>2D codes from the pretrained AE</h3>
# <h3>2D codes from the finetuned AE</h3>
