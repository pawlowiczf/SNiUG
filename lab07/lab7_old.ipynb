# %%
import time

import numpy as np
import matplotlib.pyplot as plt

from abc import abstractmethod, ABC
from typing import Sequence, Optional

from numpy.typing import NDArray

np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
# def append_ones(matrix):
#     return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=1)


def zeros(*dims: int) -> NDArray:
    return np.zeros(shape=tuple(dims), dtype=np.float32)


def ones(*dims: int) -> NDArray:
    return np.ones(shape=tuple(dims), dtype=np.float32)


def rand(*dims: int) -> NDArray:
    return np.random.rand(*dims).astype(np.float32)


def chunks(seq: NDArray, size: int):
    return (seq[pos : pos + size] for pos in range(0, len(seq), size))


def as_matrix(vector: NDArray) -> NDArray:
    return np.reshape(vector, (-1, 1))


def one_hot_encode(labels: NDArray) -> NDArray:
    one_hot = zeros(labels.shape[0], np.max(labels) + 1)
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)


def tiles(examples: NDArray):
    space = 2
    rows, cols, h, w = examples.shape

    img_matrix = np.empty(shape=(rows * (h + space) - space, cols * (h + space) - space))
    img_matrix.fill(np.nan)

    for r in range(rows):
        for c in range(cols):
            x_0 = r * (h + space)
            y_0 = c * (w + space)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0 : x_0 + h, y_0 : y_0 + w] = (examples[r, c] - ex_min) / (ex_max - ex_min)

    plt.matshow(img_matrix, cmap="gray", interpolation="none")
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(x: np.ndarray) -> np.ndarray:
    return 1.0 / (1.0 + np.exp(-x))


def sigmoid_derivative(x: np.ndarray) -> np.ndarray:
    s = sigmoid(x)
    return s * (1.0 - s)

# %% [markdown]
# # MNIST dataset

# %%
from mnists import MNIST

mnist = MNIST()
digits = mnist.train_images()
digits = digits[: 12 * 24]
digits = digits.reshape(-1, 24, 28, 28)
tiles(digits)

# %% [markdown]
# # Part 1: $L^1$ and $L^2$ penalties

# %%
class RBM:
    def __init__(
        self,
        vsize: int,
        hsize: int,
        lr: float,
        momentum: float,
        l1_penalty: float,
        l2_penalty: float,
    ):
        # Variables' sizes
        self.vsize = vsize
        self.hsize = hsize
        # Training hyper-params
        self.lr = lr
        self.momentum = momentum
        self.l1_penalty = l1_penalty
        self.l2_penalty = l2_penalty
        # Initialize
        self.reset()

    def reset(self):
        # Xavier initialization
        scale = np.sqrt(6 / (self.vsize + self.hsize))
        self.w = np.random.uniform(-scale, +scale, size=(self.vsize, self.hsize)).astype(np.float32)

        # Zero initialization
        self.b = zeros(self.vsize)
        self.c = zeros(self.hsize)

        # Velocity (momentum) tensor initialization
        self.m_w = zeros(self.vsize, self.hsize)
        self.m_b = zeros(self.vsize)
        self.m_c = zeros(self.hsize)

    def probas_v(self, h: NDArray) -> NDArray:
        return sigmoid(self.b + h @ self.w.T)

    def probas_h(self, v: NDArray) -> NDArray:
        return sigmoid(self.c + v @ self.w)

    def sample(self, v: NDArray, steps: int) -> NDArray:
        batch_size = v.shape[0]
        # --- Gibbs sampling
        for k in range(steps):
            h = self.probas_h(v) > rand(batch_size, self.hsize)
            σ = self.probas_v(h)
            if k < steps - 1:
                v = σ > rand(batch_size, self.vsize)

        return σ

# %%
def reconstuction_error(rbm: RBM, v: NDArray) -> float:
    batch_size = v.shape[0]
    σ = rbm.sample(v, steps=1)
    return 1 / batch_size * np.sum((v - σ) ** 2)

# %% [markdown]
# ### CDK with regulatization
#
# Implement the Contrastive Divergence algorithm with $L^1$ and $L^2$ penalties. If
# ```python
# rbm.l1_penalty > 0
# ```
# the algorithm should constrain the weights with $L^1$ penalty. Otherwise, if
# ```python
# rbm.l2_penalty > 0
# ```
# the algorithm should constrain the weights with $L^2$ penalty.
#
# Do **not** apply the penalties to the biases!

# %%
def cdk(rbm: RBM, minibatch: NDArray, k: int = 1):
    batch_size = minibatch.shape[0]
    v = minibatch

    # Compute gradients
    # -----------------

    # Positive phase
    σ = rbm.probas_h(v)

    grad_w = -1 / batch_size * (v.T @ σ)
    grad_b = -1 / batch_size * (v.sum(axis=0))
    grad_c = -1 / batch_size * (σ.sum(axis=0))

    # Negative phase

    # --- Gibbs sampling
    h = σ > rand(batch_size, rbm.hsize)
    v = rbm.probas_v(h) > rand(batch_size, rbm.vsize)
    for _ in range(k - 1):
        h = rbm.probas_h(v) > rand(batch_size, rbm.hsize)
        v = rbm.probas_v(h) > rand(batch_size, rbm.vsize)

    # --- Negative gradient estimation
    σ = rbm.probas_h(v)

    grad_w += 1 / batch_size * (v.T @ σ)
    grad_b += 1 / batch_size * (v.sum(axis=0))
    grad_c += 1 / batch_size * (σ.sum(axis=0))

    # Apply L1 / L2 regularization
    # ----------------------------
    grad_w += rbm.l1_penalty * np.sign(rbm.w) + rbm.l2_penalty * rbm.w

    # Update params
    # -------------
    rbm.m_w = rbm.momentum * rbm.m_w - rbm.lr * grad_w
    rbm.m_b = rbm.momentum * rbm.m_b - rbm.lr * grad_b
    rbm.m_c = rbm.momentum * rbm.m_c - rbm.lr * grad_c

    rbm.w += rbm.m_w
    rbm.b += rbm.m_b
    rbm.c += rbm.m_c

# %% [markdown]
# ## Comparison of regularization penalties

# %%
def train_epoch(rbm: RBM, dataset: NDArray, batch_size: int):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 40) == 0:
            print("#", end="")


def run_training(
    rbm: RBM,
    dataset: NDArray,
    monitoring_set: NDArray,
    batch_size: int,
    epochs_count: int,
):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch + 1), end="\t")

        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time

        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")


def draw_filters(rbm: RBM):
    filters = rbm.w.T
    filters = filters.reshape(8, -1, 28, 28)
    tiles(filters)

# %%
DATASET_SIZE = 20000  # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE * DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = mnist_train[:DATASET_SIZE]
dataset = dataset.reshape(DATASET_SIZE, DIGIT_SIZE * DIGIT_SIZE)
# dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

# %% [markdown]
# ### RBM with no regularization

# %%
L1_PENALTY = 0.0
L2_PENALTY = 0.0

np.random.seed(1234)
rbm_plain = RBM(
    VISIBLE_LAYER_SIZE,
    HIDDEN_LAYER_SIZE,
    LEARNING_RATE,
    MOMENTUM,
    L1_PENALTY,
    L2_PENALTY,
)

run_training(rbm_plain, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 0.58s, reconstruction error: 24.28
# Epoch 2:	########################################	elapsed: 0.61s, reconstruction error: 20.35
# Epoch 3:	########################################	elapsed: 0.56s, reconstruction error: 18.09
# Epoch 4:	########################################	elapsed: 0.57s, reconstruction error: 16.83
# Epoch 5:	########################################	elapsed: 0.56s, reconstruction error: 16.03
# Epoch 6:	########################################	elapsed: 0.56s, reconstruction error: 15.15
# Epoch 7:	########################################	elapsed: 0.57s, reconstruction error: 13.88
# Epoch 8:	########################################	elapsed: 0.56s, reconstruction error: 13.29
# Epoch 9:	########################################	elapsed: 0.56s, reconstruction error: 12.78
# Epoch 10:	########################################	elapsed: 0.57s, reconstruction error: 12.41
# Epoch 11:	########################################	elapsed: 0.56s, reconstruction error: 11.90
# Epoch 12:	########################################	elapsed: 0.57s, reconstruction error: 11.81
# Epoch 13:	########################################	elapsed: 0.57s, reconstruction error: 11.52
# Epoch 14:	########################################	elapsed: 0.57s, reconstruction error: 11.54
# Epoch 15:	########################################	elapsed: 0.58s, reconstruction error: 11.14
# Epoch 16:	########################################	elapsed: 0.57s, reconstruction error: 11.30
# Epoch 17:	########################################	elapsed: 0.57s, reconstruction error: 11.05
# Epoch 18:	########################################	elapsed: 0.57s, reconstruction error: 11.03
# Epoch 19:	########################################	elapsed: 0.67s, reconstruction error: 10.84
# Epoch 20:	########################################	elapsed: 0.57s, reconstruction error: 10.91
# Epoch 21:	########################################	elapsed: 0.57s, reconstruction error: 10.69
# Epoch 22:	########################################	elapsed: 0.57s, reconstruction error: 10.68
# Epoch 23:	########################################	elapsed: 0.57s, reconstruction error: 10.56
# Epoch 24:	########################################	elapsed: 0.58s, reconstruction error: 10.73
# Epoch 25:	########################################	elapsed: 0.57s, reconstruction error: 10.49
# Epoch 26:	########################################	elapsed: 0.57s, reconstruction error: 10.51
# Epoch 27:	########################################	elapsed: 0.56s, reconstruction error: 10.56
# Epoch 28:	########################################	elapsed: 0.57s, reconstruction error: 10.49
# Epoch 29:	########################################	elapsed: 0.58s, reconstruction error: 10.51
# Epoch 30:	########################################	elapsed: 0.56s, reconstruction error: 10.45
# Epoch 31:	########################################	elapsed: 0.58s, reconstruction error: 10.46
# Epoch 32:	########################################	elapsed: 0.57s, reconstruction error: 10.18
# Epoch 33:	########################################	elapsed: 0.57s, reconstruction error: 10.15
# Epoch 34:	########################################	elapsed: 0.66s, reconstruction error: 10.28
# Epoch 35:	########################################	elapsed: 0.57s, reconstruction error: 10.34
# Epoch 36:	########################################	elapsed: 0.58s, reconstruction error: 10.22
# Epoch 37:	########################################	elapsed: 0.60s, reconstruction error: 10.18
# Epoch 38:	########################################	elapsed: 0.60s, reconstruction error: 9.94
# Epoch 39:	########################################	elapsed: 0.59s, reconstruction error: 9.95
# Epoch 40:	########################################	elapsed: 0.58s, reconstruction error: 10.22
# Epoch 41:	########################################	elapsed: 0.59s, reconstruction error: 10.29
# Epoch 42:	########################################	elapsed: 0.58s, reconstruction error: 10.14
# Epoch 43:	########################################	elapsed: 0.59s, reconstruction error: 10.27
# Epoch 44:	########################################	elapsed: 0.61s, reconstruction error: 10.04
# Epoch 45:	########################################	elapsed: 0.64s, reconstruction error: 10.17
# Epoch 46:	########################################	elapsed: 0.59s, reconstruction error: 10.05
# Epoch 47:	########################################	elapsed: 0.59s, reconstruction error: 9.99
# Epoch 48:	########################################	elapsed: 0.60s, reconstruction error: 10.07
# Epoch 49:	########################################	elapsed: 0.72s, reconstruction error: 10.03
# Epoch 50:	########################################	elapsed: 0.56s, reconstruction error: 10.04
# Training finished!

# %% [markdown]
# ### RBM with $L^1$ penalty

# %%
L1_PENALTY = 0.0001
L2_PENALTY = 0.0

np.random.seed(1234)
rbm_l1 = RBM(
    VISIBLE_LAYER_SIZE,
    HIDDEN_LAYER_SIZE,
    LEARNING_RATE,
    MOMENTUM,
    L1_PENALTY,
    L2_PENALTY,
)

run_training(rbm_l1, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 0.65s, reconstruction error: 24.34
# Epoch 2:	########################################	elapsed: 0.56s, reconstruction error: 20.33
# Epoch 3:	########################################	elapsed: 0.58s, reconstruction error: 18.11
# Epoch 4:	########################################	elapsed: 0.62s, reconstruction error: 16.87
# Epoch 5:	########################################	elapsed: 0.66s, reconstruction error: 15.94
# Epoch 6:	########################################	elapsed: 0.58s, reconstruction error: 15.12
# Epoch 7:	########################################	elapsed: 0.62s, reconstruction error: 13.85
# Epoch 8:	########################################	elapsed: 0.57s, reconstruction error: 13.11
# Epoch 9:	########################################	elapsed: 0.59s, reconstruction error: 12.66
# Epoch 10:	########################################	elapsed: 0.56s, reconstruction error: 12.21
# Epoch 11:	########################################	elapsed: 0.57s, reconstruction error: 12.06
# Epoch 12:	########################################	elapsed: 0.57s, reconstruction error: 11.86
# Epoch 13:	########################################	elapsed: 0.56s, reconstruction error: 11.42
# Epoch 14:	########################################	elapsed: 0.56s, reconstruction error: 11.44
# Epoch 15:	########################################	elapsed: 0.57s, reconstruction error: 11.23
# Epoch 16:	########################################	elapsed: 0.56s, reconstruction error: 11.22
# Epoch 17:	########################################	elapsed: 0.60s, reconstruction error: 10.98
# Epoch 18:	########################################	elapsed: 0.59s, reconstruction error: 11.08
# Epoch 19:	########################################	elapsed: 0.57s, reconstruction error: 10.98
# Epoch 20:	########################################	elapsed: 0.62s, reconstruction error: 10.93
# Epoch 21:	########################################	elapsed: 0.58s, reconstruction error: 10.55
# Epoch 22:	########################################	elapsed: 0.58s, reconstruction error: 10.71
# Epoch 23:	########################################	elapsed: 0.63s, reconstruction error: 10.56
# Epoch 24:	########################################	elapsed: 0.57s, reconstruction error: 10.69
# Epoch 25:	########################################	elapsed: 0.60s, reconstruction error: 10.60
# Epoch 26:	########################################	elapsed: 0.70s, reconstruction error: 10.47
# Epoch 27:	########################################	elapsed: 0.61s, reconstruction error: 10.63
# Epoch 28:	########################################	elapsed: 0.58s, reconstruction error: 10.39
# Epoch 29:	########################################	elapsed: 0.59s, reconstruction error: 10.48
# Epoch 30:	########################################	elapsed: 0.58s, reconstruction error: 10.44
# Epoch 31:	########################################	elapsed: 0.62s, reconstruction error: 10.32
# Epoch 32:	########################################	elapsed: 0.93s, reconstruction error: 10.06
# Epoch 33:	########################################	elapsed: 0.80s, reconstruction error: 10.08
# Epoch 34:	########################################	elapsed: 0.59s, reconstruction error: 10.08
# Epoch 35:	########################################	elapsed: 0.58s, reconstruction error: 10.07
# Epoch 36:	########################################	elapsed: 0.61s, reconstruction error: 10.10
# Epoch 37:	########################################	elapsed: 0.58s, reconstruction error: 10.14
# Epoch 38:	########################################	elapsed: 0.65s, reconstruction error: 10.05
# Epoch 39:	########################################	elapsed: 0.56s, reconstruction error: 10.07
# Epoch 40:	########################################	elapsed: 0.61s, reconstruction error: 10.09
# Epoch 41:	########################################	elapsed: 0.60s, reconstruction error: 10.23
# Epoch 42:	########################################	elapsed: 0.56s, reconstruction error: 10.06
# Epoch 43:	########################################	elapsed: 0.58s, reconstruction error: 10.12
# Epoch 44:	########################################	elapsed: 0.61s, reconstruction error: 9.91
# Epoch 45:	########################################	elapsed: 0.60s, reconstruction error: 9.93
# Epoch 46:	########################################	elapsed: 0.58s, reconstruction error: 9.95
# Epoch 47:	########################################	elapsed: 0.61s, reconstruction error: 9.98
# Epoch 48:	########################################	elapsed: 0.60s, reconstruction error: 10.00
# Epoch 49:	########################################	elapsed: 0.62s, reconstruction error: 10.05
# Epoch 50:	########################################	elapsed: 0.77s, reconstruction error: 10.03
# Training finished!

# %% [markdown]
# ### RBM with $L^2$ penalty

# %%
L1_PENALTY = 0.0
L2_PENALTY = 0.0005

np.random.seed(1234)
rbm_l2 = RBM(
    VISIBLE_LAYER_SIZE,
    HIDDEN_LAYER_SIZE,
    LEARNING_RATE,
    MOMENTUM,
    L1_PENALTY,
    L2_PENALTY,
)

run_training(rbm_l2, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)
# Out:
# Epoch 1:	########################################	elapsed: 0.83s, reconstruction error: 24.37
# Epoch 2:	########################################	elapsed: 0.58s, reconstruction error: 20.36
# Epoch 3:	########################################	elapsed: 0.65s, reconstruction error: 18.16
# Epoch 4:	########################################	elapsed: 0.68s, reconstruction error: 16.92
# Epoch 5:	########################################	elapsed: 0.79s, reconstruction error: 16.09
# Epoch 6:	########################################	elapsed: 0.60s, reconstruction error: 15.15
# Epoch 7:	########################################	elapsed: 0.59s, reconstruction error: 13.99
# Epoch 8:	########################################	elapsed: 0.60s, reconstruction error: 13.32
# Epoch 9:	########################################	elapsed: 0.58s, reconstruction error: 12.88
# Epoch 10:	########################################	elapsed: 0.60s, reconstruction error: 12.41
# Epoch 11:	########################################	elapsed: 0.86s, reconstruction error: 12.17
# Epoch 12:	########################################	elapsed: 0.62s, reconstruction error: 12.16
# Epoch 13:	########################################	elapsed: 0.55s, reconstruction error: 11.75
# Epoch 14:	########################################	elapsed: 0.60s, reconstruction error: 11.74
# Epoch 15:	########################################	elapsed: 0.63s, reconstruction error: 11.26
# Epoch 16:	########################################	elapsed: 0.55s, reconstruction error: 11.47
# Epoch 17:	########################################	elapsed: 0.58s, reconstruction error: 11.15
# Epoch 18:	########################################	elapsed: 0.64s, reconstruction error: 11.35
# Epoch 19:	########################################	elapsed: 0.71s, reconstruction error: 11.05
# Epoch 20:	########################################	elapsed: 0.55s, reconstruction error: 11.19
# Epoch 21:	########################################	elapsed: 0.61s, reconstruction error: 10.80
# Epoch 22:	########################################	elapsed: 0.58s, reconstruction error: 10.83
# Epoch 23:	########################################	elapsed: 0.58s, reconstruction error: 10.79
# Epoch 24:	########################################	elapsed: 0.56s, reconstruction error: 10.83
# Epoch 25:	########################################	elapsed: 0.58s, reconstruction error: 10.77
# Epoch 26:	########################################	elapsed: 0.59s, reconstruction error: 10.69
# Epoch 27:	########################################	elapsed: 0.56s, reconstruction error: 10.70
# Epoch 28:	########################################	elapsed: 0.58s, reconstruction error: 10.55
# Epoch 29:	########################################	elapsed: 0.56s, reconstruction error: 10.65
# Epoch 30:	########################################	elapsed: 0.58s, reconstruction error: 10.45
# Epoch 31:	########################################	elapsed: 0.78s, reconstruction error: 10.37
# Epoch 32:	########################################	elapsed: 0.59s, reconstruction error: 10.29
# Epoch 33:	########################################	elapsed: 0.80s, reconstruction error: 10.33
# Epoch 34:	########################################	elapsed: 0.58s, reconstruction error: 10.32
# Epoch 35:	########################################	elapsed: 0.63s, reconstruction error: 10.52
# Epoch 36:	########################################	elapsed: 0.58s, reconstruction error: 10.21
# Epoch 37:	########################################	elapsed: 0.56s, reconstruction error: 10.41
# Epoch 38:	########################################	elapsed: 0.58s, reconstruction error: 10.21
# Epoch 39:	########################################	elapsed: 0.57s, reconstruction error: 10.18
# Epoch 40:	########################################	elapsed: 0.55s, reconstruction error: 10.29
# Epoch 41:	########################################	elapsed: 0.56s, reconstruction error: 10.48
# Epoch 42:	########################################	elapsed: 0.62s, reconstruction error: 10.05
# Epoch 43:	########################################	elapsed: 0.58s, reconstruction error: 10.24
# Epoch 44:	########################################	elapsed: 0.57s, reconstruction error: 10.07
# Epoch 45:	########################################	elapsed: 0.56s, reconstruction error: 10.15
# Epoch 46:	########################################	elapsed: 0.64s, reconstruction error: 10.08
# Epoch 47:	########################################	elapsed: 0.56s, reconstruction error: 10.08
# Epoch 48:	########################################	elapsed: 0.79s, reconstruction error: 10.10
# Epoch 49:	########################################	elapsed: 0.56s, reconstruction error: 10.03
# Epoch 50:	########################################	elapsed: 0.61s, reconstruction error: 10.18
# Training finished!

# %% [markdown]
# ### Plain filters

# %%
draw_filters(rbm_plain)

# %% [markdown]
# ### $L^1$ filters

# %%
draw_filters(rbm_l1)

# %% [markdown]
# ### $L^2$ filters

# %%
draw_filters(rbm_l2)

# %% [markdown]
# # Part 2: MLP pretraining

# %%
def softmax(x: NDArray) -> NDArray:
    m = x.max(axis=1, keepdims=True)
    y = np.exp(x - m)
    return y / y.sum(axis=1, keepdims=True)

# %%
class Layer(ABC):
    # Outputs of the layer after forward pass
    y: Optional[NDArray]

    @abstractmethod
    def reset(self, *args, **kwargs):
        """Initialize the layer."""
        raise NotImplementedError

    @abstractmethod
    def forward(self, x: NDArray) -> NDArray:
        """Propagate the input `x` forward through the layer and save the output in `self.y`."""
        raise NotImplementedError

    @abstractmethod
    def backward(self, x: NDArray, grad_y: NDArray) -> NDArray:
        """
        Given layer input `x` and ∂Loss/∂y (`grad_y`)
            * compute ∂Loss/∂x and ∂Loss/∂θ (where θ are the layer's params;
            * update parameters using (momentum) SGD;
            * return ∂Loss/∂x;

        NOTE: We assume that the layers are connected in a simple path (i.e. the computation graph
        is linear) and thus we don't have to keep and accumulate the gradients ∂Loss/∂y in the layer
        itself, but can instead just dynamically pass ∂Loss/∂y while traversing this linear
        computation graph.
        """
        raise NotImplementedError

# %%
class Sigmoid(Layer):
    def __init__(self):
        self.reset()

    def reset(self):
        # Outputs
        self.y: Optional[NDArray] = None

    def forward(self, x: NDArray) -> NDArray:
        self.y = 1.0 / (1.0 + np.exp(-x))
        return self.y

    def backward(self, x: NDArray, grad_y: NDArray) -> NDArray:
        # --- Compute ∂Loss/∂x
        grad_x = grad_y * (self.y * (1.0 - self.y))

        # --- Propagate ∂Loss/∂x backward
        return grad_x


class Linear(Layer):
    def __init__(self, vsize: int, hsize: int, lr: float, momentum: float, l2_penalty: float):
        self.vsize: int = vsize
        self.hsize: int = hsize
        self.lr: float = lr
        self.momentum: float = momentum
        self.l2_penalty: float = l2_penalty
        self.reset()

    def reset(self):
        # Weights initialization
        scale = np.sqrt(6 / (self.vsize + self.hsize))
        self.w = np.random.uniform(-scale, +scale, size=(self.vsize, self.hsize)).astype(np.float32)
        # self.w = np.random.normal(0, 0.01, size=(self.vsize, self.hsize)).astype(np.float32)
        # Biases initialization
        self.b = zeros(self.hsize)
        # Velocity (momentum) tensors initialization
        self.m_w = zeros(self.vsize, self.hsize)
        self.m_b = zeros(self.hsize)
        # Outputs
        self.y: Optional[NDArray] = None

    def forward(self, x: NDArray) -> NDArray:
        self.y = self.b + x @ self.w
        return self.y

    def backward(self, x: NDArray, grad_y: NDArray) -> NDArray:
        # --- Compute ∂Loss/∂x
        grad_x = grad_y @ self.w.T

        # --- Compute  ∂Loss/∂w and ∂Loss/∂b
        grad_w = x.T @ grad_y
        grad_b = grad_y.sum(axis=0)

        # --- Penalties
        grad_w += self.l2_penalty * self.w

        # --- Update params
        self.m_w = self.momentum * self.m_w - self.lr * grad_w
        self.m_b = self.momentum * self.m_b - self.lr * grad_b

        self.w += self.m_w
        self.b += self.m_b

        # --- Propagate ∂Loss/∂x backward
        return grad_x

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp: Sequence[Layer], x: NDArray) -> NDArray:
    for layer in mlp:
        x = layer.forward(x)
    return x

# %% [markdown]
# ### Error backpropagation
#
# Extend the implementation of error backpropagation (from Lab 6) with $L^2$ penalty. Apply the penalty when:
# ```python
# rbm.l2_penalty > 0
# ```
#
# Do **not** apply the penalty to the biases.

# %%
def error_backpropagate(mlp: Sequence[Layer], batch: NDArray, grad_y: NDArray):
    for i in reversed(range(len(mlp))):
        # --- Get input to the i-th layer i.e. output of the (i-1)-th layer (or `batch` if i=0)
        x = mlp[i - 1].y if i > 0 else batch

        # --- Propagate the ∂Loss/∂y backward through layer `i` and update params
        grad_y = mlp[i].backward(x, grad_y)

# %% [markdown]
# ### MLP training

# %%
def train_mlp(mlp: Sequence[Layer], dataset: NDArray, labels: NDArray, batch_size: int):
    batches_limit = dataset.shape[0] / batch_size

    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)

    for batch_idx, (X_batch, t_batch) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        # NOTE: in this implementation mlp returns *mlogits* and not probabilities
        y = forward_pass(mlp, X_batch)

        # Compute ∂Loss/∂y for the last layer i.e. the output of the whole network assuming the loss
        # function is the cross entropy function.
        # NOTE: in this implementation mlp returns *mlogits* and thus we need to pass `y` through
        # the softmax function to compute the appropriate gradients.
        grad_y = 1 / len(X_batch) * (softmax(y) - t_batch)

        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, X_batch, grad_y)

        if batch_idx % round(batches_limit / 50) == 0:
            print("#", end="")

# %%
def classify(mlp: Sequence[Layer], batch: NDArray) -> NDArray:
    mlogits = forward_pass(mlp, batch)
    return np.argmax(mlogits, axis=1)


def run_mlp_training(
    mlp: Sequence[Layer],
    X_train: NDArray,
    t_train: NDArray,
    X_valid: NDArray,
    t_valid: NDArray,
    batch_size: int,
    epochs_count: int,
):

    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch + 1), end="\t")

        if epoch == 5:
            for layer in mlp:
                layer.momentum = 0.9

        start_time = time.time()
        train_mlp(mlp, X_train, t_train, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, X_valid)
        accuracy = np.sum(predictions == t_valid) / predictions.shape[0]
        print("\telapsed: {0:>2.2}s, accuracy: {1:>2.2%}".format(elapsed, accuracy))

    print("Training finished!")


def draw_layer_filters(layer: Linear):
    filters = layer.w.T
    filters = filters.reshape(8, -1, 28, 28)
    tiles(filters)

# %% [markdown]
# ## DBN Pretraining

# %%
def propagate_up(dbn: Sequence[RBM], n_layers: int, v: NDArray) -> NDArray:
    assert 0 <= n_layers < len(dbn)
    for i in range(n_layers):
        v = dbn[i].probas_h(v)
    return v


def propagate_dn(dbn: Sequence[RBM], n_layers: int, h: NDArray) -> NDArray:
    assert 0 <= n_layers < len(dbn)
    for i in reversed(range(n_layers)):
        h = dbn[i].probas_v(h)
    return h

# %%
def dbn_reconstuction_error(dbn: Sequence[RBM], n_layers: int, minibatch: NDArray) -> float:
    assert 0 <= n_layers < len(dbn)
    visible = propagate_up(dbn, n_layers, minibatch)
    return reconstuction_error(dbn[n_layers], visible)

# %%
def train_dbn_layer(dbn: Sequence[RBM], layer_idx: int, dataset: NDArray, batch_size: int):
    dataset = propagate_up(dbn, layer_idx, dataset)
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0:
            print("#", end="")

# %%
def train_dbn(dbn, dataset, monitoring_set, batch_size, epochs_count):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx))

        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch + 1), end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = 0.9

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# ##  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp(mlp: Sequence[Layer], dbn: Sequence[RBM]):
    linear_layers = [layer for layer in mlp if isinstance(layer, Linear)]
    for layer, rbm in zip(linear_layers, dbn):
        layer.w = rbm.w.copy()
        layer.b = rbm.c.copy()

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 10_000  # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE * DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = mnist_train_images[:DATASET_SIZE]
mnist_train_images = mnist_train_images.reshape(DATASET_SIZE, DIGIT_SIZE * DIGIT_SIZE)
# mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = mnist_test_images.reshape(-1, DIGIT_SIZE * DIGIT_SIZE)
# mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %% [markdown]
# ### Plain vs pretrained MLP comparison

# %%
from IPython.core.display import HTML


def compare_pretraining_results(
    mlp: Sequence[Layer],
    dbn: Sequence[RBM],
    X_train: NDArray,
    t_train: NDArray,
    X_valid: NDArray,
    t_valid: NDArray,
    monitoring_set: NDArray,
    batch_size: int,
    epochs_count: int,
):
    for layer in mlp:
        layer.reset()

    display(HTML("<h3>Plain MLP training</h3>"))
    run_mlp_training(mlp, X_train, t_train, X_valid, t_valid, batch_size, epochs_count)

    display(HTML("<h3>Input layer filters in the plain MLP</h3>"))
    draw_layer_filters(mlp[0])

    display(HTML("<h3>DBN training</h3>"))
    train_dbn(dbn, X_train, monitoring_set, batch_size, epochs_count)

    for layer in mlp:
        layer.reset()

    initialize_mlp(mlp, dbn)

    display(HTML("<h3>Finetuning pretrained MLP</h3>"))
    run_mlp_training(mlp, X_train, t_train, X_valid, t_valid, batch_size, epochs_count)

    display(HTML("<h3>First layer filters in the DBN</h3>"))
    draw_filters(dbn[0])

    display(HTML("<h3>Input layer filters in the pretrained & finetuned MLP</h3>"))
    draw_layer_filters(mlp[0])

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE * DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.5
L2_PENALTY = 0.00002

# %% [markdown]
# ### Shallow neural network

# %%
shallow_mlp = [
    Linear(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Sigmoid(),
    Linear(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    
# Epoch 46:	########################################	elapsed: 0.23s, accuracy: 94.38%
# Epoch 47:	########################################	elapsed: 0.22s, accuracy: 94.23%
# Epoch 48:	########################################	elapsed: 0.24s, accuracy: 94.19%
# Epoch 49:	########################################	elapsed: 0.26s, accuracy: 94.35%
# Epoch 50:	########################################	elapsed: 0.29s, accuracy: 94.36%
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 0.53s, reconstruction error: 26.99
# Epoch 2:	########################################	elapsed: 0.41s, reconstruction error: 21.66
# Epoch 3:	########################################	elapsed: 0.41s, reconstruction error: 19.37
# Epoch 4:	########################################	elapsed: 0.39s, reconstruction error: 17.25
# Epoch 5:	########################################	elapsed: 0.45s, reconstruction error: 16.32
# Epoch 6:	########################################	elapsed: 0.39s, reconstruction error: 14.83
# Epoch 7:	########################################	elapsed: 0.57s, reconstruction error: 13.45
# Epoch 8:	########################################	elapsed: 0.40s, reconstruction error: 12.50
# Epoch 9:	########################################	elapsed: 0.45s, reconstruction error: 11.99
# Epoch 10:	########################################	elapsed: 0.41s, reconstruction error: 11.94
# Epoch 11:	########################################	elapsed: 0.41s, reconstruction error: 11.63
# Epoch 12:	########################################	elapsed: 0.47s, reconstruction error: 11.03
# Epoch 13:	########################################	elapsed: 0.46s, reconstruction error: 11.09
# Epoch 14:	########################################	elapsed: 0.45s, reconstruction error: 10.95
# Epoch 15:	########################################	elapsed: 0.43s, reconstruction error: 10.84
# Epoch 16:	########################################	elapsed: 0.48s, reconstruction error: 10.56
# Epoch 17:	########################################	elapsed: 0.42s, reconstruction error: 10.61
# Epoch 18:	########################################	elapsed: 0.40s, reconstruction error: 10.57
# Epoch 19:	########################################	elapsed: 0.46s, reconstruction error: 10.24
# Epoch 20:	########################################	elapsed: 0.42s, reconstruction error: 10.13
# Epoch 21:	########################################	elapsed: 0.41s, reconstruction error: 10.13
# Epoch 22:	########################################	elapsed: 0.41s, reconstruction error: 10.08
# Epoch 23:	########################################	elapsed: 0.41s, reconstruction error: 10.08
# Epoch 24:	########################################	elapsed: 0.41s, reconstruction error: 10.10
# Epoch 25:	########################################	elapsed: 0.42s, reconstruction error: 9.83
# Epoch 26:	########################################	elapsed: 0.39s, reconstruction error: 9.91
# Epoch 27:	########################################	elapsed: 0.42s, reconstruction error: 9.91
# Epoch 28:	########################################	elapsed: 0.39s, reconstruction error: 9.84
# Epoch 29:	########################################	elapsed: 0.42s, reconstruction error: 9.60
# Epoch 30:	########################################	elapsed: 0.39s, reconstruction error: 9.87
# Epoch 31:	########################################	elapsed: 0.39s, reconstruction error: 9.87
# Epoch 32:	########################################	elapsed: 0.40s, reconstruction error: 9.79
# Epoch 33:	########################################	elapsed: 0.46s, reconstruction error: 9.68
# Epoch 34:	########################################	elapsed: 0.40s, reconstruction error: 9.53
# Epoch 35:	########################################	elapsed: 0.39s, reconstruction error: 9.66
# Epoch 36:	########################################	elapsed: 0.41s, reconstruction error: 9.60
# Epoch 37:	########################################	elapsed: 0.41s, reconstruction error: 9.62
# Epoch 38:	########################################	elapsed: 0.38s, reconstruction error: 9.61
# Epoch 39:	########################################	elapsed: 0.43s, reconstruction error: 9.61
# Epoch 40:	########################################	elapsed: 0.42s, reconstruction error: 9.50
# Epoch 41:	########################################	elapsed: 0.42s, reconstruction error: 9.42
# Epoch 42:	########################################	elapsed: 0.43s, reconstruction error: 9.54
# Epoch 43:	########################################	elapsed: 0.47s, reconstruction error: 9.44
# Epoch 44:	########################################	elapsed: 0.43s, reconstruction error: 9.43
# Epoch 45:	########################################	elapsed: 0.54s, reconstruction error: 9.38
# Epoch 46:	########################################	elapsed: 0.43s, reconstruction error: 9.21
# Epoch 47:	########################################	elapsed: 0.44s, reconstruction error: 9.47
# Epoch 48:	########################################	elapsed: 0.44s, reconstruction error: 9.37
# Epoch 49:	########################################	elapsed: 0.41s, reconstruction error: 9.35
# Epoch 50:	########################################	elapsed: 0.39s, reconstruction error: 9.36
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.25s, reconstruction error: 14.78
# Epoch 2:	########################################	elapsed: 0.34s, reconstruction error: 11.68
# Epoch 3:	########################################	elapsed: 0.23s, reconstruction error: 10.26
# Epoch 4:	########################################	elapsed: 0.26s, reconstruction error: 9.24
# Epoch 5:	########################################	elapsed: 0.24s, reconstruction error: 8.60
# Epoch 6:	########################################	elapsed: 0.23s, reconstruction error: 7.62
# Epoch 7:	########################################	elapsed: 0.22s, reconstruction error: 6.83
# Epoch 8:	########################################	elapsed: 0.26s, reconstruction error: 6.27
# Epoch 9:	########################################	elapsed: 0.23s, reconstruction error: 5.94
# Epoch 10:	########################################	elapsed: 0.24s, reconstruction error: 5.85
# Epoch 11:	########################################	elapsed: 0.22s, reconstruction error: 5.55
# Epoch 12:	########################################	elapsed: 0.24s, reconstruction error: 5.41
# Epoch 13:	########################################	elapsed: 0.23s, reconstruction error: 5.33
# Epoch 14:	########################################	elapsed: 0.25s, reconstruction error: 5.27
# Epoch 15:	########################################	elapsed: 0.23s, reconstruction error: 5.23
# Epoch 16:	########################################	elapsed: 0.23s, reconstruction error: 5.06
# Epoch 17:	########################################	elapsed: 0.23s, reconstruction error: 5.12
# Epoch 18:	########################################	elapsed: 0.30s, reconstruction error: 4.94
# Epoch 19:	########################################	elapsed: 0.23s, reconstruction error: 4.97
# Epoch 20:	########################################	elapsed: 0.24s, reconstruction error: 4.84
# Epoch 21:	########################################	elapsed: 0.24s, reconstruction error: 4.77
# Epoch 22:	########################################	elapsed: 0.22s, reconstruction error: 4.79
# Epoch 23:	########################################	elapsed: 0.24s, reconstruction error: 4.76
# Epoch 24:	########################################	elapsed: 0.22s, reconstruction error: 4.65
# Epoch 25:	########################################	elapsed: 0.25s, reconstruction error: 4.59
# Epoch 26:	########################################	elapsed: 0.23s, reconstruction error: 4.66
# Epoch 27:	########################################	elapsed: 0.23s, reconstruction error: 4.75
# Epoch 28:	########################################	elapsed: 0.25s, reconstruction error: 4.54
# Epoch 29:	########################################	elapsed: 0.24s, reconstruction error: 4.60
# Epoch 30:	########################################	elapsed: 0.24s, reconstruction error: 4.56
# Epoch 31:	########################################	elapsed: 0.24s, reconstruction error: 4.45
# Epoch 32:	########################################	elapsed: 0.22s, reconstruction error: 4.42
# Epoch 33:	########################################	elapsed: 0.22s, reconstruction error: 4.52
# Epoch 34:	########################################	elapsed: 0.23s, reconstruction error:
# Epoch 32:	########################################	elapsed: 0.29s, accuracy: 96.87%
# Epoch 33:	########################################	elapsed: 0.21s, accuracy: 96.89%
# Epoch 34:	########################################	elapsed: 0.24s, accuracy: 96.90%
# Epoch 35:	########################################	elapsed: 0.23s, accuracy: 96.93%
# Epoch 36:	########################################	elapsed: 0.25s, accuracy: 96.94%
# Epoch 37:	########################################	elapsed: 0.25s, accuracy: 96.94%
# Epoch 38:	########################################	elapsed: 0.25s, accuracy: 96.93%
# Epoch 39:	########################################	elapsed: 0.25s, accuracy: 96.93%
# Epoch 40:	########################################	elapsed: 0.25s, accuracy: 96.92%
# Epoch 41:	########################################	elapsed: 0.27s, accuracy: 96.92%
# Epoch 42:	########################################	elapsed: 0.25s, accuracy: 96.95%
# Epoch 43:	########################################	elapsed: 0.26s, accuracy: 96.95%
# Epoch 44:	########################################	elapsed: 0.24s, accuracy: 96.95%
# Epoch 45:	########################################	elapsed: 0.27s, accuracy: 96.95%
# Epoch 46:	########################################	elapsed: 0.27s, accuracy: 96.95%
# Epoch 47:	########################################	elapsed: 0.28s, accuracy: 96.97%
# Epoch 48:	########################################	elapsed: 0.21s, accuracy: 96.97%
# Epoch 49:	########################################	elapsed: 0.32s, accuracy: 96.98%
# Epoch 50:	########################################	elapsed: 0.23s, accuracy: 96.98%
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>

# %% [markdown]
# ### Deep neural network

# %%
deep_mlp = [
    Linear(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Sigmoid(),
    Linear(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Sigmoid(),
    Linear(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM, L2_PENALTY),
    Sigmoid(),
    Linear(HIDDEN_LAYER_SIZE, 10, SOFTMAX_LEARNING_RATE, MOMENTUM, L2_PENALTY),
]

deep_dbn = [
    RBM(layer.vsize, layer.hsize, LEARNING_RATE, MOMENTUM, 0.0, L2_PENALTY)
    for layer in deep_mlp[:-1]
    if isinstance(layer, Linear)
]

compare_pretraining_results(
    deep_mlp,
    deep_dbn,
    mnist_train_images,
    mnist_train_labels,
    mnist_test_images,
    mnist_test_labels,
    monitoring_set,
    BATCH_SIZE,
    EPOCHS_COUNT,
)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.34s, accuracy: 10.28%
# Epoch 2:	########################################	elapsed: 0.34s, accuracy: 10.28%
# Epoch 3:	########################################	elapsed: 0.4s, accuracy: 10.28%
# Epoch 4:	########################################	elapsed: 0.34s, accuracy: 18.54%
# Epoch 5:	########################################	elapsed: 0.33s, accuracy: 45.50%
# Epoch 6:	########################################	elapsed: 0.32s, accuracy: 73.86%
# Epoch 7:	########################################	elapsed: 0.32s, accuracy: 82.44%
# Epoch 8:	########################################	elapsed: 0.3s, accuracy: 85.44%
# Epoch 9:	########################################	elapsed: 0.32s, accuracy: 86.74%
# Epoch 10:	########################################	elapsed: 0.48s, accuracy: 88.77%
# Epoch 11:	########################################	elapsed: 0.4s, accuracy: 89.66%
# Epoch 12:	########################################	elapsed: 0.35s, accuracy: 90.19%
# Epoch 13:	########################################	elapsed: 0.33s, accuracy: 90.49%
# Epoch 14:	########################################	elapsed: 0.3s, accuracy: 91.20%
# Epoch 15:	########################################	elapsed: 0.38s, accuracy: 91.68%
# Epoch 16:	########################################	elapsed: 0.37s, accuracy: 92.15%
# Epoch 17:	########################################	elapsed: 0.34s, accuracy: 92.55%
# Epoch 18:	########################################	elapsed: 0.34s, accuracy: 92.79%
# Epoch 19:	########################################	elapsed: 0.35s, accuracy: 92.95%
# Epoch 20:	########################################	elapsed: 0.31s, accuracy: 92.77%
# Epoch 21:	########################################	elapsed: 0.34s, accuracy: 92.96%
# Epoch 19:	########################################	elapsed: 0.36s, reconstruction error: 10.27
# Epoch 20:	########################################	elapsed: 0.38s, reconstruction error: 10.12
# Epoch 21:	########################################	elapsed: 0.38s, reconstruction error: 10.01
# Epoch 22:	########################################	elapsed: 0.37s, reconstruction error: 10.00
# Epoch 23:	########################################	elapsed: 0.37s, reconstruction error: 9.95
# Epoch 24:	########################################	elapsed: 0.39s, reconstruction error: 10.01
# Epoch 25:	########################################	elapsed: 0.37s, reconstruction error: 9.74
# Epoch 26:	########################################	elapsed: 0.38s, reconstruction error: 9.83
# Epoch 27:	########################################	elapsed: 0.36s, reconstruction error: 9.78
# Epoch 28:	########################################	elapsed: 0.42s, reconstruction error: 9.99
# Epoch 29:	########################################	elapsed: 0.40s, reconstruction error: 9.88
# Epoch 30:	########################################	elapsed: 0.36s, reconstruction error: 9.69
# Epoch 31:	########################################	elapsed: 0.37s, reconstruction error: 9.74
# Epoch 32:	########################################	elapsed: 0.37s, reconstruction error: 9.62
# Epoch 33:	########################################	elapsed: 0.38s, reconstruction error: 9.57
# Epoch 34:	########################################	elapsed: 0.37s, reconstruction error: 9.61
# Epoch 35:	########################################	elapsed: 0.38s, reconstruction error: 9.55
# Epoch 36:	########################################	elapsed: 0.37s, reconstruction error: 9.54
# Epoch 37:	########################################	elapsed: 0.38s, reconstruction error: 9.58
# Epoch 38:	########################################	elapsed: 0.37s, reconstruction error: 9.55
# Epoch 39:	########################################	elapsed: 0.36s, reconstruction error: 9.54
# Epoch 40:	########################################	elapsed: 0.38s, reconstruction error: 9.72
# Epoch 41:	########################################	elapsed: 0.37s, reconstruction error: 9.69
# Epoch 42:	########################################	elapsed: 0.39s, reconstruction error: 9.67
# Epoch 43:	########################################	elapsed: 0.36s, reconstruction error: 9.63
# Epoch 44:	########################################	elapsed: 0.39s, reconstruction error: 9.56
# Epoch 45:	########################################	elapsed: 0.37s, reconstruction error: 9.38
# Epoch 46:	########################################	elapsed: 0.37s, reconstruction error: 9.43
# Epoch 47:	########################################	elapsed: 0.38s, reconstruction error: 9.42
# Epoch 48:	########################################	elapsed: 0.36s, reconstruction error: 9.27
# Epoch 49:	########################################	elapsed: 0.36s, reconstruction error: 9.44
# Epoch 50:	########################################	elapsed: 0.36s, reconstruction error: 9.43
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.24s, reconstruction error: 14.74
# Epoch 2:	########################################	elapsed: 0.23s, reconstruction error: 11.80
# Epoch 3:	########################################	elapsed: 0.24s, reconstruction error: 10.33
# Epoch 4:	########################################	elapsed: 0.23s, reconstruction error: 9.24
# Epoch 5:	########################################	elapsed: 0.23s, reconstruction error: 8.70
# Epoch 6:	########################################	elapsed: 0.23s, reconstruction error: 7.80
# Epoch 7:	########################################	elapsed: 0.25s, reconstruction error: 6.68
# Epoch 8:	########################################	elapsed: 0.23s, reconstruction error: 6.36
# Epoch 9:	########################################	elapsed: 0.24s, reconstruction error: 6.07
# Epoch 10:	########################################	elapsed: 0.23s, reconstruction error: 5.75
# Epoch 11:	########################################	elapsed: 0.25s, reconstruction error: 5.56
# Epoch 12:	########################################	elapsed: 0.24s, reconstruction error: 5.52
# Epoch 13:	########################################	elapsed: 0.23s, reconstruction error: 5.44
# Epoch 14:	########################################	elapsed: 0.24s, reconstruction error: 5.25
# Epoch 15:	########################################	elapsed: 0.24s, reconstruction error: 5.17
# Epoch 16:	########################################	elapsed: 0.24s, reconstruction error: 5.15
# Epoch 17:	########################################	elapsed: 0.23s, reconstruction error: 4.94
# Epoch 18:	########################################	elapsed: 0.25s, reconstruction error: 4.91
# Epoch 19:	########################################	elapsed: 0.24s, reconstruction error: 4.92
# Epoch 20:	########################################	elapsed: 0.24s, reconstruction error: 4.89
# Epoch 21:	########################################	elapsed: 0.22s, reconstruction error: 4.88
# Epoch 22:	########################################	elapsed: 0.24s, reconstruction error: 4.79
# Epoch 23:	########################################	elapsed: 0.25s, reconstruction error: 4.72
# Epoch 24:	########################################	elapsed: 0.22s, reconstruction error: 4.69
# Epoch 25:	########################################	elapsed: 0.23s, reconstruction error: 4.57
# Epoch 26:	########################################	elapsed: 0.24s, reconstruction error: 4.65
# Epoch 27:	########################################	elapsed: 0.22s, reconstruction error: 4.68
# Epoch 28:	########################################	elapsed: 0.22s, reconstruction error: 4.53
# Epoch 29:	########################################	elapsed: 0.23s, reconstruction error: 4.51
# Epoch 30:	########################################	elapsed: 0.24s, reconstruction error: 4.69
# Epoch 31:	########################################	elapsed: 0.25s, reconstruction error: 4.43
# Epoch 32:	########################################	elapsed: 0.22s, reconstruction error: 4.51
# Epoch 33:	########################################	elapsed: 0.23s, reconstruction error: 4.46
# Epoch 34:	########################################	elapsed: 0.23s, reconstruction error: 4.48
# Epoch 35:	########################################	elapsed: 0.24s, reconstruction error: 4.56
# Epoch 36:	########################################	elapsed: 0.25s, reconstruction error: 4.49
# Epoch 37:	########################################	elapsed: 0.24s, reconstruction error: 4.47
# Epoch 38:	########################################	elapsed: 0.24s, reconstruction error: 4.43
# Epoch 39:	########################################	elapsed: 0.23s, reconstruction error: 4.45
# Epoch 40:	########################################	elapsed: 0.23s, reconstruction error: 4.50
# Epoch 41:	########################################	elapsed: 0.24s, reconstruction error: 4.55
# Epoch 42:	########################################	elapsed: 0.26s, reconstruction error: 4.55
# Epoch 43:	########################################	elapsed: 0.22s, reconstruction error: 4.48
# Epoch 44:	########################################	elapsed: 0.23s, reconstruction error: 4.39
# Epoch 45:	########################################	elapsed: 0.23s, reconstruction error: 4.41
# Epoch 46:	########################################	elapsed: 0.24s, reconstruction error: 4.41
# Epoch 47:	########################################	elapsed: 0.23s, reconstruction error: 4.33
# Epoch 48:	########################################	elapsed: 0.24s, reconstruction error: 4.38
# Epoch 49:	########################################	elapsed: 0.24s, reconstruction error: 4.33
# Epoch 50:	########################################	elapsed: 0.24s, reconstruction error: 4.44
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.26s, reconstruction error: 10.85
# Epoch 2:	########################################	elapsed: 0.27s, reconstruction error: 8.25
# Epoch 3:	########################################	elapsed: 0.26s, reconstruction error: 6.99
# Epoch 4:	########################################	elapsed: 0.27s, reconstruction error: 6.33
# Epoch 5:	########################################	elapsed: 0.27s, reconstruction error: 5.71
# Epoch 6:	########################################	elapsed: 0.27s, reconstruction error: 5.00
# Epoch 7:	########################################	elapsed: 0.27s, reconstruction error: 4.51
# Epoch 8:	########################################	elapsed: 0.31s, reconstruction error: 4.11
# Epoch 9:	########################################	elapsed: 0.26s, reconstruction error: 3.87
# Epoch 10:	########################################	elapsed: 0.27s, reconstruction error: 3.87
# Epoch 11:	########################################	elapsed: 0.26s, reconstruction error: 3.72
# Epoch 12:	########################################	elapsed: 0.25s, reconstruction error: 3.61
# Epoch 13:	########################################	elapsed: 0.27s, reconstruction error: 3.60
# Epoch 14:	########################################	elapsed: 0.26s, reconstruction error: 3.51
# Epoch 15:	########################################	elapsed: 0.26s, reconstruction error: 3.49
# Epoch 16:	########################################	elapsed: 0.27s, reconstruction error: 3.36
# Epoch 17:	########################################	elapsed: 0.26s, reconstruction error: 3.33
# Epoch 18:	########################################	elapsed: 0.26s, reconstruction error: 3.34
# Epoch 19:	########################################	elapsed: 0.25s, reconstruction error: 3.36
# Epoch 20:	########################################	elapsed: 0.27s, reconstruction error: 3.28
# Epoch 21:	########################################	elapsed: 0.25s, reconstruction error: 3.28
# Epoch 22:	########################################	elapsed: 0.26s, reconstruction error: 3.27
# Epoch 23:	########################################	elapsed: 0.27s, reconstruction error: 3.25
# Epoch 24:	########################################	elapsed: 0.27s, reconstruction error: 3.20
# Epoch 25:	########################################	elapsed: 0.29s, reconstruction error: 3.24
# Epoch 26:	########################################	elapsed: 0.26s, reconstruction error: 3.12
# Epoch 27:	########################################	elapsed: 0.26s, reconstruction error: 3.10
# Epoch 28:	########################################	elapsed: 0.27s, reconstruction error: 3.11
# Epoch 29:	########################################	elapsed: 0.26s, reconstruction error: 3.16
# Epoch 30:	########################################	elapsed: 0.26s, reconstruction error: 3.10
# Epoch 31:	########################################	elapsed: 0.25s, reconstruction error: 3.07
# Epoch 32:	########################################	elapsed: 0.27s, reconstruction error: 3.19
# Epoch 33:	########################################	elapsed: 0.26s, reconstruction error: 3.22
# Epoch 34:	########################################	elapsed: 0.27s, reconstruction error: 3.22
# Epoch 35:	########################################	elapsed: 0.25s, reconstruction error: 3.07
# Epoch 36:	########################################	elapsed: 0.32s, reconstruction error: 3.03
# Epoch 37:	########################################	elapsed: 0.27s, reconstruction error: 3.10
# Epoch 38:	########################################	elapsed: 0.25s, reconstruction error: 3.07
# Epoch 39:	########################################	elapsed: 0.27s, reconstruction error: 3.02
# Epoch 40:	########################################	elapsed: 0.26s, reconstruction error: 2.99
# Epoch 41:	########################################	elapsed: 0.25s, reconstruction error: 3.01
# Epoch 42:	########################################	elapsed: 0.26s, reconstruction error: 3.02
# Epoch 43:	########################################	elapsed: 0.27s, reconstruction error: 3.07
# Epoch 44:	########################################	elapsed: 0.26s, reconstruction error: 3.05
# Epoch 45:	########################################	elapsed: 0.24s, reconstruction error: 3.07
# Epoch 46:	########################################	elapsed: 0.25s, reconstruction error: 3.12
# Epoch 47:	########################################	elapsed: 0.25s, reconstruction error: 2.99
# Epoch 48:	########################################	elapsed: 0.26s, reconstruction error: 2.99
# Epoch 49:	########################################	elapsed: 0.25s, reconstruction error: 3.09
# Epoch 50:	########################################	elapsed: 0.26s, reconstruction error: 3.00
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0